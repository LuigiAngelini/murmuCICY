# %%
from sage.databases.cremona import CremonaDatabase # Database of elliptic curves over the rationals

# %%
db = CremonaDatabase()

# Extract elliptic curves with conductor in (7500, 10000) and rank 0 or 1
rank_zero_curves = []
rank_one_curves = []
for E in db.iter(range(7500, 10000)):
    if E.rank() == 0:
        rank_zero_curves.append(E)
    elif E.rank() == 1:
        rank_one_curves.append(E)

# %%
len(rank_zero_curves), len(rank_one_curves)
# Out:
# (7397, 8141)

# %%
# Extract representatives for different isogeny classes
rk0_isogeny_reps = []
rk0_isogeny_classes = []
rk1_isogeny_reps = []
rk1_isogeny_classes = []

for E in rank_zero_curves:
    if E.isogeny_class() not in rk0_isogeny_classes:
        rk0_isogeny_reps.append(E)
        rk0_isogeny_classes.append(E.isogeny_class())
for E in rank_one_curves:
    if E.isogeny_class() not in rk1_isogeny_classes:
        rk1_isogeny_reps.append(E)
        rk1_isogeny_classes.append(E.isogeny_class())

# %%
print(f"Number of distinct isogeny classes for conductor in [7500, 10000] and rank 0, 1: {len(rk0_isogeny_reps)}, {len(rk1_isogeny_reps)}")
# Out:
# Number of distinct isogeny classes for conductor in [7500, 10000] and rank 0, 1: 4328, 5194

# %%
# Import the list of primes
P = Primes()
P[0]
# Out:
# 2

# %%
import numpy as np

# %%
# Extract the average aps
N = 1000 # Number of primes I want to plot
rk0_eigenforms = [E.q_eigenform(P[N]) for E in rk0_isogeny_reps]
rk1_eigenforms = [E.q_eigenform(P[N]) for E in rk1_isogeny_reps]

rk0_aps = np.array([np.mean([ef[P[i]] for ef in rk0_eigenforms]) for i in range(N)])
rk1_aps = np.array([np.mean([ef[P[i]] for ef in rk1_eigenforms]) for i in range(N)])

# %%
save(rk0_aps, "rk0_aps")
save(rk1_aps, "rk1_aps")

# %%
rk0_aps = load("rk0_aps")
rk1_aps = load("rk1_aps")

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(range(N), rk0_aps, label="Rank 0", alpha=0.6, s=10)
plt.scatter(range(N), rk1_aps, label="Rank 1", alpha=0.6, s=10)
plt.legend()
plt.xlabel(r"Prime index $i$")
plt.ylabel(r"Average $a_{p_i}$")
plt.title(r"Average $a_p$ vs prime index over conductors $c \in [7500, 10000]$")
plt.show()

# %%
# Import rational elliptic curves from Candelas' paper

rational_form_labels = [
    "108570.cs1",
    "8190.j1",
    "99484.d1",
    "294630.bg2",
    "244530.bh2",
    "15180.m2",
    "56826.h2",
    "136290.cl2",
    "30940.b2",
    "198.d1",
    "18270.h2",
    "215710.l2",
    "170940.t2",
    "6006.n2",
    "1260.j1",
    "460922.d2",
    "60060.bc1",
    "39270.cn2",
    "30690.bc2",
    "2310.l3",
    "1260.d2",
    "910.a2",
    "106590.bz2",
    "422730.bw2",
    "244530.c1",
    "210.d3",
    "220.a2",
    "2394.k2",
    "414414.ck1",
    "30.a3",
    "53130.cf2",
    "81774.r2",
    "2310.u3",
    "358666.b2",
    "2170.k2",
    "15708.g2",
    "23310.w2",
    "5742.t2",
    "376740.v2",
    "2310.t2",
    "140910.be2",
    "1170.h2",
    "214830.bt2",
    "6270.k2",
    "84.b2",
    "87890.g2",
    "13860.t2",
    "117810.x2",
    "197340.n2",
    "90.a2",
    "10010.n2",
    "115710.cr2",
    "488070.c2",
    "462.f2",
    "10710.bc2",
    "20.a2",
    "180180.q2",
    "6006.p2",
    "256410.bs2",
    "43010.a2",
    "7770.ba4",
    "159390.s3",
    "630.j2",
    "12870.cc3",
    "125580.s3",
    "6930.ba3",
    "66.a2",
    "770.g3",
    "381810.bn3",
    "3570.j3",
    "432630.dv3",
    "497420.g3",
    "237510.v3",
    "2310.i2",
    "94710.br3",
    "352590.cz4",
    "363660.n4",
    "383460.w4",
    "6510.j4",
    "770.f4",
    "432630.c4",
    "308154.bw4",
    "27846.bf4",
    "284130.de4",
    "180180.bx4",
    "390.g4",
    "396270.bu4",
    "50622.j4",
    "487410.bw4",
    "48070.f4",
    "420.c4",
    "11220.k4",
    "144970.p4",
    "630.c4",
    "159390.eo4",
    "28490.b4",
    "124542.bc4",
    "421260.ba4",
    "217140.p4",
    "14.a6",
    "455070.cy4",
    "453390.cs4",
    "16830.bl4",
    "180180.cb4",
    "11970.bo4",
    "22610.m4",
    "14190.n4",
    "71610.o4",
    "1218.h4",
    "94710.cv4",
    "81510.bi4",
    "660.c4",
    "90090.dn4",
    "1638.e4",
    "4004.a4",
    "14070.e4",
    "415380.m4",
    "90.b4",
    "261030.v4",
    "418110.bh4",
    "122430.ba4",
    "11130.n4",
    "158730.bz4",
    "2660.c4",
    "4026.i4",
    "13860.k4",
    "117810.w4",
    "990.e4",
    "25830.bi4",
    "2730.m6",
    "244970.c4",
    "39270.bf4",
    "310.a4",
    "47124.k4",
    "4620.j4",
    "1170.c4",
    "118910.a4",
    "1974.j4",
    "186846.f4",
    "39780.h4",
    "218196.g4",
    "264740.a4",
    "180642.o4",
    "2130.g4",
    "23940.j4",
    "8690.f4",
    "53130.ch4",
    "61110.c4",
    "18746.c4",
    "23310.bl4",
    "33390.ca4",
    "77154.k4",
    "200970.p4",
    "16830.bi4",
    "322490.i4",
    "142230.t4",
    "30030.bt4",
    "345730.n3",
    "3570.w4",
    "306306.cv3",
    "231570.a3",
    "93610.a3",
    "81774.bv3",
    "150612.j1",
    "3870.l3",
    "2310.l3",
    "6402.r3",
    "179676.g3",
    "9790.b3",
    "431340.bd1",
    "73260.n1",
    "70380.t3",
    "66990.bq3",
    "910.g5",
    "2310.h2",
    "284130.du1",
    "171930.r3",
    "2394.d3",
    "30316.b3",
    "21420.v1",
    "210.d3",
    "99246.m3",
    "72930.bw3",
    "33110.b1",
    "56826.h1",
    "43890.ct4",
    "44460.c1",
    "53130.ci3",
    "3108.g3",
    "41730.k3",
    "198.d3",
    "208810.b3",
    "20460.m1",
    "18270.h1",
    "4060.b3",
    "17430.bp3",
    "14630.o2",
    "189210.cm1",
    "422730.dc2",
    "23562.bc1",
    "30.a3",
    "123354.bu2",
    "2070.a1",
    "159324.h2",
    "7084.c1",
    "2010.j2",
    "483210.ci1",
    "302610.ch1",
    "69762.bg2",
    "186438.j2",
    "1260.j2",
    "384090.z1",
    "170170.c2",
    "21210.bd2",
    "2090.c1",
    "60606.z1",
    "162470.b2",
    "1140.d1",
    "4290.bb2",
    "30690.r2",
    "60060.bc2",
    "91770.x2",
    "411180.n2",
    "332990.l1",
    "125034.i2",
    "296010.dq1",
    "34.a2",
    "30690.bc1",
    "21252.i1",
    "159390.dr2",
    "413490.bg2",
    "139230.cv2",
    "210.b2",
    "60606.k2",
    "175890.bx2",
    "31020.k2",
    "193578.i2",
    "164780.a2",
    "5754.i2",
    "1260.d1",
    "21630.bb2",
    "173740.b2",
    "1914.n1",
    "1290.h2",
    "126882.bk1",
    "71610.bs2",
    "910.a1",
    "19140.f2",
    "2070.p2",
    "123354.m1",
    "118830.f2",
    "65436.j1",
    "2310.u3",
    "456940.b1",
    "247170.dj1",
    "23562.h2",
    "157430.n2",
    "422730.bw1",
    "127974.y2",
    "156.b2",
    "71910.x1",
    "441210.cn2",
    "244530.c2",
    "43890.bj1",
    "15290.f2",
    "103290.s2",
    "1610.b1",
    "18270.bz2",
    "37740.f1",
    "149226.bs2",
    "415074.p2",
    "4270.c2",
    "45780.t2",
    "61230.z2",
    "198.b1",
    "358530.i2",
    "220780.b2",
    "471546.h2",
    "24780.p1",
    "44462.g1",
    "210.d4",
    "332010.ec1",
    "124830.bd2",
    "4830.bf1",
    "117810.cz2"
]

# %%
len(rational_form_labels)
# Out:
# 285

# %%
# Extract Candelas' curves from LMFDB directly
curves = [EllipticCurve(label) for label in rational_form_labels]

# %%
save(curves, "Candelas_rational_curves")

# %%
curves = load("Candelas_rational_curves")

# %%
# Sort them by rank
ranks = []

for E in curves:
    if E.rank() not in ranks:
        ranks.append(E.rank())

# %%
ranks
# Out:
# [0, 1, 2]

# %%
rk0_curves = []
rk1_curves = []
rk2_curves = []

for E in curves:
    if E.rank() == 0:
        rk0_curves.append(E)
    elif E.rank() == 1:
        rk1_curves.append(E)
    else:
        rk2_curves.append(E)

# %%
print(f"Number of curves of rank 0, 1, 2: {len(rk0_curves)}, {len(rk1_curves)}, {len(rk2_curves)}")
# Out:
# Number of curves of rank 0, 1, 2: 144, 134, 7

# %%
def get_isogeny_class_representatives(cs):
    """Extract one representative from each isogeny class"""
    seen_classes = []
    representatives = []
    
    for i, E in enumerate(cs):
        iso_class = E.isogeny_class()
        if iso_class not in seen_classes:
            representatives.append(E)
            seen_classes.append(iso_class)
    
    return representatives

# %%
# Apply to all three groups
print("Obtaining the isogeny class representatives for rank zero curves...")
rk0_isogeny_reps = get_isogeny_class_representatives(rk0_curves)
print("Done.")
print("Obtaining the isogeny class representatives for rank one curves...")
rk1_isogeny_reps = get_isogeny_class_representatives(rk1_curves)
print("Done.")
print("Obtaining the isogeny class representatives for rank two curves...")
rk2_isogeny_reps = get_isogeny_class_representatives(rk2_curves)
print("Done.")
# Out:
# Obtaining the isogeny class representatives for rank zero curves...
# Done.
# Obtaining the isogeny class representatives for rank one curves...
# Done.
# Obtaining the isogeny class representatives for rank two curves...
# Done.

# %%
import numpy as np
# Import the list of primes
P = Primes()

# %%
# Extract the average aps
N = 1000 # Number of primes I want to plot
rk0_eigenforms = [E.q_eigenform(P[N]) for E in rk0_isogeny_reps]
rk1_eigenforms = [E.q_eigenform(P[N]) for E in rk1_isogeny_reps]
rk2_eigenforms = [E.q_eigenform(P[N]) for E in rk2_isogeny_reps]

rk0_aps = np.array([np.mean([ef[P[i]] for ef in rk0_eigenforms]) for i in range(N)])
rk1_aps = np.array([np.mean([ef[P[i]] for ef in rk1_eigenforms]) for i in range(N)])
rk2_aps = np.array([np.mean([ef[P[i]] for ef in rk2_eigenforms]) for i in range(N)])

# %%
save(rk0_aps, "Candelas_rk0_aps")
save(rk1_aps, "Candelas_rk1_aps")
save(rk2_aps, "Candelas_rk2_aps")

# %%
rk0_aps = load("Candelas_rk0_aps")
rk1_aps = load("Candelas_rk1_aps")
rk2_aps = load("Candelas_rk2_aps")
N = 1000

# %%
import matplotlib.pyplot as plt

# %%
N = 1000
plt.scatter(range(N), rk0_aps[:N], label="Rank 0", alpha=0.6, s=10)
plt.scatter(range(N), rk1_aps[:N], label="Rank 1", alpha=0.6, s=10)
# plt.scatter(range(N), rk2_aps[:N], label="Rank 2", alpha=0.6, s=10)
plt.legend()
plt.xlabel(r"Prime index $i$")
plt.ylabel(r"Average $a_{p_i}$")
plt.title(r"Average $a_p$ vs prime index for Candelas' rational elliptic curves")
plt.show()

# %%
db.isogeny_class("2254f")
# Out:
# [Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 - 687*x - 2059 over Rational Field,
#  Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 - 8527*x - 306251 over Rational Field]

# %%
from sage.databases.cremona import CremonaDatabase

# Create database instance
db = CremonaDatabase()

# Specify the isogeny class
conductor = 2254
isogeny_class = 'f'
class_label = f"{conductor}{isogeny_class}"

# Get all curves in the isogeny class
try:
    # You can use either notation: "2254f" or "2254f1" 
    curves = db.isogeny_class(class_label)
    
    print(f"Isogeny class: {class_label}")
    print(f"Number of curves in class: {len(curves)}")
    print("-" * 60)
    
    for i, E in enumerate(curves, 1):
        label = f"{class_label}{i}"
        print(f"\nCurve {label}:")
        print(f"  Weierstrass equation: y^2 = {E.a_invariants()}")
        print(f"  Conductor: {E.conductor()}")
        print(f"  Discriminant: {E.discriminant()}")
        print(f"  j-invariant: {E.j_invariant()}")
        print(f"  Rank: {E.rank()}")
        print(f"  Torsion: {E.torsion_order()}")
        
    # Alternatively, access individual curves by their full label
    print("\n" + "="*60)
    print("Accessing curves individually:")
    for i in range(1, len(curves) + 1):
        label = f"{class_label}{i}"
        E = db.elliptic_curve(label)
        print(f"{label}: {E.ainvs()}")
        
except RuntimeError as e:
    print(f"Error: Isogeny class {class_label} not found in database")
    print(f"The conductor {conductor} may not have an isogeny class '{isogeny_class}'")
# Out:
# Isogeny class: 2254f
# Number of curves in class: 2
# ------------------------------------------------------------
#
# Curve 2254f1:
#   Weierstrass equation: y^2 = (1, 1, 1, -687, -2059)
#   Conductor: 2254
#   Discriminant: 19396084736
#   j-invariant: 304821217/164864
#   Rank: 0
#   Torsion: 2
#
# Curve 2254f2:
#   Weierstrass equation: y^2 = (1, 1, 1, -8527, -306251)
#   Conductor: 2254
#   Discriminant: 97586551328
#   j-invariant: 582810602977/829472
#   Rank: 0
#   Torsion: 2
#
# ============================================================
# Accessing curves individually:
# 2254f1: (1, 1, 1, -687, -2059)
# 2254f2: (1, 1, 1, -8527, -306251)

# %%
EllipticCurve("2254f1").q_eigenform(100)[3]
# Out:
# 2

# %%
R.<x> = PolynomialRing(QQ);  K.<a> = NumberField(R([-2, 0, 1]))
E = EllipticCurve([K([1,1]),K([-1,1]),K([1,0]),K([-883,-934]),K([-22223,-13420])])
# Elliptic curves over rational extensions do not have q_eigenforms, how do I extract the ap's? Via the L-functions, if I understand how to get
# the associated labels

# %%
# !sage -optional
# Out:
# [package]...............................[latest version] ([version])
#
# /projects/ruehlehet/luigi/sage/src/sage/misc/package.py:118: UserWarning: failed to fetch the version of pkg='auditwheel_or_delocate' at https://pypi.org/pypi/auditwheel_or_delocate/json
#   warnings.warn("failed to fetch the version of pkg={!r} at {}".format(pkg, url))
# /projects/ruehlehet/luigi/sage/src/sage/misc/package.py:118: UserWarning: failed to fetch the version of pkg='ore_algebra' at https://pypi.org/pypi/ore_algebra/json
#   warnings.warn("failed to fetch the version of pkg={!r} at {}".format(pkg, url))
# 4ti2....................................1.6.10 (not_installed)
# _bootstrap..............................? (not_installed)
# _develop................................? (not_installed)
# _gcc10..................................? (not_installed)
# _gcc11..................................? (not_installed)
# _gcc12..................................? (not_installed)
# _gcc8...................................? (not_installed)
# _gcc9...................................? (not_installed)
# _recommended............................? (not_installed)
# _sagemath...............................? (not_installed)
# admcycles...............................1.4 (not_installed)
# auditwheel_or_delocate..................? (not_installed)
# benzene.................................20130630 (not_installed)
# biopython...............................1.85 (not_installed)
# bliss...................................0.77 (not_installed)
# buckygen................................1.1 (not_installed)
# build...................................? (1.2.1)
# cbc.....................................2.9.4.p0 (not_installed)
# ccache..................................4.10.2 (4.10.2)
# clarabel................................0.9.0 (not_installed)
# coxeter3................................8ac9c71723c8ca57a836d6381aed125261e44e9e.p0 (not_installed)
# csdp....................................6.2.p1 (not_installed)
# cunningham_tables.......................1.0 (not_installed)
# cvxpy...................................1.4.1 (not_installed)
# cylp....................................0.92.2 (not_installed)
# cypari2.................................? (2.2.1)
# d3js....................................3.4.8 (not_installed)
# database_cremona_ellcurve...............20190911 (20190911)
# database_cubic_hecke....................2022.4.4 (not_installed)
# database_jones_numfield.................4 (not_installed)
# database_knotinfo.......................2024.10.1 (not_installed)
# database_kohel..........................20160724 (not_installed)
# database_mutation_class.................1.0 (not_installed)
# database_odlyzko_zeta...................20061209 (not_installed)
# database_stein_watkins..................20110713 (not_installed)
# database_stein_watkins_mini.............20070827 (not_installed)
# database_symbolic_data..................20070206 (not_installed)
# dot2tex.................................2.11.3.p0 (not_installed)
# dsdp....................................5.8 (not_installed)
# e_antic.................................2.0.2 (not_installed)
# ecos_python.............................2.0.12 (not_installed)
# ffmpeg..................................? (not_installed)
# free_fonts..............................? (not_installed)
# fricas..................................1.3.11 (not_installed)
# frobby..................................0.9.0.p2 (not_installed)
# gap_jupyter.............................0.9 (not_installed)
# gap_packages............................4.14.0 (not_installed)
# gdb.....................................? (not_installed)
# giac....................................1.9.0.15p0 (not_installed)
# git.....................................? (not_installed)
# github_cli..............................? (not_installed)
# gitpython...............................3.1.9 (not_installed)
# glucose.................................4.1 (not_installed)
# gp2c....................................0.0.10.p0 (not_installed)
# graphviz................................? (not_installed)
# hypothesis..............................6.99.9 (not_installed)
# igraph..................................0.10.15 (not_installed)
# imagemagick.............................? (not_installed)
# isl.....................................0.20 (not_installed)
# jmol....................................14.29.52 (not_installed)
# jupymake................................0.9 (not_installed)
# jupyter_jsmol...........................2022.1.0 (not_installed)
# kenzo...................................1.1.10 (not_installed)
# kissat..................................3.1.0 (not_installed)
# latte_int...............................1.7.6 (not_installed)
# libgraphviz.............................? (not_installed)
# libjpeg.................................? (not_installed)
# libnauty................................? (not_installed)
# libogg..................................1.3.1.p0 (not_installed)
# libsemigroups...........................2.7.3 (not_installed)
# libxml2.................................? (not_installed)
# lidia...................................2.3.0+latte-patches-2019-05-02 (not_installed)
# llvm....................................? (not_installed)
# lrslib..................................071b+autotools-2021-07-13 (not_installed)
# mathics.................................1.0 (not_installed)
# matroid_database........................0.3 (not_installed)
# mcqd....................................1.0.p0 (not_installed)
# meataxe.................................1.0.1 (not_installed)
# modular_resolution......................1.1 (not_installed)
# mpfrcx..................................0.6.3 (not_installed)
# msolve..................................0.7.5 (not_installed)
# nibabel.................................5.3.2 (not_installed)
# normaliz................................3.10.3 (not_installed)
# notedown................................1.5.1 (not_installed)
# onetbb..................................2021.12.0 (not_installed)
# ore_algebra.............................? (not_installed)
# osqp_python.............................0.6.3 (not_installed)
# p_group_cohomology......................3.3.3.p1 (not_installed)
# pandoc..................................? (not_installed)
# pandoc_attributes.......................8bc82f6d (not_installed)
# papilo..................................2.2.1 (not_installed)
# pari_elldata............................20161017 (not_installed)
# pari_galpol.............................20180625 (not_installed)
# pari_jupyter............................1.4.3 (not_installed)
# pari_nftables...........................20080929 (not_installed)
# pari_seadata............................20090618 (not_installed)
# pdf2svg.................................? (not_installed)
# perl_cpan_polymake_prereq...............? (not_installed)
# perl_mongodb............................? (not_installed)
# perl_term_readline_gnu..................1.35 (not_installed)
# phitigra................................0.2.6 (not_installed)
# plantri.................................5.3 (not_installed)
# polymake................................4.12 (not_installed)
# polytopes_db_4d.........................1.0 (not_installed)
# pybtex..................................0.9 (not_installed)
# pycosat.................................0.6.3 (not_installed)
# pycryptosat.............................5.11.9 (not_installed)
# pygraphviz..............................1.9 (not_installed)
# pynormaliz..............................2.20 (not_installed)
# pyppeteer...............................2.0.0rc2 (not_installed)
# pyscipopt...............................5.0.0 (not_installed)
# pysingular..............................0.9.7 (not_installed)
# python3_venv............................? (3.12--projects-ruehlehet-luigi-miniconda3-envs-sage-build-bin-python3)
# python_dateutil.........................? (2.9.0.post0)
# python_flint............................0.6.0 (not_installed)
# python_igraph...........................0.11.8 (not_installed)
# pyx.....................................0.9 (not_installed)
# qdldl_python............................0.1.5.post3 (not_installed)
# qepcad..................................1.74 (not_installed)
# r.......................................? (not_installed)
# rst2ipynb...............................0.2.3 (not_installed)
# rubiks..................................20070912.p21 (not_installed)
# saclib..................................2.2.8 (not_installed)
# sage_flatsurf...........................0.7.4 (not_installed)
# sage_numerical_backends_coin............10.4 (not_installed)
# sage_numerical_backends_cplex...........10.4 (not_installed)
# sage_numerical_backends_gurobi..........10.4 (not_installed)
# sage_sws2rst............................? (not_installed)
# sagemath................................? (0.0.0)
# sagemath_bliss..........................? (not_installed)
# sagemath_categories.....................? (not_installed)
# sagemath_coxeter3.......................? (not_installed)
# sagemath_doc_pdf........................? (not_installed)
# sagemath_environment....................? (not_installed)
# sagemath_giac...........................0.1.1 (not_installed)
# sagemath_mcqd...........................? (not_installed)
# sagemath_meataxe........................? (not_installed)
# sagemath_objects........................? (not_installed)
# sagemath_repl...........................? (not_installed)
# sagemath_sirocco........................? (not_installed)
# sagemath_standard.......................? (10.6)
# sagemath_tdlib..........................? (not_installed)
# sbcl....................................? (not_installed)
# scip....................................9.0.1 (not_installed)
# scip_sdp................................4.3.0 (not_installed)
# scs.....................................3.2.3 (not_installed)
# singular_jupyter........................0.9.7 (not_installed)
# sirocco.................................2.1.0 (not_installed)
# slabbe..................................0.8.0 (not_installed)
# snappy..................................3.2 (not_installed)
# soplex..................................7.0.1 (not_installed)
# sqlalchemy..............................2.0.9 (not_installed)
# surface_dynamics........................0.7.0 (not_installed)
# symengine...............................0.11.2 (not_installed)
# symengine_py............................0.11.0 (not_installed)
# tdlib...................................0.9.3.p0 (not_installed)
# texlive.................................? (not_installed)
# texlive_luatex..........................? (not_installed)
# texttable...............................1.7.0 (not_installed)
# tides...................................2.0.p0 (not_installed)
# topcom..................................1.1.2 (1.1.2)
# valgrind................................? (not_installed)
# xindy...................................? (not_installed)

# %%
# Extract conductors
conductors = [E.conductor() for E in curves]

# Create histogram using Sage
from sage.plot.histogram import histogram
h = histogram(conductors, bins=60)
h.show()
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
min(conductors), max(conductors)
# This set is spread over all possible conductors!
# Out:
# (14, 497420)

# %%
import numpy as np

conductors = np.array(conductors)
len(np.nonzero((conductors > 7500)*(conductors < 10000))[0])
# Out:
# 4

# %%
conductors[np.nonzero((conductors > 7500)*(conductors < 10000))[0]]
# Out:
# array([8190, 7770, 8690, 9790])

# %%
len(np.nonzero((conductors > 1)*(conductors < 100000))[0])
# Out:
# 177

# %%
# Restrict plot to conductors < 100 000
rk0_isogeny_reps_restricted = [rk0_isogeny_reps[i] for i in np.nonzero(np.array([E.conductor() for E in rk0_isogeny_reps]) < 100000)[0]]
rk1_isogeny_reps_restricted = [rk1_isogeny_reps[i] for i in np.nonzero(np.array([E.conductor() for E in rk1_isogeny_reps]) < 100000)[0]]
rk2_isogeny_reps_restricted = [rk2_isogeny_reps[i] for i in np.nonzero(np.array([E.conductor() for E in rk2_isogeny_reps]) < 100000)[0]]

# %%
# Extract the average aps
N = 1000 # Number of primes I want to plot
rk0_eigenforms_restricted = [E.q_eigenform(P[N]) for E in rk0_isogeny_reps_restricted]
rk1_eigenforms_restricted = [E.q_eigenform(P[N]) for E in rk1_isogeny_reps_restricted]
rk2_eigenforms_restricted = [E.q_eigenform(P[N]) for E in rk2_isogeny_reps_restricted]

rk0_restricted_aps = np.array([np.mean([ef[P[i]] for ef in rk0_eigenforms_restricted]) for i in range(N)])
rk1_restricted_aps = np.array([np.mean([ef[P[i]] for ef in rk1_eigenforms_restricted]) for i in range(N)])
rk2_restricted_aps = np.array([np.mean([ef[P[i]] for ef in rk2_eigenforms_restricted]) for i in range(N)])

# %%
import matplotlib.pyplot as plt

N = 1000
plt.scatter(range(N), rk0_restricted_aps[:N], label="Rank 0", alpha=0.6, s=10)
plt.scatter(range(N), rk1_restricted_aps[:N], label="Rank 1", alpha=0.6, s=10)
# plt.scatter(range(N), rk2_aps[:N], label="Rank 2", alpha=0.6, s=10)
plt.legend()
plt.xlabel(r"Prime index $i$")
plt.ylabel(r"Average $a_{p_i}$")
plt.title(r"Average $a_p$ vs prime index for Candelas' curves, conductor < 100000")
plt.show()

# %%
from sage.databases.cremona import CremonaDatabase # Database of elliptic curves over the rationals

db = CremonaDatabase()

# Define conductor range
cmax = 1000
cmin = 1

# Extract elliptic curves with conductor in (cmin, cmax) and rank 0 or 1
print(fr"Extracting curves in conductor range [{cmin, cmax}]...")
rank_zero_curves = []
rank_one_curves = []
for E in db.iter(range(cmin, cmax)):
    if E.rank() == 0:
        rank_zero_curves.append(E)
    elif E.rank() == 1:
        rank_one_curves.append(E)
print("Done.")

# Extract representatives for different isogeny classes
print("Extracting isogeny class representatives...")
rk0_isogeny_reps = []
rk0_isogeny_classes = []
rk1_isogeny_reps = []
rk1_isogeny_classes = []

for E in rank_zero_curves:
    if E.isogeny_class() not in rk0_isogeny_classes:
        rk0_isogeny_reps.append(E)
        rk0_isogeny_classes.append(E.isogeny_class())
for E in rank_one_curves:
    if E.isogeny_class() not in rk1_isogeny_classes:
        rk1_isogeny_reps.append(E)
        rk1_isogeny_classes.append(E.isogeny_class())
print("Done.")

# Import the list of primes
P = Primes()
P[0]

import numpy as np

# Extract the average aps
print("Computing average aps...")
N = 1000 # Number of primes I want to plot
rk0_eigenforms = [E.q_eigenform(P[N]) for E in rk0_isogeny_reps]
rk1_eigenforms = [E.q_eigenform(P[N]) for E in rk1_isogeny_reps]

rk0_aps = np.array([np.mean([ef[P[i]] for ef in rk0_eigenforms]) for i in range(N)])
rk1_aps = np.array([np.mean([ef[P[i]] for ef in rk1_eigenforms]) for i in range(N)])
print("Done.")

print("Saving aps...")
save(rk0_aps, f"({cmin}, {cmax})_rk0_aps")
save(rk1_aps, f"({cmin}, {cmax})_rk1_aps")
print("Done.")

import matplotlib.pyplot as plt

print("Plotting...")
plt.scatter(range(N), rk0_aps, label="Rank 0", alpha=0.6, s=10)
plt.scatter(range(N), rk1_aps, label="Rank 1", alpha=0.6, s=10)
plt.legend()
plt.xlabel(r"Prime index $i$")
plt.ylabel(r"Average $a_{p_i}$")
plt.title(fr"Average $a_p$ vs prime index over conductors $c \in [{cmin}, {cmax}]$")
plt.show()
# Out:
# Extracting curves in conductor range [(1, 1000)]...
# Done.
# Extracting isogeny class representatives...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:4832, in EllipticCurve_rational_field.isogeny_class(self, algorithm, order)
#    4831 try:
# -> 4832     isoclass = self._isoclass[algorithm]
#    4833 except KeyError:
#
# KeyError: 'sage'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /projects/ruehlehet/luigi/sage/src/sage/structure/category_object.pyx:857, in sage.structure.category_object.CategoryObject.getattr_from_category()
#     856 try:
# --> 857     return self._cached_methods[name]
#     858 except KeyError:
#
# KeyError: '_EllipticCurve_rational_field__minimal_model'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:3172, in EllipticCurve_rational_field.minimal_model(self)
#    3171 try:
# -> 3172     return self.__minimal_model
#    3173 except AttributeError:
#
# File /projects/ruehlehet/luigi/sage/src/sage/structure/category_object.pyx:851, in sage.structure.category_object.CategoryObject.__getattr__()
#     850 """
# --> 851 return self.getattr_from_category(name)
#     852
#
# File /projects/ruehlehet/luigi/sage/src/sage/structure/category_object.pyx:866, in sage.structure.category_object.CategoryObject.getattr_from_category()
#     865
# --> 866             attr = getattr_from_other_class(self, cls, name)
#     867             self._cached_methods[name] = attr
#
# File /projects/ruehlehet/luigi/sage/src/sage/cpython/getattr.pyx:358, in sage.cpython.getattr.getattr_from_other_class()
#     357     dummy_error_message.name = name
# --> 358     raise AttributeError(dummy_error_message)
#     359 cdef PyObject* attr = instance_getattr(cls, name)
#
# AttributeError: 'EllipticCurve_rational_field_with_category' object has no attribute '_pari_mincurve'
#
# During handling of the above exception, another exception occurred:
#
# SignalError                               Traceback (most recent call last)
# Cell In[20], line 28
#      25 rk1_isogeny_classes = []
#      27 for E in rank_zero_curves:
# ---> 28     if E.isogeny_class() not in rk0_isogeny_classes:
#      29         rk0_isogeny_reps.append(E)
#      30         rk0_isogeny_classes.append(E.isogeny_class())
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:4842, in EllipticCurve_rational_field.isogeny_class(self, algorithm, order)
#    4839     else:
#    4840         label = None
# -> 4842     isoclass = IsogenyClass_EC_Rational(self, algorithm, label)
#    4843     self._isoclass[algorithm] = isoclass
#    4845 if order:
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/isogeny_class.py:1039, in IsogenyClass_EC_Rational.__init__(self, E, algorithm, label, empty)
#    1007 r"""
#    1008 INPUT:
#    1009
#    (...)
#    1036     sage: TestSuite(isocls).run()
#    1037 """
#    1038 self._algorithm = algorithm
# -> 1039 IsogenyClass_EC.__init__(self, E, label=label, empty=empty)
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/isogeny_class.py:72, in IsogenyClass_EC.__init__(self, E, label, empty)
#      70 self._label = label
#      71 if not empty:
# ---> 72     self._compute()
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/isogeny_class.py:1105, in IsogenyClass_EC_Rational._compute(self)
#    1103 while i < len(curves):
#    1104     E = curves[i]
# -> 1105     isogs = E.isogenies_prime_degree(l_list)
#    1106     for phi in isogs:
#    1107         Edash = phi.codomain()
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:4924, in EllipticCurve_rational_field.isogenies_prime_degree(self, l)
#    4922         raise ValueError("%s is not prime." % l)
#    4923 if l is None:
# -> 4924     isogs = isogenies_prime_degree_genus_0(self)
#    4925     if isogs:
#    4926         return isogs
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/isogeny_small_degree.py:343, in isogenies_prime_degree_genus_0(E, l, minimal_models)
#     340     return isogs
#     342 if l is None:
# --> 343     return sum([isogenies_prime_degree_genus_0(E, ell, minimal_models=minimal_models)
#     344                 for ell in [2,3,5,7,13]],[])
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/isogeny_small_degree.py:299, in isogenies_prime_degree_genus_0(E, l, minimal_models)
#     297     return isogenies_2(E, minimal_models=minimal_models)
#     298 if l == 3:
# --> 299     return isogenies_3(E, minimal_models=minimal_models)
#     300 if j == F(0):
#     301     if l == 5:
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/isogeny_small_degree.py:812, in isogenies_3(E, minimal_models)
#     810 from sage.rings.number_field.number_field_base import NumberField
#     811 model = "minimal" if minimal_models and isinstance(E.base_field(), NumberField) else None
# --> 812 isogs = [E.isogeny(f, model=model) for f in ff]
#     813 return isogs
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_field.py:1489, in EllipticCurve_field.isogeny(self, kernel, codomain, degree, model, check, algorithm, velu_sqrt_bound)
#    1487             return EllipticCurveHom_composite(self, kernel, codomain=codomain, model=model, velu_sqrt_bound=velu_sqrt_bound)
#    1488 try:
# -> 1489     return EllipticCurveIsogeny(self, kernel, codomain, degree, model, check=check)
#    1490 except AttributeError as e:
#    1491     raise RuntimeError("Unable to construct isogeny: %s" % e)
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_curve_isogeny.py:1078, in EllipticCurveIsogeny.__init__(self, E, kernel, codomain, degree, model, check)
#    1074     raise NotImplementedError
#    1076 self.__compute_codomain()
# -> 1078 self.__setup_post_isomorphism(codomain, model)
#    1080 if pre_isom is not None:
#    1081     self._set_pre_isomorphism(pre_isom)
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_curve_isogeny.py:1844, in EllipticCurveIsogeny.__setup_post_isomorphism(self, codomain, model)
#    1841         raise ValueError("cannot specify a codomain curve and model name simultaneously")
#    1843     from sage.schemes.elliptic_curves.ell_field import compute_model
# -> 1844     codomain = compute_model(oldE2, model)
#    1846 else:  # codomain is not None
#    1847     if not isinstance(codomain, EllipticCurve_generic):
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_field.py:2719, in compute_model(E, name)
#    2717     if not isinstance(E.base_field(), NumberField):
#    2718         raise ValueError('can only compute minimal model for curves over number fields')
# -> 2719     return E.global_minimal_model(semi_global=True)
#    2721 if name == 'short_weierstrass':
#    2722     return E.short_weierstrass_model()
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_number_field.py:1896, in EllipticCurve_number_field.global_minimal_model(self, proof, semi_global)
#    1894     E = self.global_integral_model()
#    1895     for P in E.base_ring()(E.discriminant()).support():
# -> 1896         E = E.local_data(P,proof, globally=True).minimal_model()
#    1897 else:
#    1898     from .kraus import semi_global_minimal_model
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_number_field.py:936, in EllipticCurve_number_field.local_data(self, P, proof, algorithm, globally)
#     933 from sage.schemes.elliptic_curves.ell_local_data import check_prime
#     934 P = check_prime(self.base_field(),P)
# --> 936 return self._get_local_data(P,proof,algorithm,globally)
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_number_field.py:999, in EllipticCurve_number_field._get_local_data(self, P, proof, algorithm, globally)
#     997     pass
#     998 from sage.schemes.elliptic_curves.ell_local_data import EllipticCurveLocalData
# --> 999 self._local_data[P, proof, algorithm, globally] = EllipticCurveLocalData(self, P, proof, algorithm, globally)
#    1000 return self._local_data[P, proof, algorithm, globally]
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_local_data.py:278, in EllipticCurveLocalData.__init__(self, E, P, proof, algorithm, globally)
#     276 self._cp = data[3].sage()
#     277 # We use a global minimal model since we can:
# --> 278 self._Emin_reduced = Eint.minimal_model()
#     279 self._val_disc = self._Emin_reduced.discriminant().valuation(p)
#     280 if self._fp > 0:
#
# File /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:3175, in EllipticCurve_rational_field.minimal_model(self)
#    3173 except AttributeError:
#    3174     F = self.pari_mincurve()
# -> 3175     self.__minimal_model = constructor.EllipticCurve([Q(F[i]) for i in range(5)])
#    3176     return self.__minimal_model
#
# File /projects/ruehlehet/luigi/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/cypari2/gen.pyx:1404, in cypari2.gen.Gen.__getitem__()
#    1402 # Create a new Gen as child of self
#    1403 # and store it in itemcache
# -> 1404 val = self.new_ref(gel(self.fixGEN(), i+1))
#    1405 self.cache(ind, val)
#    1406 return val
#
# File /projects/ruehlehet/luigi/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/cypari2/gen.pyx:209, in cypari2.gen.Gen.fixGEN()
#     207 """
#     208 if self.next is not None:
# --> 209     move_gens_to_heap(self.sp())
#     210 return self.g
#     211
#
# File /projects/ruehlehet/luigi/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/cypari2/stack.pyx:123, in cypari2.stack.move_gens_to_heap()
#     121 while avma <= lim and stackbottom is not <PyObject*>top_of_stack:
#     122     current = <Gen>stackbottom
# --> 123     sig_on()
#     124     current.g = gclone(current.g)
#     125     sig_block()
#
# SignalError: Segmentation fault

# %%
# Unparallelized, but it works. It breaks the retrieval of aps in batches to avoid errors

from sage.databases.cremona import CremonaDatabase
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import gc

# Database of elliptic curves over the rationals
db = CremonaDatabase()

# Define conductor range
cmax = 100000
cmin = 1

# Extract elliptic curves with conductor in (cmin, cmax) and rank 0 or 1
print(f"Extracting curves in conductor range [{cmin}, {cmax}]...")
rank_zero_curves = []
rank_one_curves = []

for E in tqdm(db.iter(range(cmin, cmax)), desc="Loading curves"):
    if E.rank() == 0:
        rank_zero_curves.append(E)
    elif E.rank() == 1:
        rank_one_curves.append(E)

print(f"Found {len(rank_zero_curves)} rank 0 curves and {len(rank_one_curves)} rank 1 curves.")

# Extract representatives for different isogeny classes using LABELS
print("Extracting isogeny class representatives...")

def get_isogeny_label(E):
    """Extract isogeny class from Cremona label (e.g., '11a1' -> '11a')"""
    label = E.cremona_label()
    # Remove the final digit(s) to get isogeny class
    i = len(label) - 1
    while i >= 0 and label[i].isdigit():
        i -= 1
    return label[:i+1]

rk0_isogeny_reps = []
rk0_seen_labels = set()

for E in tqdm(rank_zero_curves, desc="Rank 0 isogeny classes"):
    iso_label = get_isogeny_label(E)
    if iso_label not in rk0_seen_labels:
        rk0_isogeny_reps.append(E)
        rk0_seen_labels.add(iso_label)

rk1_isogeny_reps = []
rk1_seen_labels = set()

for E in tqdm(rank_one_curves, desc="Rank 1 isogeny classes"):
    iso_label = get_isogeny_label(E)
    if iso_label not in rk1_seen_labels:
        rk1_isogeny_reps.append(E)
        rk1_seen_labels.add(iso_label)

print(f"Found {len(rk0_isogeny_reps)} rank 0 isogeny classes")
print(f"Found {len(rk1_isogeny_reps)} rank 1 isogeny classes")

# Use prime_range instead of Primes() to avoid PARI issues
N = 1000  # Number of primes to plot
print(f"Computing first {N} primes using prime_range...")
primes_list = list(primes_first_n(N))
print(f"Prime range: {primes_list[0]} to {primes_list[-1]}")

# Function to safely compute all ap values for a curve
def compute_ap_list_for_curve(E, primes):
    """Compute all ap values for a curve, return None if any fail"""
    try:
        ap_list = []
        for p in primes:
            ap = E.ap(p)
            ap_list.append(ap)
        return ap_list
    except:
        return None

# Process curves in batches to avoid memory issues
BATCH_SIZE = 500

# Compute ap values for rank 0 curves
print("Computing rank 0 ap values in batches...")
rk0_ap_matrix = []
rk0_valid_curves = []
rk0_skipped = []

for batch_start in range(0, len(rk0_isogeny_reps), BATCH_SIZE):
    batch_end = min(batch_start + BATCH_SIZE, len(rk0_isogeny_reps))
    batch = rk0_isogeny_reps[batch_start:batch_end]
    
    print(f"Processing rank 0 batch {batch_start//BATCH_SIZE + 1}/{(len(rk0_isogeny_reps)-1)//BATCH_SIZE + 1}...")
    
    for E in tqdm(batch, desc=f"Rank 0 batch {batch_start}-{batch_end}"):
        ap_list = compute_ap_list_for_curve(E, primes_list)
        
        if ap_list is not None:
            rk0_ap_matrix.append(ap_list)
            rk0_valid_curves.append(E)
        else:
            rk0_skipped.append(E.cremona_label())
            print(f"  Skipping: {E.cremona_label()}")
    
    # Force garbage collection after each batch
    gc.collect()

print(f"Successfully computed ap for {len(rk0_valid_curves)}/{len(rk0_isogeny_reps)} rank 0 curves")

# Compute ap values for rank 1 curves
print("Computing rank 1 ap values in batches...")
rk1_ap_matrix = []
rk1_valid_curves = []
rk1_skipped = []

for batch_start in range(0, len(rk1_isogeny_reps), BATCH_SIZE):
    batch_end = min(batch_start + BATCH_SIZE, len(rk1_isogeny_reps))
    batch = rk1_isogeny_reps[batch_start:batch_end]
    
    print(f"Processing rank 1 batch {batch_start//BATCH_SIZE + 1}/{(len(rk1_isogeny_reps)-1)//BATCH_SIZE + 1}...")
    
    for E in tqdm(batch, desc=f"Rank 1 batch {batch_start}-{batch_end}"):
        ap_list = compute_ap_list_for_curve(E, primes_list)
        
        if ap_list is not None:
            rk1_ap_matrix.append(ap_list)
            rk1_valid_curves.append(E)
        else:
            rk1_skipped.append(E.cremona_label())
            print(f"  Skipping: {E.cremona_label()}")
    
    # Force garbage collection after each batch
    gc.collect()

print(f"Successfully computed ap for {len(rk1_valid_curves)}/{len(rk1_isogeny_reps)} rank 1 curves")

if len(rk0_ap_matrix) == 0 or len(rk1_ap_matrix) == 0:
    print("ERROR: Not enough ap values computed. Cannot proceed.")
else:
    # Convert to numpy arrays
    rk0_ap_matrix = np.array(rk0_ap_matrix)
    rk1_ap_matrix = np.array(rk1_ap_matrix)
    
    # Compute averages across curves for each prime
    print("Computing averages...")
    rk0_aps = np.mean(rk0_ap_matrix, axis=0)
    rk1_aps = np.mean(rk1_ap_matrix, axis=0)

    print("Saving aps...")
    save(rk0_aps, f"({cmin}, {cmax})_rk0_aps")
    save(rk1_aps, f"({cmin}, {cmax})_rk1_aps")
    print("Done.")

    print("Plotting...")
    plt.figure(figsize=(10, 6))
    plt.scatter(range(N), rk0_aps, label="Rank 0", alpha=0.6, s=10)
    plt.scatter(range(N), rk1_aps, label="Rank 1", alpha=0.6, s=10)
    plt.legend()
    plt.xlabel(r"Prime index $i$")
    plt.ylabel(r"Average $a_{p_i}$")
    plt.title(fr"Average $a_p$ vs prime index over conductors $c \in [{cmin}, {cmax}]$")
    plt.tight_layout()
    plt.savefig(f"ap_averages_{cmin}_{cmax}.png", dpi=150)
    plt.show()

    print("\n=== Summary ===")
    rk0_pct = 100.0 * len(rk0_valid_curves) / len(rk0_isogeny_reps)
    rk1_pct = 100.0 * len(rk1_valid_curves) / len(rk1_isogeny_reps)
    print(f"Rank 0: {len(rk0_valid_curves)}/{len(rk0_isogeny_reps)} curves ({rk0_pct:.1f}%)")
    print(f"Rank 1: {len(rk1_valid_curves)}/{len(rk1_isogeny_reps)} curves ({rk1_pct:.1f}%)")
    print(f"Total skipped: {len(rk0_skipped) + len(rk1_skipped)}")
# Out:
# Extracting curves in conductor range [1, 100000]...
# Loading curves: 204790it [06:49, 499.83it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 19
#      16 rank_zero_curves = []
#      17 rank_one_curves = []
# ---> 19 for E in tqdm(db.iter(range(cmin, cmax)), desc="Loading curves"):
#      20     if E.rank() == Integer(0):
#      21         rank_zero_curves.append(E)
#
# File /projects/ruehlehet/luigi/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /projects/ruehlehet/luigi/sage/src/sage/databases/cremona.py:1034, in MiniCremonaDatabase.iter(self, conductors)
#    1017 """
#    1018 Return an iterator through all curves in the database with given
#    1019 conductors.
#    (...)
#    1031      '14a6', '15a1', '15a2', '15a3', '15a4', '15a5', '15a6', '15a7', '15a8']
#    1032 """
#    1033 for N in conductors:
# -> 1034     for c in self.__connection__.cursor().execute('SELECT curve '
#    1035         + 'FROM t_curve,t_class USING(class) WHERE conductor=?',
#    1036         (int(N),)):
#    1037         yield self.elliptic_curve(c[0])
#
# File signals.pyx:355, in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
# Parallelized

from sage.databases.cremona import CremonaDatabase
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from joblib import Parallel, delayed
import gc
import multiprocessing

# Get number of available cores
n_cores = multiprocessing.cpu_count()
print(f"Using {n_cores} CPU cores")

# Database of elliptic curves over the rationals
db = CremonaDatabase()

# Define conductor range
cmax = 10000
cmin = 1

# Extract elliptic curves with conductor in (cmin, cmax) and rank 0 or 1
print(f"Extracting curves in conductor range [{cmin}, {cmax}]...")
rank_zero_curves = []
rank_one_curves = []

for E in tqdm(db.iter(range(cmin, cmax)), desc="Loading curves"):
    if E.rank() == 0:
        rank_zero_curves.append(E)
    elif E.rank() == 1:
        rank_one_curves.append(E)

print(f"Found {len(rank_zero_curves)} rank 0 curves and {len(rank_one_curves)} rank 1 curves.")

# Extract representatives for different isogeny classes using LABELS
print("Extracting isogeny class representatives...")

def get_isogeny_label(E):
    """Extract isogeny class from Cremona label (e.g., '11a1' -> '11a')"""
    label = E.cremona_label()
    # Remove the final digit(s) to get isogeny class
    i = len(label) - 1
    while i >= 0 and label[i].isdigit():
        i -= 1
    return label[:i+1]

rk0_isogeny_reps = []
rk0_seen_labels = set()

for E in tqdm(rank_zero_curves, desc="Rank 0 isogeny classes"):
    iso_label = get_isogeny_label(E)
    if iso_label not in rk0_seen_labels:
        rk0_isogeny_reps.append(E)
        rk0_seen_labels.add(iso_label)

rk1_isogeny_reps = []
rk1_seen_labels = set()

for E in tqdm(rank_one_curves, desc="Rank 1 isogeny classes"):
    iso_label = get_isogeny_label(E)
    if iso_label not in rk1_seen_labels:
        rk1_isogeny_reps.append(E)
        rk1_seen_labels.add(iso_label)

print(f"Found {len(rk0_isogeny_reps)} rank 0 isogeny classes")
print(f"Found {len(rk1_isogeny_reps)} rank 1 isogeny classes")

# Use prime_range instead of Primes() to avoid PARI issues
N = 1000  # Number of primes to plot
print(f"Computing first {N} primes using prime_range...")
primes_list = list(primes_first_n(N))
print(f"Prime range: {primes_list[0]} to {primes_list[-1]}")

# Function to compute ap values for a single curve
def compute_ap_list_for_curve(E, primes):
    """Compute all ap values for a curve, return (label, ap_list) or (label, None) if failed"""
    try:
        label = E.cremona_label()
        ap_list = []
        for p in primes:
            ap = E.ap(p)
            ap_list.append(ap)
        return (label, ap_list)
    except:
        return (E.cremona_label(), None)

# Process curves in parallel
print("Computing rank 0 ap values in parallel...")
rk0_results = Parallel(n_jobs=n_cores, backend='multiprocessing')(
    delayed(compute_ap_list_for_curve)(E, primes_list)
    for E in tqdm(rk0_isogeny_reps, desc="Rank 0 curves")
)

# Process results
rk0_ap_matrix = []
rk0_valid_labels = []
rk0_skipped = []

for label, ap_list in rk0_results:
    if ap_list is not None:
        rk0_ap_matrix.append(ap_list)
        rk0_valid_labels.append(label)
    else:
        rk0_skipped.append(label)
        print(f"  Skipped: {label}")

print(f"Successfully computed ap for {len(rk0_valid_labels)}/{len(rk0_isogeny_reps)} rank 0 curves")

# Force garbage collection
gc.collect()

print("Computing rank 1 ap values in parallel...")
rk1_results = Parallel(n_jobs=n_cores, backend='multiprocessing')(
    delayed(compute_ap_list_for_curve)(E, primes_list)
    for E in tqdm(rk1_isogeny_reps, desc="Rank 1 curves")
)

# Process results
rk1_ap_matrix = []
rk1_valid_labels = []
rk1_skipped = []

for label, ap_list in rk1_results:
    if ap_list is not None:
        rk1_ap_matrix.append(ap_list)
        rk1_valid_labels.append(label)
    else:
        rk1_skipped.append(label)
        print(f"  Skipped: {label}")

print(f"Successfully computed ap for {len(rk1_valid_labels)}/{len(rk1_isogeny_reps)} rank 1 curves")

# Force garbage collection
gc.collect()

if len(rk0_ap_matrix) == 0 or len(rk1_ap_matrix) == 0:
    print("ERROR: Not enough ap values computed. Cannot proceed.")
else:
    # Convert to numpy arrays
    print("Converting to numpy arrays...")
    rk0_ap_matrix = np.array(rk0_ap_matrix, dtype=np.float64)
    rk1_ap_matrix = np.array(rk1_ap_matrix, dtype=np.float64)
    
    # Compute averages across curves for each prime
    print("Computing averages...")
    rk0_aps = np.mean(rk0_ap_matrix, axis=0)
    rk1_aps = np.mean(rk1_ap_matrix, axis=0)

    print("Saving aps...")
    save(rk0_aps, f"({cmin}, {cmax})_rk0_aps")
    save(rk1_aps, f"({cmin}, {cmax})_rk1_aps")
    save(rk0_valid_labels, f"({cmin}, {cmax})_rk0_labels")
    save(rk1_valid_labels, f"({cmin}, {cmax})_rk1_labels")
    print("Done.")

    print("Plotting...")
    plt.figure(figsize=(12, 6))
    plt.scatter(range(N), rk0_aps, label=f"Rank 0 (n={len(rk0_valid_labels)})", alpha=0.6, s=10)
    plt.scatter(range(N), rk1_aps, label=f"Rank 1 (n={len(rk1_valid_labels)})", alpha=0.6, s=10)
    plt.legend()
    plt.xlabel(r"Prime index $i$")
    plt.ylabel(r"Average $a_{p_i}$")
    plt.title(fr"Average $a_p$ vs prime index over conductors $c \in [{cmin}, {cmax}]$")
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(f"ap_averages_{cmin}_{cmax}.png", dpi=150)
    plt.show()

    print("\n=== Summary ===")
    rk0_pct = 100.0 * len(rk0_valid_labels) / len(rk0_isogeny_reps)
    rk1_pct = 100.0 * len(rk1_valid_labels) / len(rk1_isogeny_reps)
    print(f"Rank 0: {len(rk0_valid_labels)}/{len(rk0_isogeny_reps)} curves ({rk0_pct:.1f}%)")
    print(f"Rank 1: {len(rk1_valid_labels)}/{len(rk1_isogeny_reps)} curves ({rk1_pct:.1f}%)")
    print(f"Total skipped: {len(rk0_skipped) + len(rk1_skipped)}")
    
    if rk0_skipped or rk1_skipped:
        print(f"\nSkipped curves saved to files.")
        save(rk0_skipped, f"({cmin}, {cmax})_rk0_skipped")
        save(rk1_skipped, f"({cmin}, {cmax})_rk1_skipped")
# Out:
# Using 28 CPU cores
# Extracting curves in conductor range [1, 10000]...
# Loading curves: 35321it [01:06, 532.65it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 25
#      22 rank_zero_curves = []
#      23 rank_one_curves = []
# ---> 25 for E in tqdm(db.iter(range(cmin, cmax)), desc="Loading curves"):
#      26     if E.rank() == Integer(0):
#      27         rank_zero_curves.append(E)
#
# File /projects/ruehlehet/luigi/sage/local/var/lib/sage/venv-python3.12/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /projects/ruehlehet/luigi/sage/src/sage/databases/cremona.py:1034, in MiniCremonaDatabase.iter(self, conductors)
#    1017 """
#    1018 Return an iterator through all curves in the database with given
#    1019 conductors.
#    (...)
#    1031      '14a6', '15a1', '15a2', '15a3', '15a4', '15a5', '15a6', '15a7', '15a8']
#    1032 """
#    1033 for N in conductors:
# -> 1034     for c in self.__connection__.cursor().execute('SELECT curve '
#    1035         + 'FROM t_curve,t_class USING(class) WHERE conductor=?',
#    1036         (int(N),)):
#    1037         yield self.elliptic_curve(c[0])
#
# File signals.pyx:355, in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:
