# %%
def j_invariant(phi):
    """
    Compute j(τ(φ)) = j(τ(φ,φ,φ))
    
    Parameters:
    -----------
    phi : float or complex
        The parameter φ
    
    Returns:
    --------
    float or complex
        The j-invariant value
    """
    numerator = (3*phi - 1)**3 * (3*phi**3 - 3*phi**2 + 9*phi - 1)**3
    denominator = phi**6 * (phi - 1)**3 * (9*phi - 1)
    
    return numerator / denominator

# %%
j_invariant(15/2)
# Out:
# 64096528489320601/13313408062500

# %%
def elliptic_curve_from_phi(phi):
    """
    Compute the Weierstrass coefficients (a, b) for the elliptic curve:
    y² = x³ + ax + b
    
    where the coefficients are given in terms of φ by equation (70):
    a = -(9φ⁴ - 12φ³ + 30φ² - 12φ + 1) / 3
    b = -2(27φ⁶ - 54φ⁵ - 135φ⁴ + 180φ³ - 99φ² + 18φ - 1) / 27
    
    Parameters:
    -----------
    phi : numeric (int, float, or symbolic)
        The parameter φ
    
    Returns:
    --------
    tuple : (a, b)
        The two Weierstrass coefficients
    """
    # Compute coefficient a
    a_numerator = 9*phi**4 - 12*phi**3 + 30*phi**2 - 12*phi + 1
    a = -a_numerator / 3
    
    # Compute coefficient b
    b_numerator = 27*phi**6 - 54*phi**5 - 135*phi**4 + 180*phi**3 - 99*phi**2 + 18*phi - 1
    b = -2 * b_numerator / 27
    
    return a, b

# SageMath version (if using Sage)
def elliptic_curve_from_phi_sage(phi):
    """
    SageMath version that returns an actual EllipticCurve object.
    
    Parameters:
    -----------
    phi : numeric or symbolic
        The parameter φ
    
    Returns:
    --------
    EllipticCurve : Sage EllipticCurve object
    """
    from sage.all import EllipticCurve, QQ
    
    a, b = elliptic_curve_from_phi(phi)
    
    # Create elliptic curve in Weierstrass form [0, 0, 0, a, b]
    return EllipticCurve([0, 0, 0, a, b])

# %%
phi = 2/23
ctest = elliptic_curve_from_phi_sage(phi)
ctest.label()
# Out:
# '4830be1'

# %%
import numpy as np

#Let's generate a new set of rational elliptic curves associated to the HV manifold
N = 8000

phis = np.random.randint(1, 100, size = (N))/np.random.randint(1, 100, size = (N))
phis = [QQ(x) for x in phis]

# %%
curves = []
for phi in phis:
    try:
        curves.append(elliptic_curve_from_phi_sage(phi))
    except (ArithmeticError, RuntimeError, LookupError):
        continue

print(f"Found {sum(l is not None for l in labels)}/{N} curves in database")
# Out:
# Found 7902/8000 curves in database

# %%
import matplotlib.pyplot as plt

# Convert Sage rationals to floats for plotting
phis_float = [float(phi) for phi in phis]

plt.hist(phis_float, bins=100)
plt.xlabel('φ')
plt.ylabel('Frequency')
plt.title('Distribution of φ values')
plt.show()

# %%
from tqdm import tqdm

# Sort them by rank
ranks = []

for E in tqdm(curves, "Checking ranks: "):
    try:
        rk = E.rank()
        if rk not in ranks:
            ranks.append(E.rank())
    except (RuntimeError, SignalError):
        continue
# Out:
# Checking ranks:   1%|▌                                                               | 75/7902 [00:00<00:45, 173.62it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   1%|▊                                                               | 93/7902 [00:00<01:15, 102.86it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   2%|▉                                                               | 122/7902 [00:01<01:18, 98.59it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   2%|█▎                                                              | 158/7902 [00:01<01:37, 79.10it/s]
# Unable to compute the rank with certainty (lower bound=1).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   2%|█▎                                                              | 167/7902 [00:02<02:03, 62.40it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   3%|█▊                                                              | 221/7902 [00:02<01:22, 92.62it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   4%|██▌                                                            | 316/7902 [00:02<00:54, 138.90it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   5%|███                                                             | 377/7902 [00:07<06:05, 20.58it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   7%|████▎                                                           | 537/7902 [00:20<09:38, 12.74it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   7%|████▎                                                           | 540/7902 [00:21<12:31,  9.80it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   8%|████▉                                                           | 605/7902 [00:26<09:24, 12.93it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   8%|█████                                                           | 624/7902 [00:27<13:19,  9.10it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   8%|█████▏                                                          | 637/7902 [00:29<17:20,  6.98it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   8%|█████▏                                                          | 640/7902 [00:30<21:02,  5.75it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   8%|█████▍                                                          | 665/7902 [00:34<14:28,  8.33it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:   9%|█████▌                                                          | 690/7902 [00:37<15:41,  7.66it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  11%|██████▊                                                         | 840/7902 [00:48<12:59,  9.06it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  11%|██████▊                                                         | 845/7902 [00:49<11:09, 10.54it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  11%|███████                                                         | 876/7902 [00:51<12:32,  9.34it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  11%|███████▏                                                        | 886/7902 [00:52<15:41,  7.45it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  11%|███████▎                                                        | 897/7902 [00:54<23:47,  4.91it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  12%|███████▋                                                        | 955/7902 [01:02<22:53,  5.06it/s]
# Unable to compute the rank with certainty (lower bound=1).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  12%|███████▊                                                        | 963/7902 [01:05<45:09,  2.56it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  13%|████████▎                                                      | 1045/7902 [01:15<12:52,  8.88it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  14%|████████▌                                                      | 1077/7902 [01:17<10:22, 10.97it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  14%|████████▊                                                      | 1113/7902 [01:22<22:12,  5.10it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  15%|█████████▌                                                     | 1199/7902 [01:29<14:33,  7.67it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  16%|██████████▎                                                    | 1287/7902 [01:38<12:44,  8.66it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  16%|██████████▎                                                    | 1300/7902 [01:40<15:52,  6.93it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  17%|██████████▍                                                    | 1309/7902 [01:41<15:17,  7.18it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  18%|███████████                                                    | 1385/7902 [01:49<11:21,  9.57it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  18%|███████████▌                                                   | 1447/7902 [01:54<08:19, 12.91it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  19%|████████████▏                                                  | 1528/7902 [02:02<11:58,  8.88it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  19%|████████████▎                                                  | 1537/7902 [02:03<09:34, 11.08it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  20%|████████████▌                                                  | 1577/7902 [02:06<16:10,  6.52it/s]
# Unable to compute the rank with certainty (lower bound=1).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  20%|████████████▌                                                  | 1583/7902 [02:06<07:57, 13.23it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  21%|█████████████▏                                                 | 1660/7902 [02:12<09:30, 10.94it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  21%|█████████████▍                                                 | 1693/7902 [02:14<08:22, 12.35it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  22%|█████████████▉                                                 | 1750/7902 [02:18<06:17, 16.29it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  24%|██████████████▊                                                | 1864/7902 [02:25<06:40, 15.09it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  24%|███████████████▏                                               | 1902/7902 [02:28<10:13,  9.78it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  24%|███████████████▍                                               | 1934/7902 [02:30<07:49, 12.71it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  25%|███████████████▌                                               | 1950/7902 [02:32<13:14,  7.49it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  25%|███████████████▌                                               | 1954/7902 [02:32<12:47,  7.75it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  25%|███████████████▊                                               | 1982/7902 [02:34<08:45, 11.26it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  25%|███████████████▉                                               | 1993/7902 [02:35<09:21, 10.53it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  25%|████████████████                                               | 2008/7902 [02:36<06:35, 14.89it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  26%|████████████████▌                                              | 2084/7902 [02:41<07:06, 13.64it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  26%|████████████████▋                                              | 2088/7902 [02:42<10:14,  9.46it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  26%|████████████████▋                                              | 2093/7902 [02:43<12:42,  7.62it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  27%|████████████████▉                                              | 2123/7902 [02:44<06:03, 15.90it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  27%|█████████████████                                              | 2139/7902 [02:45<07:03, 13.60it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  27%|█████████████████▏                                             | 2148/7902 [02:46<10:35,  9.06it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  28%|█████████████████▌                                             | 2205/7902 [02:51<05:59, 15.85it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  30%|██████████████████▋                                            | 2343/7902 [03:00<09:28,  9.78it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  30%|██████████████████▉                                            | 2375/7902 [03:02<07:07, 12.94it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  31%|███████████████████▎                                           | 2422/7902 [03:06<07:08, 12.78it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  31%|███████████████████▊                                           | 2483/7902 [03:11<09:22,  9.63it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  32%|███████████████████▊                                           | 2490/7902 [03:11<10:48,  8.34it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  32%|████████████████████▏                                          | 2535/7902 [03:15<08:52, 10.08it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  33%|████████████████████▊                                          | 2607/7902 [03:20<10:53,  8.10it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  34%|█████████████████████▋                                         | 2720/7902 [03:27<05:48, 14.85it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  35%|█████████████████████▊                                         | 2736/7902 [03:28<08:13, 10.46it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  35%|█████████████████████▉                                         | 2744/7902 [03:29<12:09,  7.07it/s]
# Unable to compute the rank with certainty (lower bound=1).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  35%|██████████████████████▏                                        | 2787/7902 [03:32<04:16, 19.98it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  36%|██████████████████████▍                                        | 2816/7902 [03:34<06:55, 12.24it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  36%|██████████████████████▋                                        | 2847/7902 [03:36<07:48, 10.79it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  36%|██████████████████████▉                                        | 2877/7902 [03:37<04:18, 19.46it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  37%|███████████████████████                                        | 2889/7902 [03:38<09:00,  9.28it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  37%|███████████████████████▍                                       | 2945/7902 [03:41<06:03, 13.63it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  38%|███████████████████████▋                                       | 2977/7902 [03:44<08:26,  9.72it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  38%|███████████████████████▊                                       | 2987/7902 [03:45<07:33, 10.84it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  38%|████████████████████████▏                                      | 3040/7902 [03:48<07:05, 11.43it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  39%|████████████████████████▋                                      | 3093/7902 [03:51<04:03, 19.76it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  39%|████████████████████████▊                                      | 3117/7902 [03:53<06:43, 11.86it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  40%|█████████████████████████▏                                     | 3153/7902 [03:55<03:25, 23.12it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  40%|█████████████████████████▍                                     | 3185/7902 [03:57<04:48, 16.36it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  40%|█████████████████████████▌                                     | 3199/7902 [03:58<07:03, 11.10it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  41%|█████████████████████████▌                                     | 3214/7902 [03:59<06:32, 11.95it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  41%|██████████████████████████                                     | 3274/7902 [04:03<06:43, 11.47it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  42%|██████████████████████████▍                                    | 3316/7902 [04:05<06:37, 11.53it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  43%|███████████████████████████▎                                   | 3432/7902 [04:12<05:53, 12.65it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  47%|█████████████████████████████▎                                 | 3681/7902 [04:23<05:18, 13.25it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  48%|██████████████████████████████▎                                | 3801/7902 [04:29<04:18, 15.89it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  49%|██████████████████████████████▌                                | 3839/7902 [04:31<03:51, 17.57it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  50%|███████████████████████████████▍                               | 3939/7902 [04:35<02:55, 22.57it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  50%|███████████████████████████████▍                               | 3944/7902 [04:36<06:26, 10.24it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  50%|███████████████████████████████▊                               | 3987/7902 [04:38<04:38, 14.07it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  53%|█████████████████████████████████▏                             | 4164/7902 [04:47<03:40, 16.99it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  53%|█████████████████████████████████▎                             | 4176/7902 [04:48<04:04, 15.24it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  53%|█████████████████████████████████▎                             | 4186/7902 [04:48<03:19, 18.66it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  54%|█████████████████████████████████▉                             | 4262/7902 [04:53<04:45, 12.75it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  54%|██████████████████████████████████▎                            | 4298/7902 [04:54<01:29, 40.08it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  56%|███████████████████████████████████                            | 4405/7902 [04:59<02:09, 26.98it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  57%|████████████████████████████████████                           | 4523/7902 [05:03<02:17, 24.61it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  58%|████████████████████████████████████▎                          | 4552/7902 [05:04<02:16, 24.57it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  58%|████████████████████████████████████▍                          | 4569/7902 [05:05<03:28, 16.01it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  58%|████████████████████████████████████▍                          | 4571/7902 [05:06<05:29, 10.10it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  58%|████████████████████████████████████▍                          | 4578/7902 [05:07<06:19,  8.75it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  59%|█████████████████████████████████████▍                         | 4698/7902 [05:12<03:35, 14.86it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  61%|██████████████████████████████████████▌                        | 4842/7902 [05:18<02:33, 19.90it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  63%|███████████████████████████████████████▉                       | 5010/7902 [05:26<03:34, 13.46it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  64%|████████████████████████████████████████▍                      | 5078/7902 [05:29<01:22, 34.11it/s]
# Unable to compute the rank with certainty (lower bound=1).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  64%|████████████████████████████████████████▌                      | 5083/7902 [05:30<03:15, 14.43it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  65%|████████████████████████████████████████▋                      | 5106/7902 [05:31<02:29, 18.71it/s]
# Unable to compute the rank with certainty (lower bound=1).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  65%|█████████████████████████████████████████                      | 5149/7902 [05:32<02:21, 19.52it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  66%|█████████████████████████████████████████▍                     | 5192/7902 [05:35<02:37, 17.20it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  66%|█████████████████████████████████████████▉                     | 5253/7902 [05:38<02:57, 14.96it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  67%|█████████████████████████████████████████▉                     | 5267/7902 [05:39<02:08, 20.45it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  70%|████████████████████████████████████████████                   | 5531/7902 [05:49<01:34, 25.18it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  70%|████████████████████████████████████████████                   | 5534/7902 [05:50<03:04, 12.85it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  70%|████████████████████████████████████████████▏                  | 5546/7902 [05:50<02:18, 16.95it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  72%|█████████████████████████████████████████████▎                 | 5688/7902 [05:56<01:59, 18.55it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  72%|█████████████████████████████████████████████▍                 | 5700/7902 [05:57<02:07, 17.22it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  72%|█████████████████████████████████████████████▍                 | 5705/7902 [05:57<02:22, 15.45it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  73%|██████████████████████████████████████████████▏                | 5786/7902 [06:00<01:42, 20.70it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  74%|██████████████████████████████████████████████▌                | 5839/7902 [06:02<01:09, 29.50it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  74%|██████████████████████████████████████████████▊                | 5874/7902 [06:04<01:56, 17.46it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  75%|███████████████████████████████████████████████▏               | 5920/7902 [06:07<02:03, 16.09it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  78%|████████████████████████████████████████████████▊              | 6128/7902 [06:15<01:22, 21.46it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  78%|█████████████████████████████████████████████████▎             | 6183/7902 [06:16<01:07, 25.57it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  78%|█████████████████████████████████████████████████▎             | 6191/7902 [06:18<02:27, 11.63it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  78%|█████████████████████████████████████████████████▍             | 6199/7902 [06:18<02:15, 12.58it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  79%|█████████████████████████████████████████████████▉             | 6262/7902 [06:21<01:11, 23.00it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  81%|██████████████████████████████████████████████████▊            | 6379/7902 [06:26<01:18, 19.34it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  81%|██████████████████████████████████████████████████▉            | 6382/7902 [06:27<01:57, 12.89it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  82%|███████████████████████████████████████████████████▋           | 6486/7902 [06:31<00:46, 30.28it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  82%|███████████████████████████████████████████████████▊           | 6500/7902 [06:31<01:08, 20.37it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  82%|███████████████████████████████████████████████████▉           | 6516/7902 [06:32<01:01, 22.66it/s]
# Unable to compute the rank with certainty (lower bound=1).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  83%|███████████████████████████████████████████████████▉           | 6520/7902 [06:33<01:23, 16.54it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  83%|████████████████████████████████████████████████████           | 6525/7902 [06:33<01:41, 13.57it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  83%|████████████████████████████████████████████████████▎          | 6569/7902 [06:35<00:50, 26.60it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  83%|████████████████████████████████████████████████████▍          | 6577/7902 [06:35<00:57, 22.95it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  84%|█████████████████████████████████████████████████████          | 6651/7902 [06:37<00:37, 33.00it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  85%|█████████████████████████████████████████████████████▎         | 6682/7902 [06:37<00:16, 73.30it/s]
# Unable to compute the rank with certainty (lower bound=1).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  85%|█████████████████████████████████████████████████████▋         | 6736/7902 [06:39<00:30, 37.74it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  85%|█████████████████████████████████████████████████████▋         | 6741/7902 [06:40<00:36, 32.05it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  88%|███████████████████████████████████████████████████████▌       | 6964/7902 [06:49<01:34,  9.91it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  89%|███████████████████████████████████████████████████████▊       | 7003/7902 [06:59<03:04,  4.87it/s]
# Unable to compute the rank with certainty (lower bound=1).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  89%|████████████████████████████████████████████████████████       | 7026/7902 [07:01<01:49,  8.02it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  89%|████████████████████████████████████████████████████████▏      | 7051/7902 [07:03<01:05, 12.98it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  89%|████████████████████████████████████████████████████████▎      | 7068/7902 [07:04<00:44, 18.67it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  90%|████████████████████████████████████████████████████████▍      | 7073/7902 [07:04<00:39, 20.79it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  90%|████████████████████████████████████████████████████████▍      | 7081/7902 [07:05<00:55, 14.67it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  90%|████████████████████████████████████████████████████████▌      | 7099/7902 [07:05<00:45, 17.52it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  90%|████████████████████████████████████████████████████████▋      | 7103/7902 [07:06<00:52, 15.29it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  90%|████████████████████████████████████████████████████████▉      | 7134/7902 [07:07<00:37, 20.66it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  91%|█████████████████████████████████████████████████████████▎     | 7191/7902 [07:09<00:30, 23.68it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  91%|█████████████████████████████████████████████████████████▍     | 7206/7902 [07:10<00:36, 19.12it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  92%|██████████████████████████████████████████████████████████▏    | 7296/7902 [07:14<00:29, 20.35it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  93%|██████████████████████████████████████████████████████████▊    | 7375/7902 [07:17<00:19, 27.59it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  93%|██████████████████████████████████████████████████████████▊    | 7379/7902 [07:17<00:21, 24.51it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  94%|███████████████████████████████████████████████████████████▏   | 7424/7902 [07:20<00:29, 16.17it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  94%|███████████████████████████████████████████████████████████▌   | 7465/7902 [07:22<00:20, 20.88it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  95%|███████████████████████████████████████████████████████████▋   | 7486/7902 [07:23<00:21, 19.34it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  95%|████████████████████████████████████████████████████████████   | 7537/7902 [07:25<00:16, 22.02it/s]
# Unable to compute the rank with certainty (lower bound=1).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  96%|████████████████████████████████████████████████████████████▋  | 7609/7902 [07:27<00:13, 21.61it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  98%|█████████████████████████████████████████████████████████████▉ | 7768/7902 [07:33<00:06, 21.91it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks:  99%|██████████████████████████████████████████████████████████████▎| 7809/7902 [07:35<00:05, 15.72it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks: 100%|██████████████████████████████████████████████████████████████▊| 7875/7902 [07:38<00:01, 24.49it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks: 100%|██████████████████████████████████████████████████████████████▊| 7882/7902 [07:38<00:00, 20.63it/s]
# Unable to compute the rank with certainty (lower bound=0).
# This could be because Sha(E/Q)[2] is nontrivial.
# Try calling something like two_descent(second_limit=13) on the
# curve then trying this command again.  You could also try rank
# with only_use_mwrank=False.
# Checking ranks: 100%|███████████████████████████████████████████████████████████████| 7902/7902 [07:39<00:00, 17.21it/s]

# %%
ranks
# Out:
# [1, 0, 2, 3]
