# %%
from sage.databases.cremona import CremonaDatabase # Database of elliptic curves over the rationals

# %%
db = CremonaDatabase()

# Extract elliptic curves with conductor in (7500, 10000) and rank 0 or 1
rank_zero_curves = []
rank_one_curves = []
for E in db.iter(range(7500, 10000)):
    if E.rank() == 0:
        rank_zero_curves.append(E)
    elif E.rank() == 1:
        rank_one_curves.append(E)

# %%
len(rank_zero_curves), len(rank_one_curves)
# Out:
# (7397, 8141)

# %%
# Extract representatives for different isogeny classes
rk0_isogeny_reps = []
rk0_isogeny_classes = []
rk1_isogeny_reps = []
rk1_isogeny_classes = []

for E in rank_zero_curves:
    if E.isogeny_class() not in rk0_isogeny_classes:
        rk0_isogeny_reps.append(E)
        rk0_isogeny_classes.append(E.isogeny_class())
for E in rank_one_curves:
    if E.isogeny_class() not in rk1_isogeny_classes:
        rk1_isogeny_reps.append(E)
        rk1_isogeny_classes.append(E.isogeny_class())

# %%
print(f"Number of distinct isogeny classes for conductor in [7500, 10000] and rank 0, 1: {len(rk0_isogeny_reps)}, {len(rk1_isogeny_reps)}")
# Out:
# Number of distinct isogeny classes for conductor in [7500, 10000] and rank 0, 1: 4328, 5194

# %%
# Import the list of primes
P = Primes()
P[0]
# Out:
# 2

# %%
import numpy as np

# %%
# Extract the average aps
N = 1000 # Number of primes I want to plot
rk0_eigenforms = [E.q_eigenform(P[N]) for E in rk0_isogeny_reps]
rk1_eigenforms = [E.q_eigenform(P[N]) for E in rk1_isogeny_reps]

rk0_aps = np.array([np.mean([ef[P[i]] for ef in rk0_eigenforms]) for i in range(N)])
rk1_aps = np.array([np.mean([ef[P[i]] for ef in rk1_eigenforms]) for i in range(N)])

# %%
save(rk0_aps, "rk0_aps")
save(rk1_aps, "rk1_aps")

# %%
rk0_aps = load("rk0_aps")
rk1_aps = load("rk1_aps")
N = 1000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(range(N), rk0_aps, label="Rank 0", alpha=0.6, s=10)
plt.scatter(range(N), rk1_aps, label="Rank 1", alpha=0.6, s=10)
plt.legend()
plt.xlabel(r"Prime index $i$")
plt.ylabel(r"Average $a_{p_i}$")
plt.title(r"Average $a_p$ vs prime index over conductors $c \in [7500, 10000]$")
plt.savefig(f"ap_averages_7500_10000.png", dpi=150)
plt.show()

# %%
# Import rational elliptic curves from Candelas' paper

rational_form_labels = [
    "108570.cs1",
    "8190.j1",
    "99484.d1",
    "294630.bg2",
    "244530.bh2",
    "15180.m2",
    "56826.h2",
    "136290.cl2",
    "30940.b2",
    "198.d1",
    "18270.h2",
    "215710.l2",
    "170940.t2",
    "6006.n2",
    "1260.j1",
    "460922.d2",
    "60060.bc1",
    "39270.cn2",
    "30690.bc2",
    "2310.l3",
    "1260.d2",
    "910.a2",
    "106590.bz2",
    "422730.bw2",
    "244530.c1",
    "210.d3",
    "220.a2",
    "2394.k2",
    "414414.ck1",
    "30.a3",
    "53130.cf2",
    "81774.r2",
    "2310.u3",
    "358666.b2",
    "2170.k2",
    "15708.g2",
    "23310.w2",
    "5742.t2",
    "376740.v2",
    "2310.t2",
    "140910.be2",
    "1170.h2",
    "214830.bt2",
    "6270.k2",
    "84.b2",
    "87890.g2",
    "13860.t2",
    "117810.x2",
    "197340.n2",
    "90.a2",
    "10010.n2",
    "115710.cr2",
    "488070.c2",
    "462.f2",
    "10710.bc2",
    "20.a2",
    "180180.q2",
    "6006.p2",
    "256410.bs2",
    "43010.a2",
    "7770.ba4",
    "159390.s3",
    "630.j2",
    "12870.cc3",
    "125580.s3",
    "6930.ba3",
    "66.a2",
    "770.g3",
    "381810.bn3",
    "3570.j3",
    "432630.dv3",
    "497420.g3",
    "237510.v3",
    "2310.i2",
    "94710.br3",
    "352590.cz4",
    "363660.n4",
    "383460.w4",
    "6510.j4",
    "770.f4",
    "432630.c4",
    "308154.bw4",
    "27846.bf4",
    "284130.de4",
    "180180.bx4",
    "390.g4",
    "396270.bu4",
    "50622.j4",
    "487410.bw4",
    "48070.f4",
    "420.c4",
    "11220.k4",
    "144970.p4",
    "630.c4",
    "159390.eo4",
    "28490.b4",
    "124542.bc4",
    "421260.ba4",
    "217140.p4",
    "14.a6",
    "455070.cy4",
    "453390.cs4",
    "16830.bl4",
    "180180.cb4",
    "11970.bo4",
    "22610.m4",
    "14190.n4",
    "71610.o4",
    "1218.h4",
    "94710.cv4",
    "81510.bi4",
    "660.c4",
    "90090.dn4",
    "1638.e4",
    "4004.a4",
    "14070.e4",
    "415380.m4",
    "90.b4",
    "261030.v4",
    "418110.bh4",
    "122430.ba4",
    "11130.n4",
    "158730.bz4",
    "2660.c4",
    "4026.i4",
    "13860.k4",
    "117810.w4",
    "990.e4",
    "25830.bi4",
    "2730.m6",
    "244970.c4",
    "39270.bf4",
    "310.a4",
    "47124.k4",
    "4620.j4",
    "1170.c4",
    "118910.a4",
    "1974.j4",
    "186846.f4",
    "39780.h4",
    "218196.g4",
    "264740.a4",
    "180642.o4",
    "2130.g4",
    "23940.j4",
    "8690.f4",
    "53130.ch4",
    "61110.c4",
    "18746.c4",
    "23310.bl4",
    "33390.ca4",
    "77154.k4",
    "200970.p4",
    "16830.bi4",
    "322490.i4",
    "142230.t4",
    "30030.bt4",
    "345730.n3",
    "3570.w4",
    "306306.cv3",
    "231570.a3",
    "93610.a3",
    "81774.bv3",
    "150612.j1",
    "3870.l3",
    "2310.l3",
    "6402.r3",
    "179676.g3",
    "9790.b3",
    "431340.bd1",
    "73260.n1",
    "70380.t3",
    "66990.bq3",
    "910.g5",
    "2310.h2",
    "284130.du1",
    "171930.r3",
    "2394.d3",
    "30316.b3",
    "21420.v1",
    "210.d3",
    "99246.m3",
    "72930.bw3",
    "33110.b1",
    "56826.h1",
    "43890.ct4",
    "44460.c1",
    "53130.ci3",
    "3108.g3",
    "41730.k3",
    "198.d3",
    "208810.b3",
    "20460.m1",
    "18270.h1",
    "4060.b3",
    "17430.bp3",
    "14630.o2",
    "189210.cm1",
    "422730.dc2",
    "23562.bc1",
    "30.a3",
    "123354.bu2",
    "2070.a1",
    "159324.h2",
    "7084.c1",
    "2010.j2",
    "483210.ci1",
    "302610.ch1",
    "69762.bg2",
    "186438.j2",
    "1260.j2",
    "384090.z1",
    "170170.c2",
    "21210.bd2",
    "2090.c1",
    "60606.z1",
    "162470.b2",
    "1140.d1",
    "4290.bb2",
    "30690.r2",
    "60060.bc2",
    "91770.x2",
    "411180.n2",
    "332990.l1",
    "125034.i2",
    "296010.dq1",
    "34.a2",
    "30690.bc1",
    "21252.i1",
    "159390.dr2",
    "413490.bg2",
    "139230.cv2",
    "210.b2",
    "60606.k2",
    "175890.bx2",
    "31020.k2",
    "193578.i2",
    "164780.a2",
    "5754.i2",
    "1260.d1",
    "21630.bb2",
    "173740.b2",
    "1914.n1",
    "1290.h2",
    "126882.bk1",
    "71610.bs2",
    "910.a1",
    "19140.f2",
    "2070.p2",
    "123354.m1",
    "118830.f2",
    "65436.j1",
    "2310.u3",
    "456940.b1",
    "247170.dj1",
    "23562.h2",
    "157430.n2",
    "422730.bw1",
    "127974.y2",
    "156.b2",
    "71910.x1",
    "441210.cn2",
    "244530.c2",
    "43890.bj1",
    "15290.f2",
    "103290.s2",
    "1610.b1",
    "18270.bz2",
    "37740.f1",
    "149226.bs2",
    "415074.p2",
    "4270.c2",
    "45780.t2",
    "61230.z2",
    "198.b1",
    "358530.i2",
    "220780.b2",
    "471546.h2",
    "24780.p1",
    "44462.g1",
    "210.d4",
    "332010.ec1",
    "124830.bd2",
    "4830.bf1",
    "117810.cz2"
]

# %%
len(rational_form_labels)
# Out:
# 285

# %%
# Extract Candelas' curves from LMFDB directly
curves = [EllipticCurve(label) for label in rational_form_labels]

# %%
save(curves, "Candelas_rational_curves")

# %%
curves = load("Candelas_rational_curves")

# %%
# Sort them by rank
ranks = []

for E in curves:
    if E.rank() not in ranks:
        ranks.append(E.rank())

# %%
ranks
# Out:
# [0, 1, 2]

# %%
rk0_curves = []
rk1_curves = []
rk2_curves = []

for E in curves:
    if E.rank() == 0:
        rk0_curves.append(E)
    elif E.rank() == 1:
        rk1_curves.append(E)
    else:
        rk2_curves.append(E)

# %%
print(f"Number of curves of rank 0, 1, 2: {len(rk0_curves)}, {len(rk1_curves)}, {len(rk2_curves)}")
# Out:
# Number of curves of rank 0, 1, 2: 144, 134, 7

# %%
def get_isogeny_class_representatives(cs):
    """Extract one representative from each isogeny class"""
    seen_classes = []
    representatives = []
    
    for i, E in enumerate(cs):
        iso_class = E.isogeny_class()
        if iso_class not in seen_classes:
            representatives.append(E)
            seen_classes.append(iso_class)
    
    return representatives

# %%
from sage.databases.cremona import CremonaDatabase # Database of elliptic curves over the rationals

# Apply to all three groups
print("Obtaining the isogeny class representatives for rank zero curves...")
rk0_isogeny_reps = get_isogeny_class_representatives(rk0_curves)
print("Done.")
print("Obtaining the isogeny class representatives for rank one curves...")
rk1_isogeny_reps = get_isogeny_class_representatives(rk1_curves)
print("Done.")
print("Obtaining the isogeny class representatives for rank two curves...")
rk2_isogeny_reps = get_isogeny_class_representatives(rk2_curves)
print("Done.")
# Out:
# Obtaining the isogeny class representatives for rank zero curves...
# Done.
# Obtaining the isogeny class representatives for rank one curves...
# Done.
# Obtaining the isogeny class representatives for rank two curves...
# Done.

# %%
import numpy as np
# Import the list of primes
P = Primes()

# %%
# Extract the average aps
N = 1000 # Number of primes I want to plot
rk0_eigenforms = [E.q_eigenform(P[N]) for E in rk0_isogeny_reps]
rk1_eigenforms = [E.q_eigenform(P[N]) for E in rk1_isogeny_reps]
rk2_eigenforms = [E.q_eigenform(P[N]) for E in rk2_isogeny_reps]

rk0_aps = np.array([np.mean([ef[P[i]] for ef in rk0_eigenforms]) for i in range(N)])
rk1_aps = np.array([np.mean([ef[P[i]] for ef in rk1_eigenforms]) for i in range(N)])
rk2_aps = np.array([np.mean([ef[P[i]] for ef in rk2_eigenforms]) for i in range(N)])

# %%
save(rk0_aps, "Candelas_rk0_aps")
save(rk1_aps, "Candelas_rk1_aps")
save(rk2_aps, "Candelas_rk2_aps")

# %%
rk0_aps = load("Candelas_rk0_aps")
rk1_aps = load("Candelas_rk1_aps")
rk2_aps = load("Candelas_rk2_aps")
N = 1000

# %%
import matplotlib.pyplot as plt

# %%
N = 1000
plt.scatter(range(N), rk0_aps[:N], label="Rank 0", alpha=0.6, s=10)
plt.scatter(range(N), rk1_aps[:N], label="Rank 1", alpha=0.6, s=10)
# plt.scatter(range(N), rk2_aps[:N], label="Rank 2", alpha=0.6, s=10)
plt.legend()
plt.xlabel(r"Prime index $i$")
plt.ylabel(r"Average $a_{p_i}$")
plt.title(r"Average $a_p$ vs prime index for Candelas' rational elliptic curves")
plt.savefig(f"Candelas_ap_averages_all_conductors.png", dpi=150)
plt.show()

# %%
db.isogeny_class("2254f")
# Out:
# [Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 - 687*x - 2059 over Rational Field,
#  Elliptic Curve defined by y^2 + x*y + y = x^3 + x^2 - 8527*x - 306251 over Rational Field]

# %%
from sage.databases.cremona import CremonaDatabase

# Create database instance
db = CremonaDatabase()

# Specify the isogeny class
conductor = 2254
isogeny_class = 'f'
class_label = f"{conductor}{isogeny_class}"

# Get all curves in the isogeny class
try:
    # You can use either notation: "2254f" or "2254f1" 
    curves = db.isogeny_class(class_label)
    
    print(f"Isogeny class: {class_label}")
    print(f"Number of curves in class: {len(curves)}")
    print("-" * 60)
    
    for i, E in enumerate(curves, 1):
        label = f"{class_label}{i}"
        print(f"\nCurve {label}:")
        print(f"  Weierstrass equation: y^2 = {E.a_invariants()}")
        print(f"  Conductor: {E.conductor()}")
        print(f"  Discriminant: {E.discriminant()}")
        print(f"  j-invariant: {E.j_invariant()}")
        print(f"  Rank: {E.rank()}")
        print(f"  Torsion: {E.torsion_order()}")
        
    # Alternatively, access individual curves by their full label
    print("\n" + "="*60)
    print("Accessing curves individually:")
    for i in range(1, len(curves) + 1):
        label = f"{class_label}{i}"
        E = db.elliptic_curve(label)
        print(f"{label}: {E.ainvs()}")
        
except RuntimeError as e:
    print(f"Error: Isogeny class {class_label} not found in database")
    print(f"The conductor {conductor} may not have an isogeny class '{isogeny_class}'")
# Out:
# Isogeny class: 2254f
# Number of curves in class: 2
# ------------------------------------------------------------
#
# Curve 2254f1:
#   Weierstrass equation: y^2 = (1, 1, 1, -687, -2059)
#   Conductor: 2254
#   Discriminant: 19396084736
#   j-invariant: 304821217/164864
#   Rank: 0
#   Torsion: 2
#
# Curve 2254f2:
#   Weierstrass equation: y^2 = (1, 1, 1, -8527, -306251)
#   Conductor: 2254
#   Discriminant: 97586551328
#   j-invariant: 582810602977/829472
#   Rank: 0
#   Torsion: 2
#
# ============================================================
# Accessing curves individually:
# 2254f1: (1, 1, 1, -687, -2059)
# 2254f2: (1, 1, 1, -8527, -306251)

# %%
EllipticCurve("2254f1").q_eigenform(100)[3]
# Out:
# 2

# %%
R.<x> = PolynomialRing(QQ);  K.<a> = NumberField(R([-2, 0, 1]))
E = EllipticCurve([K([1,1]),K([-1,1]),K([1,0]),K([-883,-934]),K([-22223,-13420])])
# Elliptic curves over rational extensions do not have q_eigenforms, how do I extract the ap's? Via the L-functions, if I understand how to get
# the associated labels

# %%
# Extract conductors
conductors = [E.conductor() for E in curves]

# Create histogram using Sage
from sage.plot.histogram import histogram
h = histogram(conductors, bins=60)
h.show()
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
min(conductors), max(conductors)
# This set is spread over all possible conductors!
# Out:
# (14, 497420)

# %%
import numpy as np

conductors = np.array(conductors)
len(np.nonzero((conductors > 7500)*(conductors < 10000))[0])
# Out:
# 4

# %%
conductors[np.nonzero((conductors > 7500)*(conductors < 10000))[0]]
# Out:
# array([8190, 7770, 8690, 9790])

# %%
len(np.nonzero((conductors > 1)*(conductors < 100000))[0])
# Out:
# 177

# %%
# Restrict plot to conductors < 100 000
rk0_isogeny_reps_restricted = [rk0_isogeny_reps[i] for i in np.nonzero(np.array([E.conductor() for E in rk0_isogeny_reps]) < 100000)[0]]
rk1_isogeny_reps_restricted = [rk1_isogeny_reps[i] for i in np.nonzero(np.array([E.conductor() for E in rk1_isogeny_reps]) < 100000)[0]]
rk2_isogeny_reps_restricted = [rk2_isogeny_reps[i] for i in np.nonzero(np.array([E.conductor() for E in rk2_isogeny_reps]) < 100000)[0]]

# %%
# Extract the average aps
N = 1000 # Number of primes I want to plot
rk0_eigenforms_restricted = [E.q_eigenform(P[N]) for E in rk0_isogeny_reps_restricted]
rk1_eigenforms_restricted = [E.q_eigenform(P[N]) for E in rk1_isogeny_reps_restricted]
rk2_eigenforms_restricted = [E.q_eigenform(P[N]) for E in rk2_isogeny_reps_restricted]

rk0_restricted_aps = np.array([np.mean([ef[P[i]] for ef in rk0_eigenforms_restricted]) for i in range(N)])
rk1_restricted_aps = np.array([np.mean([ef[P[i]] for ef in rk1_eigenforms_restricted]) for i in range(N)])
rk2_restricted_aps = np.array([np.mean([ef[P[i]] for ef in rk2_eigenforms_restricted]) for i in range(N)])

# %%
import matplotlib.pyplot as plt

N = 1000
plt.scatter(range(N), rk0_restricted_aps[:N], label="Rank 0", alpha=0.6, s=10)
plt.scatter(range(N), rk1_restricted_aps[:N], label="Rank 1", alpha=0.6, s=10)
# plt.scatter(range(N), rk2_aps[:N], label="Rank 2", alpha=0.6, s=10)
plt.legend()
plt.xlabel(r"Prime index $i$")
plt.ylabel(r"Average $a_{p_i}$")
plt.title(r"Average $a_p$ vs prime index for Candelas' curves, conductor < 100000")
plt.savefig(f"Candelas_ap_averages_0_100000.png", dpi=150)
plt.show()

# %%
# Parallelized

from sage.databases.cremona import CremonaDatabase
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from joblib import Parallel, delayed
import gc
import multiprocessing

# Get number of available cores
n_cores = multiprocessing.cpu_count()
print(f"Using {n_cores} CPU cores")

# Database of elliptic curves over the rationals
db = CremonaDatabase()

# Define conductor range
cmax = 100000
cmin = 1

# Extract elliptic curves with conductor in (cmin, cmax) and rank 0 or 1
print(f"Extracting curves in conductor range [{cmin}, {cmax}]...")
rank_zero_curves = []
rank_one_curves = []

for E in tqdm(db.iter(range(cmin, cmax)), desc="Loading curves"):
    if E.rank() == 0:
        rank_zero_curves.append(E)
    elif E.rank() == 1:
        rank_one_curves.append(E)

print(f"Found {len(rank_zero_curves)} rank 0 curves and {len(rank_one_curves)} rank 1 curves.")

# Extract representatives for different isogeny classes using LABELS
print("Extracting isogeny class representatives...")

def get_isogeny_label(E):
    """Extract isogeny class from Cremona label (e.g., '11a1' -> '11a')"""
    label = E.cremona_label()
    # Remove the final digit(s) to get isogeny class
    i = len(label) - 1
    while i >= 0 and label[i].isdigit():
        i -= 1
    return label[:i+1]

rk0_isogeny_reps = []
rk0_seen_labels = set()

for E in tqdm(rank_zero_curves, desc="Rank 0 isogeny classes"):
    iso_label = get_isogeny_label(E)
    if iso_label not in rk0_seen_labels:
        rk0_isogeny_reps.append(E)
        rk0_seen_labels.add(iso_label)

rk1_isogeny_reps = []
rk1_seen_labels = set()

for E in tqdm(rank_one_curves, desc="Rank 1 isogeny classes"):
    iso_label = get_isogeny_label(E)
    if iso_label not in rk1_seen_labels:
        rk1_isogeny_reps.append(E)
        rk1_seen_labels.add(iso_label)

print(f"Found {len(rk0_isogeny_reps)} rank 0 isogeny classes")
print(f"Found {len(rk1_isogeny_reps)} rank 1 isogeny classes")

# Use prime_range instead of Primes() to avoid PARI issues
N = 1000  # Number of primes to plot
print(f"Computing first {N} primes using prime_range...")
primes_list = list(primes_first_n(N))
print(f"Prime range: {primes_list[0]} to {primes_list[-1]}")

# Function to compute ap values for a single curve
def compute_ap_list_for_curve(E, primes):
    """Compute all ap values for a curve, return (label, ap_list) or (label, None) if failed"""
    try:
        label = E.cremona_label()
        ap_list = []
        for p in primes:
            ap = E.ap(p)
            ap_list.append(ap)
        return (label, ap_list)
    except:
        return (E.cremona_label(), None)

# Process curves in parallel
print("Computing rank 0 ap values in parallel...")
rk0_results = Parallel(n_jobs=n_cores, backend='multiprocessing')(
    delayed(compute_ap_list_for_curve)(E, primes_list)
    for E in tqdm(rk0_isogeny_reps, desc="Rank 0 curves")
)

# Process results
rk0_ap_matrix = []
rk0_valid_labels = []
rk0_skipped = []

for label, ap_list in rk0_results:
    if ap_list is not None:
        rk0_ap_matrix.append(ap_list)
        rk0_valid_labels.append(label)
    else:
        rk0_skipped.append(label)
        print(f"  Skipped: {label}")

print(f"Successfully computed ap for {len(rk0_valid_labels)}/{len(rk0_isogeny_reps)} rank 0 curves")

# Force garbage collection
gc.collect()

print("Computing rank 1 ap values in parallel...")
rk1_results = Parallel(n_jobs=n_cores, backend='multiprocessing')(
    delayed(compute_ap_list_for_curve)(E, primes_list)
    for E in tqdm(rk1_isogeny_reps, desc="Rank 1 curves")
)

# Process results
rk1_ap_matrix = []
rk1_valid_labels = []
rk1_skipped = []

for label, ap_list in rk1_results:
    if ap_list is not None:
        rk1_ap_matrix.append(ap_list)
        rk1_valid_labels.append(label)
    else:
        rk1_skipped.append(label)
        print(f"  Skipped: {label}")

print(f"Successfully computed ap for {len(rk1_valid_labels)}/{len(rk1_isogeny_reps)} rank 1 curves")

# Force garbage collection
gc.collect()

if len(rk0_ap_matrix) == 0 or len(rk1_ap_matrix) == 0:
    print("ERROR: Not enough ap values computed. Cannot proceed.")
else:
    # Convert to numpy arrays
    print("Converting to numpy arrays...")
    rk0_ap_matrix = np.array(rk0_ap_matrix, dtype=np.float64)
    rk1_ap_matrix = np.array(rk1_ap_matrix, dtype=np.float64)
    
    # Compute averages across curves for each prime
    print("Computing averages...")
    rk0_aps = np.mean(rk0_ap_matrix, axis=0)
    rk1_aps = np.mean(rk1_ap_matrix, axis=0)

    print("Saving aps...")
    save(rk0_aps, f"({cmin}, {cmax})_rk0_aps")
    save(rk1_aps, f"({cmin}, {cmax})_rk1_aps")
    save(rk0_valid_labels, f"({cmin}, {cmax})_rk0_labels")
    save(rk1_valid_labels, f"({cmin}, {cmax})_rk1_labels")
    print("Done.")

    print("Plotting...")
    plt.figure(figsize=(12, 6))
    plt.scatter(range(N), rk0_aps, label=f"Rank 0 (n={len(rk0_valid_labels)})", alpha=0.6, s=10)
    plt.scatter(range(N), rk1_aps, label=f"Rank 1 (n={len(rk1_valid_labels)})", alpha=0.6, s=10)
    plt.legend()
    plt.xlabel(r"Prime index $i$")
    plt.ylabel(r"Average $a_{p_i}$")
    plt.title(fr"Average $a_p$ vs prime index over conductors $c \in [{cmin}, {cmax}]$")
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(f"ap_averages_{cmin}_{cmax}.png", dpi=150)
    plt.show()

    print("\n=== Summary ===")
    rk0_pct = 100.0 * len(rk0_valid_labels) / len(rk0_isogeny_reps)
    rk1_pct = 100.0 * len(rk1_valid_labels) / len(rk1_isogeny_reps)
    print(f"Rank 0: {len(rk0_valid_labels)}/{len(rk0_isogeny_reps)} curves ({rk0_pct:.1f}%)")
    print(f"Rank 1: {len(rk1_valid_labels)}/{len(rk1_isogeny_reps)} curves ({rk1_pct:.1f}%)")
    print(f"Total skipped: {len(rk0_skipped) + len(rk1_skipped)}")
    
    if rk0_skipped or rk1_skipped:
        print(f"\nSkipped curves saved to files.")
        save(rk0_skipped, f"({cmin}, {cmax})_rk0_skipped")
        save(rk1_skipped, f"({cmin}, {cmax})_rk1_skipped")
# Out:
# Using 28 CPU cores
# Extracting curves in conductor range [1, 100000]...
# Loading curves: 657396it [23:09, 473.15it/s]
# Found 267565 rank 0 curves and 332314 rank 1 curves.
# Extracting isogeny class representatives...
# Rank 0 isogeny classes: 100%|███████████████████████████████████████████████| 267565/267565 [00:01<00:00, 256948.48it/s]
# Rank 1 isogeny classes: 100%|███████████████████████████████████████████████| 332314/332314 [00:01<00:00, 290117.73it/s]
# Found 168760 rank 0 isogeny classes
# Found 222439 rank 1 isogeny classes
# Computing first 1000 primes using prime_range...
# Prime range: 2 to 7919
# Computing rank 0 ap values in parallel...
# Rank 0 curves: 100%|███████████████████████████████████████████████████████████| 168760/168760 [15:41<00:00, 179.17it/s]
# Successfully computed ap for 168760/168760 rank 0 curves
# Computing rank 1 ap values in parallel...
# Rank 1 curves: 100%|███████████████████████████████████████████████████████████| 222439/222439 [21:19<00:00, 173.84it/s]
# Successfully computed ap for 222439/222439 rank 1 curves
# Converting to numpy arrays...
# Computing averages...
# Saving aps...
# Done.
# Plotting...
# === Summary ===
# Rank 0: 168760/168760 curves (100.0%)
# Rank 1: 222439/222439 curves (100.0%)
# Total skipped: 0

# %%
# Define conductor range
cmax = 100000
cmin = 1

rk0_valid_labels = load(f"({cmin}, {cmax})_rk0_labels")
rk1_valid_labels = load(f"({cmin}, {cmax})_rk1_labels")

# %%
import random

#Random sample 8000 curves from curves w/ conductor < 100000
sample_size = 8000

rk0_labels_sample = random.sample(rk0_valid_labels, sample_size)
rk1_labels_sample = random.sample(rk1_valid_labels, sample_size)

# %%
from tqdm import tqdm

rk0_curves_sample = []
rk1_curves_sample = []

for label in tqdm(rk0_labels_sample, desc = "Loading rk0 curves: "):
    rk0_curves_sample.append(EllipticCurve(label))
for label in tqdm(rk1_labels_sample, desc = "Loading rk1 curves: "):
    rk1_curves_sample.append(EllipticCurve(label))
# Out:
# Loading rk0 curves: 100%|██████████████████████████████████████████████████████████| 8000/8000 [00:10<00:00, 786.66it/s]
# Loading rk1 curves: 100%|██████████████████████████████████████████████████████████| 8000/8000 [00:10<00:00, 755.92it/s]

# %%
save(rk0_curves_sample, f"rk0_labels_{sample_size}_sample")
save(rk1_curves_sample, f"rk1_labels_{sample_size}_sample")

# %%
# Extract representatives for different isogeny classes using LABELS
print("Extracting isogeny class representatives...")

def get_isogeny_label(E):
    """Extract isogeny class from Cremona label (e.g., '11a1' -> '11a')"""
    label = E.cremona_label()
    # Remove the final digit(s) to get isogeny class
    i = len(label) - 1
    while i >= 0 and label[i].isdigit():
        i -= 1
    return label[:i+1]

rk0_isogeny_reps = []
rk0_seen_labels = set()

for E in tqdm(rk0_curves_sample, desc="Rank 0 isogeny classes"):
    iso_label = get_isogeny_label(E)
    if iso_label not in rk0_seen_labels:
        rk0_isogeny_reps.append(E)
        rk0_seen_labels.add(iso_label)

rk1_isogeny_reps = []
rk1_seen_labels = set()

for E in tqdm(rk1_curves_sample, desc="Rank 1 isogeny classes"):
    iso_label = get_isogeny_label(E)
    if iso_label not in rk1_seen_labels:
        rk1_isogeny_reps.append(E)
        rk1_seen_labels.add(iso_label)

print(f"Found {len(rk0_isogeny_reps)} rank 0 isogeny classes")
print(f"Found {len(rk1_isogeny_reps)} rank 1 isogeny classes")
# Out:
# Extracting isogeny class representatives...
# Rank 0 isogeny classes: 100%|███████████████████████████████████████████████████| 8000/8000 [00:00<00:00, 311612.48it/s]
# Rank 1 isogeny classes: 100%|███████████████████████████████████████████████████| 8000/8000 [00:00<00:00, 255748.29it/s]
# Found 8000 rank 0 isogeny classes
# Found 8000 rank 1 isogeny classes

# %%
from sage.databases.cremona import CremonaDatabase
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from joblib import Parallel, delayed
import gc
import multiprocessing

# Get number of available cores
n_cores = multiprocessing.cpu_count()
print(f"Using {n_cores} CPU cores")

# Database of elliptic curves over the rationals
db = CremonaDatabase()

# Use prime_range instead of Primes() to avoid PARI issues
N = 1000  # Number of primes to plot
print(f"Computing first {N} primes using prime_range...")
primes_list = list(primes_first_n(N))
print(f"Prime range: {primes_list[0]} to {primes_list[-1]}")

# Function to compute ap values for a single curve
def compute_ap_list_for_curve(E, primes):
    """Compute all ap values for a curve, return (label, ap_list) or (label, None) if failed"""
    try:
        label = E.cremona_label()
        ap_list = []
        for p in primes:
            ap = E.ap(p)
            ap_list.append(ap)
        return (label, ap_list)
    except:
        return (E.cremona_label(), None)

# Process curves in parallel
print("Computing rank 0 ap values in parallel...")
rk0_results = Parallel(n_jobs=n_cores, backend='multiprocessing')(
    delayed(compute_ap_list_for_curve)(E, primes_list)
    for E in tqdm(rk0_isogeny_reps, desc="Rank 0 curves")
)

# Process results
rk0_ap_matrix = []
rk0_valid_labels = []
rk0_skipped = []

for label, ap_list in rk0_results:
    if ap_list is not None:
        rk0_ap_matrix.append(ap_list)
        rk0_valid_labels.append(label)
    else:
        rk0_skipped.append(label)
        print(f"  Skipped: {label}")

print(f"Successfully computed ap for {len(rk0_valid_labels)}/{len(rk0_isogeny_reps)} rank 0 curves")

# Force garbage collection
gc.collect()

print("Computing rank 1 ap values in parallel...")
rk1_results = Parallel(n_jobs=n_cores, backend='multiprocessing')(
    delayed(compute_ap_list_for_curve)(E, primes_list)
    for E in tqdm(rk1_isogeny_reps, desc="Rank 1 curves")
)

# Process results
rk1_ap_matrix = []
rk1_valid_labels = []
rk1_skipped = []

for label, ap_list in rk1_results:
    if ap_list is not None:
        rk1_ap_matrix.append(ap_list)
        rk1_valid_labels.append(label)
    else:
        rk1_skipped.append(label)
        print(f"  Skipped: {label}")

print(f"Successfully computed ap for {len(rk1_valid_labels)}/{len(rk1_isogeny_reps)} rank 1 curves")

# Force garbage collection
gc.collect()

if len(rk0_ap_matrix) == 0 or len(rk1_ap_matrix) == 0:
    print("ERROR: Not enough ap values computed. Cannot proceed.")
else:

    print("Plotting...")
    plt.figure(figsize=(12, 6))
    plt.scatter(range(N), rk0_aps, label=f"Rank 0 (n={len(rk0_valid_labels)})", alpha=0.6, s=10)
    plt.scatter(range(N), rk1_aps, label=f"Rank 1 (n={len(rk1_valid_labels)})", alpha=0.6, s=10)
    plt.legend()
    plt.xlabel(r"Prime index $i$")
    plt.ylabel(r"Average $a_{p_i}$")
    plt.title(fr"Average $a_p$ vs prime index over conductors $c \in [{cmin}, {cmax}]$")
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(f"ap_averages_{cmin}_{cmax}_sample_{sample_size}.png", dpi=150)
    plt.show()

    print("\n=== Summary ===")
    rk0_pct = 100.0 * len(rk0_valid_labels) / len(rk0_isogeny_reps)
    rk1_pct = 100.0 * len(rk1_valid_labels) / len(rk1_isogeny_reps)
    print(f"Rank 0: {len(rk0_valid_labels)}/{len(rk0_isogeny_reps)} curves ({rk0_pct:.1f}%)")
    print(f"Rank 1: {len(rk1_valid_labels)}/{len(rk1_isogeny_reps)} curves ({rk1_pct:.1f}%)")
    print(f"Total skipped: {len(rk0_skipped) + len(rk1_skipped)}")
# Out:
# Using 28 CPU cores
# Computing first 1000 primes using prime_range...
# Prime range: 2 to 7919
# Computing rank 0 ap values in parallel...
# Rank 0 curves:   0%|                                                                 | 1/8000 [00:02<5:15:11,  2.36s/it]/projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# Rank 0 curves:   1%|▉                                                                | 112/8000 [00:02<02:09, 61.12it/s]/projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# /projects/ruehlehet/luigi/sage/src/sage/schemes/elliptic_curves/ell_rational_field.py:657: RuntimeWarning: cypari2 leaked 48 bytes on the PARI stack
#   mc, change = self.pari_curve().ellminimalmodel()
# Rank 0 curves: 100%|███████████████████████████████████████████████████████████████| 8000/8000 [00:11<00:00, 726.89it/s]
#   Skipped: 81024b1
#   Skipped: 62190x1
#   Skipped: 95830z1
#   Skipped: 75504ck1
#   Skipped: 37680j1
#   Skipped: 48906n1
#   Skipped: 31482l1
#   Skipped: 41382bw1
#   Skipped: 32072a1
#   Skipped: 36600c1
#   Skipped: 35910l1
#   Skipped: 38655a1
#   Skipped: 59850ey1
#   Skipped: 79200ba1
#   Skipped: 36846o1
#   Skipped: 75480h1
#   Skipped: 61467a1
#   Skipped: 77372a1
#   Skipped: 44880bb1
#   Skipped: 93136f1
#   Skipped: 15808i1
#   Skipped: 92976x1
#   Skipped: 52452b1
#   Skipped: 94080dp1
#   Skipped: 7920x1
#   Skipped: 6588b1
#   Skipped: 25551c1
#   Skipped: 68400bs1
#   Skipped: 65415k1
#   Skipped: 23920f1
#   Skipped: 41895bc1
#   Skipped: 69674a1
#   Skipped: 40768h1
#   Skipped: 4365h1
#   Skipped: 67270r1
#   Skipped: 29760bo1
#   Skipped: 42419a1
#   Skipped: 7990h1
#   Skipped: 96240bc1
#   Skipped: 528b1
#   Skipped: 15450l1
#   Skipped: 12168g1
#   Skipped: 4905a1
#   Skipped: 87906ba1
#   Skipped: 78350d1
#   Skipped: 65028a1
#   Skipped: 98298d1
#   Skipped: 17628e1
#   Skipped: 82560bh1
#   Skipped: 39837ba1
#   Skipped: 75344b1
#   Skipped: 5390bg1
#   Skipped: 5180e1
#   Skipped: 63054v1
#   Skipped: 18650b1
#   Skipped: 36099b1
#   Skipped: 65472q1
#   Skipped: 6912j1
#   Skipped: 61606a1
#   Skipped: 72666a1
#   Skipped: 37510b1
#   Skipped: 32725d1
#   Skipped: 81150u1
#   Skipped: 42959e1
#   Skipped: 99498t1
#   Skipped: 81432p1
#   Skipped: 58975a1
#   Skipped: 6336t1
#   Skipped: 21424v1
#   Skipped: 89460j1
#   Skipped: 31920q1
#   Skipped: 98490bi1
#   Skipped: 73168c1
#   Skipped: 70704f1
#   Skipped: 48825f1
#   Skipped: 49302l1
#   Skipped: 38318l1
#   Skipped: 79110e1
#   Skipped: 69216a1
#   Skipped: 94122x1
#   Skipped: 2368i1
#   Skipped: 77040bg1
#   Skipped: 23325f1
#   Skipped: 29700v1
#   Skipped: 24273e1
#   Skipped: 40014w1
#   Skipped: 47040t1
#   Skipped: 63504ct1
#   Skipped: 85977d1
#   Skipped: 34002c1
#   Skipped: 12720bc1
#   Skipped: 4592e1
#   Skipped: 42630a1
#   Skipped: 24384bn1
#   Skipped: 52395a1
#   Skipped: 7568n1
#   Skipped: 66240fs1
#   Skipped: 98800bn1
#   Skipped: 19276a1
#   Skipped: 56043b1
#   Skipped: 95760cf1
#   Skipped: 76302b1
#   Skipped: 71604f1
#   Skipped: 72768f1
#   Skipped: 47600bk1
#   Skipped: 49374k1
#   Skipped: 67088e1
#   Skipped: 64350ek1
#   Skipped: 77910bf1
#   Skipped: 85272d1
#   Skipped: 5550u1
#   Skipped: 97850a1
#   Skipped: 30450cg1
#   Skipped: 82576c1
#   Skipped: 24860e1
#   Skipped: 98564a1
#   Skipped: 45384a1
#   Skipped: 25850m1
#   Skipped: 60690f1
#   Skipped: 35668b1
#   Skipped: 77280bo1
#   Skipped: 16920k1
#   Skipped: 32550g1
#   Skipped: 73150o1
#   Skipped: 48832l1
#   Skipped: 3550f1
#   Skipped: 15696f1
#   Skipped: 92106bx1
#   Skipped: 95670f1
#   Skipped: 3168j1
#   Skipped: 20808m1
#   Skipped: 2358w1
#   Skipped: 28550b1
#   Skipped: 67545m1
#   Skipped: 48320bj1
#   Skipped: 33930bc1
#   Skipped: 39624g1
#   Skipped: 71226j1
#   Skipped: 91512c1
#   Skipped: 74790i1
#   Skipped: 61710bi1
#   Skipped: 32382c1
#   Skipped: 23760bd1
#   Skipped: 27825o1
#   Skipped: 19560o1
#   Skipped: 82650bq1
#   Skipped: 36738a1
#   Skipped: 37392a1
#   Skipped: 20350be1
#   Skipped: 80043a1
#   Skipped: 92752a1
#   Skipped: 49728l1
#   Skipped: 39494o1
#   Skipped: 89768l1
#   Skipped: 62424n1
#   Skipped: 53640d1
#   Skipped: 30144x1
#   Skipped: 25970s1
#   Skipped: 42826f1
#   Skipped: 75240bj1
#   Skipped: 55616bf1
#   Skipped: 51291b1
#   Skipped: 10560be1
#   Skipped: 69615o1
#   Skipped: 9126y1
#   Skipped: 85025g1
#   Skipped: 46800bo1
#   Skipped: 50094bu1
#   Skipped: 22128g1
#   Skipped: 41088f1
#   Skipped: 67850m1
#   Skipped: 56115l1
#   Skipped: 32756a1
#   Skipped: 8330v1
#   Skipped: 97096a1
#   Skipped: 89730h1
#   Skipped: 97776m1
#   Skipped: 6072h1
#   Skipped: 35280ey1
#   Skipped: 71568bb1
#   Skipped: 66166c1
#   Skipped: 68840a1
#   Skipped: 11466ca1
#   Skipped: 33660g1
#   Skipped: 92202z1
#   Skipped: 83248bi1
#   Skipped: 26550by1
#   Skipped: 17640l1
#   Skipped: 99879f1
#   Skipped: 93810d1
#   Skipped: 34368o1
#   Skipped: 1183b1
#   Skipped: 33350k1
#   Skipped: 55104cq1
#   Skipped: 19925b1
#   Skipped: 57176b1
#   Skipped: 93618c1
#   Skipped: 94864dd1
#   Skipped: 94864cb1
#   Skipped: 40290f1
#   Skipped: 40986q1
#   Skipped: 33950q1
#   Skipped: 19850e1
#   Skipped: 38304h1
#   Skipped: 10850i1
#   Skipped: 6256b1
#   Skipped: 76437b1
#   Skipped: 12464c1
#   Skipped: 68740f1
#   Skipped: 36050u1
#   Skipped: 83520dz1
#   Skipped: 22080bv1
#   Skipped: 23595k1
#   Skipped: 71664c1
#   Skipped: 53140a1
#   Skipped: 72558g1
#   Skipped: 12502e1
#   Skipped: 47726m1
#   Skipped: 60204e1
#   Skipped: 65184a1
#   Skipped: 1260h1
#   Skipped: 87120dy1
#   Skipped: 49257e1
#   Skipped: 14610a1
#   Skipped: 22386t1
#   Skipped: 9048d1
#   Skipped: 54464i1
#   Skipped: 80150h1
#   Skipped: 60736e1
#   Skipped: 96552c1
#   Skipped: 9918e1
#   Skipped: 48472c1
#   Skipped: 85410t1
#   Skipped: 43248v1
#   Skipped: 93600df1
#   Skipped: 99056a1
#   Skipped: 71400cf1
#   Skipped: 68382z1
#   Skipped: 68880cv1
#   Skipped: 73596a1
#   Skipped: 59675h1
#   Skipped: 53454r1
#   Skipped: 23310bf1
#   Skipped: 66440g1
#   Skipped: 48944x1
#   Skipped: 51696t1
#   Skipped: 29988bg1
#   Skipped: 46930f1
#   Skipped: 40550l1
#   Skipped: 87390f1
#   Skipped: 63168y1
#   Skipped: 83328br1
#   Skipped: 27968bl1
#   Skipped: 61838i1
#   Skipped: 11890a1
#   Skipped: 14110j1
#   Skipped: 74337a1
#   Skipped: 87584b1
#   Skipped: 16960j1
#   Skipped: 17350d1
#   Skipped: 77665c1
#   Skipped: 11638d1
#   Skipped: 73678b1
#   Skipped: 96016d1
#   Skipped: 28236b1
#   Skipped: 48616a1
#   Skipped: 82800el1
#   Skipped: 93840bd1
#   Skipped: 96815a1
#   Skipped: 35392f1
#   Skipped: 41612a1
#   Skipped: 34920h1
#   Skipped: 51408ck1
#   Skipped: 47742h1
#   Skipped: 89040cg1
#   Skipped: 36960g1
#   Skipped: 1176b1
#   Skipped: 37440l1
#   Skipped: 62190z1
#   Skipped: 16128f1
#   Skipped: 76112d1
#   Skipped: 63544b1
#   Skipped: 11466a1
#   Skipped: 88200eb1
#   Skipped: 65646n1
#   Skipped: 32170c1
#   Skipped: 2604e1
#   Skipped: 30510g1
#   Skipped: 89984k1
#   Skipped: 78643b1
#   Skipped: 13248f1
#   Skipped: 34840i1
#   Skipped: 89406n1
#   Skipped: 21840ba1
#   Skipped: 20646e1
#   Skipped: 84804a1
#   Skipped: 77504t1
#   Skipped: 16264c1
#   Skipped: 3888h1
#   Skipped: 67450f1
#   Skipped: 5239b1
#   Skipped: 47168b1
#   Skipped: 38870bm1
#   Skipped: 23712j1
#   Skipped: 84555b1
#   Skipped: 61785e1
#   Skipped: 11376f1
#   Skipped: 56640cy1
#   Skipped: 2688d1
#   Skipped: 46671c1
#   Skipped: 60864c1
#   Skipped: 19824m1
#   Skipped: 74880y1
#   Skipped: 77938b1
#   Skipped: 39039m1
#   Skipped: 90864f1
#   Skipped: 22350bb1
#   Skipped: 8289f1
#   Skipped: 75078k1
#   Skipped: 95182a1
#   Skipped: 18615c1
#   Skipped: 47158a1
#   Skipped: 7038i1
#   Skipped: 54027c1
#   Skipped: 66878a1
#   Skipped: 54556a1
#   Skipped: 7176h1
#   Skipped: 26675d1
#   Skipped: 21525e1
#   Skipped: 10710k1
#   Skipped: 57816f1
#   Skipped: 92682d1
#   Skipped: 9434b1
#   Skipped: 11920c1
#   Skipped: 70872d1
#   Skipped: 31662c1
#   Skipped: 18316a1
#   Skipped: 94112c1
#   Skipped: 53595i1
#   Skipped: 71638k1
#   Skipped: 3690d1
#   Skipped: 35964f1
#   Skipped: 63756p1
#   Skipped: 10712d1
#   Skipped: 67014r1
#   Skipped: 46650z1
#   Skipped: 15264d1
#   Skipped: 67680w1
#   Skipped: 45660a1
#   Skipped: 11781g1
#   Skipped: 19220c1
#   Skipped: 22560i1
#   Skipped: 51600bi1
#   Skipped: 49176d1
#   Skipped: 17771b1
#   Skipped: 30400i1
#   Skipped: 55556a1
#   Skipped: 5640a1
#   Skipped: 490h1
#   Skipped: 87600cl1
#   Skipped: 1140c1
#   Skipped: 11200o1
#   Skipped: 68400dg1
#   Skipped: 42559a1
#   Skipped: 21942h1
#   Skipped: 72550l1
#   Skipped: 54360g1
#   Skipped: 32825c1
#   Skipped: 60450bs1
#   Skipped: 74205p1
#   Skipped: 72048d1
#   Skipped: 30016l1
#   Skipped: 61056t1
#   Skipped: 41067q1
#   Skipped: 49100b1
#   Skipped: 21312cb1
#   Skipped: 15582d1
#   Skipped: 91035bp1
#   Skipped: 35280fc1
#   Skipped: 5355n1
#   Skipped: 47376u1
#   Skipped: 11466j1
#   Skipped: 9990t1
#   Skipped: 84825j1
#   Skipped: 38646i1
#   Skipped: 91872d1
#   Skipped: 63168o1
#   Skipped: 89208s1
#   Skipped: 13878d1
#   Skipped: 62205p1
#   Skipped: 720j1
#   Skipped: 98120b1
#   Skipped: 4650bs1
#   Skipped: 35640f1
#   Skipped: 63840i1
#   Skipped: 93786y1
#   Skipped: 66690bt1
#   Skipped: 89958u1
#   Skipped: 69720u1
#   Skipped: 67032ce1
#   Skipped: 61760a1
#   Skipped: 17370l1
#   Skipped: 44352e1
#   Skipped: 36285c1
#   Skipped: 24310u1
#   Skipped: 42900bb1
#   Skipped: 96075bl1
#   Skipped: 88330ba1
#   Skipped: 30282bt1
#   Skipped: 85456s1
#   Skipped: 20046d1
#   Skipped: 58203a1
#   Skipped: 74175f1
#   Skipped: 50274by1
#   Skipped: 39234f1
#   Skipped: 2725c1
#   Skipped: 21408b1
#   Skipped: 99568k1
#   Skipped: 52440s1
#   Skipped: 86583p1
#   Skipped: 85802d1
#   Skipped: 84864bc1
#   Skipped: 53130bs1
#   Skipped: 11616f1
#   Skipped: 3332b1
#   Skipped: 94050ch1
#   Skipped: 3264o1
#   Skipped: 11520e1
#   Skipped: 86427c1
#   Skipped: 29888l1
#   Skipped: 48592b1
#   Skipped: 32162a1
#   Skipped: 64638bk1
#   Skipped: 55075b1
#   Skipped: 29322d1
#   Skipped: 12924e1
#   Skipped: 21854k1
#   Skipped: 24492b1
#   Skipped: 12950r1
#   Skipped: 68050g1
#   Skipped: 92010a1
#   Skipped: 33440d1
#   Skipped: 56840k1
#   Skipped: 26226x1
#   Skipped: 68244f1
#   Skipped: 13268a1
#   Skipped: 64175f1
#   Skipped: 37310i1
#   Skipped: 55112a1
#   Skipped: 76122k1
#   Skipped: 88128be1
#   Skipped: 3222a1
#   Skipped: 15858a1
#   Skipped: 52688d1
#   Skipped: 9450by1
#   Skipped: 36432bt1
#   Skipped: 35136j1
#   Skipped: 36190e1
#   Skipped: 23416a1
#   Skipped: 52800bb1
#   Skipped: 5520ba1
#   Skipped: 69450x1
#   Skipped: 48300g1
#   Skipped: 99888g1
#   Skipped: 52591d1
#   Skipped: 44240u1
#   Skipped: 85162b1
#   Skipped: 59584v1
#   Skipped: 95220f1
#   Skipped: 32186u1
#   Skipped: 26394a1
#   Skipped: 33240k1
#   Skipped: 6230b1
#   Skipped: 58905bp1
#   Skipped: 66066ci1
#   Skipped: 62466i1
#   Skipped: 27716b1
#   Skipped: 21168dj1
#   Skipped: 12274j1
#   Skipped: 28054e1
#   Skipped: 84672bs1
#   Skipped: 67200v1
#   Skipped: 60680j1
#   Skipped: 52650bq1
#   Skipped: 50400v1
#   Skipped: 45360x1
#   Skipped: 39306a1
#   Skipped: 51792o1
#   Skipped: 7130a1
#   Skipped: 81054l1
#   Skipped: 28050cr1
#   Skipped: 60867a1
#   Skipped: 13878c1
#   Skipped: 88920bc1
#   Skipped: 83700bc1
#   Skipped: 76893f1
#   Skipped: 64764l1
#   Skipped: 89280em1
#   Skipped: 54600bu1
#   Skipped: 92688m1
#   Skipped: 49539e1
#   Skipped: 80960v1
#   Skipped: 90024n1
#   Skipped: 23800k1
#   Skipped: 90816bm1
#   Skipped: 81666s1
#   Skipped: 54525a1
#   Skipped: 14868b1
#   Skipped: 2100q1
#   Skipped: 64800bg1
#   Skipped: 95616bj1
#   Skipped: 90300bm1
#   Skipped: 20800bj1
#   Skipped: 48320by1
#   Skipped: 59730e1
#   Skipped: 19570g1
#   Skipped: 15790a1
#   Skipped: 6666h1
#   Skipped: 69174d1
#   Skipped: 24318k1
#   Skipped: 36630bu1
#   Skipped: 37652a1
#   Skipped: 33602b1
#   Skipped: 66525d1
#   Skipped: 48972l1
#   Skipped: 30509a1
#   Skipped: 72216n1
#   Skipped: 12770a1
#   Skipped: 85134f1
#   Skipped: 1834c1
#   Skipped: 13110z1
#   Skipped: 15376g1
#   Skipped: 32848a1
#   Skipped: 88675c1
#   Skipped: 44880cz1
#   Skipped: 75504br1
#   Skipped: 36504q1
#   Skipped: 47291a1
#   Skipped: 97968a1
#   Skipped: 8208j1
#   Skipped: 3012d1
#   Skipped: 86904h1
#   Skipped: 5915e1
#   Skipped: 21735f1
#   Skipped: 97227d1
#   Skipped: 83136o1
#   Skipped: 6171g1
#   Skipped: 81466h1
#   Skipped: 29944a1
#   Skipped: 37779h1
#   Skipped: 5900a1
#   Skipped: 30150cm1
#   Skipped: 45968w1
#   Skipped: 16020e1
#   Skipped: 94890f1
#   Skipped: 81420a1
#   Skipped: 44958a1
#   Skipped: 19599b1
#   Skipped: 45792g1
#   Skipped: 1564a1
#   Skipped: 68208bw1
#   Skipped: 55025d1
#   Skipped: 15288be1
#   Skipped: 29175t1
#   Skipped: 21448a1
#   Skipped: 75411i1
#   Skipped: 76608bn1
#   Skipped: 13475t1
#   Skipped: 10192c1
#   Skipped: 86592dd1
#   Skipped: 49888d1
#   Skipped: 38448r1
#   Skipped: 50970g1
#   Skipped: 71200l1
#   Skipped: 85995ci1
#   Skipped: 52425f1
#   Skipped: 84672kn1
#   Skipped: 93216c1
#   Skipped: 18430h1
#   Skipped: 65142d1
#   Skipped: 81738f1
#   Skipped: 27846bn1
#   Skipped: 16830n1
#   Skipped: 50490bb1
#   Skipped: 99990i1
#   Skipped: 8736k1
#   Skipped: 42400n1
#   Skipped: 69978l1
#   Skipped: 3402c1
#   Skipped: 7040e1
#   Skipped: 34224bk1
#   Skipped: 55440df1
#   Skipped: 57312c1
#   Skipped: 44352i1
#   Skipped: 90990e1
#   Skipped: 21440g1
#   Skipped: 34398b1
#   Skipped: 69040e1
#   Skipped: 22680m1
#   Skipped: 73734h1
#   Skipped: 97200et1
#   Skipped: 82614c1
#   Skipped: 20832m1
#   Skipped: 43197n1
#   Skipped: 56940d1
#   Skipped: 79920cn1
#   Skipped: 14400en1
#   Skipped: 95920b1
#   Skipped: 94400ba1
#   Skipped: 90576j1
#   Skipped: 48240ba1
#   Skipped: 31605k1
#   Skipped: 63138b1
#   Skipped: 11232b1
#   Skipped: 37683e1
#   Skipped: 5400bg1
#   Skipped: 76494j1
#   Skipped: 13230l1
#   Skipped: 49300a1
#   Skipped: 1080d1
#   Skipped: 13770bn1
#   Skipped: 50274bz1
#   Skipped: 9606d1
#   Skipped: 79118d1
#   Skipped: 26666a1
#   Skipped: 48180a1
#   Skipped: 64350ej1
#   Skipped: 79665c1
#   Skipped: 59325e1
#   Skipped: 65760c1
#   Skipped: 4347b1
#   Skipped: 17934n1
#   Skipped: 89870e1
#   Skipped: 34326a1
#   Skipped: 90090du1
#   Skipped: 66306a1
#   Skipped: 40392h1
#   Skipped: 83790dn1
#   Skipped: 97104a1
#   Skipped: 41832k1
#   Skipped: 51472a1
#   Skipped: 62400bk1
#   Skipped: 80654d1
#   Skipped: 7350cu1
#   Skipped: 35032a1
#   Skipped: 6090x1
#   Skipped: 62424l1
#   Skipped: 8700e1
#   Skipped: 76224j1
#   Skipped: 3760q1
#   Skipped: 11340k1
#   Skipped: 8400bg1
#   Skipped: 92928a1
#   Skipped: 45795c1
#   Skipped: 65392e1
#   Skipped: 57960bo1
#   Skipped: 57600y1
#   Skipped: 22352a1
#   Skipped: 20925p1
#   Skipped: 93360bl1
#   Skipped: 81122a1
#   Skipped: 29744bh1
#   Skipped: 6992i1
#   Skipped: 55728p1
#   Skipped: 71568r1
#   Skipped: 5835j1
#   Skipped: 11968d1
#   Skipped: 28260l1
#   Skipped: 64878o1
#   Skipped: 41040t1
#   Skipped: 12144bf1
#   Skipped: 13283c1
#   Skipped: 69760be1
#   Skipped: 81701a1
#   Skipped: 50878b1
#   Skipped: 47520bc1
#   Skipped: 43059c1
#   Skipped: 94605c1
#   Skipped: 46434a1
#   Skipped: 34210a1
#   Skipped: 58140e1
#   Skipped: 64350x1
#   Skipped: 94950bx1
#   Skipped: 17200t1
#   Skipped: 84525cv1
#   Skipped: 42960x1
#   Skipped: 20745d1
#   Skipped: 71050bi1
#   Skipped: 28730j1
#   Skipped: 59400bp1
#   Skipped: 19152o1
#   Skipped: 11505f1
#   Skipped: 38672c1
#   Skipped: 70840i1
#   Skipped: 11115h1
#   Skipped: 34496j1
#   Skipped: 14784bp1
#   Skipped: 16928a1
#   Skipped: 79712d1
#   Skipped: 32208l1
#   Skipped: 54012i1
#   Skipped: 24450h1
#   Skipped: 30290a1
#   Skipped: 9240l1
#   Skipped: 84336bi1
#   Skipped: 13320a1
#   Skipped: 17595b1
#   Skipped: 26826d1
#   Skipped: 11022r1
#   Skipped: 74139b1
#   Skipped: 18816w1
#   Skipped: 25935a1
#   Skipped: 42476e1
#   Skipped: 33054j1
#   Skipped: 61362b1
#   Skipped: 28435a1
#   Skipped: 31117e1
#   Skipped: 83772b1
#   Skipped: 95420d1
#   Skipped: 1085f1
#   Skipped: 94080du1
#   Skipped: 53560d1
#   Skipped: 73791b1
#   Skipped: 93345f1
#   Skipped: 82654l1
#   Skipped: 34225j1
#   Skipped: 97200cb1
#   Skipped: 36288bq1
#   Skipped: 24960e1
#   Skipped: 83376c1
#   Skipped: 99372bs1
#   Skipped: 6300v1
#   Skipped: 97175g1
#   Skipped: 84656h1
#   Skipped: 80550bh1
#   Skipped: 79247a1
#   Skipped: 80586k1
#   Skipped: 95984d1
#   Skipped: 32418k1
#   Skipped: 76770bc1
#   Skipped: 76680l1
#   Skipped: 19494p1
#   Skipped: 64782d1
#   Skipped: 55668a1
#   Skipped: 2340f1
#   Skipped: 8778o1
#   Skipped: 22542c1
#   Skipped: 66234f1
#   Skipped: 4032j1
#   Skipped: 46449d1
#   Skipped: 96150e1
#   Skipped: 81432k1
#   Skipped: 80982l1
#   Skipped: 35334c1
#   Skipped: 23300d1
#   Skipped: 67392z1
#   Skipped: 87725bb1
#   Skipped: 34496cd1
#   Skipped: 14775c1
#   Skipped: 24682c1
#   Skipped: 25344s1
#   Skipped: 7344q1
#   Skipped: 28405d1
#   Skipped: 29376eq1
#   Skipped: 93648y1
#   Skipped: 84416f1
#   Skipped: 63118k1
#   Skipped: 81378o1
#   Skipped: 8064t1
#   Skipped: 64752g1
#   Skipped: 79920bx1
#   Skipped: 74370f1
#   Skipped: 10227b1
#   Skipped: 55512c1
#   Skipped: 10800dq1
#   Skipped: 20300o1
#   Skipped: 44400da1
#   Skipped: 92736eo1
#   Skipped: 12234a1
#   Skipped: 98735b1
#   Skipped: 75390k1
#   Skipped: 46158bl1
#   Skipped: 78345b1
#   Skipped: 13950bs1
#   Skipped: 55152h1
#   Skipped: 54384a1
#   Skipped: 33680a1
#   Skipped: 71980b1
#   Skipped: 35392g1
#   Skipped: 4876b1
#   Skipped: 99720bd1
#   Skipped: 60016b1
#   Skipped: 9646c1
#   Skipped: 27318h1
#   Skipped: 11984i1
#   Skipped: 64590f1
#   Skipped: 6238b1
#   Skipped: 56420b1
#   Skipped: 13200ci1
#   Skipped: 486c1
#   Skipped: 49800g1
#   Skipped: 9225o1
#   Skipped: 56400bj1
#   Skipped: 15054c1
#   Skipped: 96872a1
#   Skipped: 90003b1
#   Skipped: 59058a1
#   Skipped: 44992r1
#   Skipped: 87204q1
#   Skipped: 64144a1
#   Skipped: 38130q1
#   Skipped: 80444g1
#   Skipped: 80730cc1
#   Skipped: 70618h1
#   Skipped: 60480bw1
#   Skipped: 32160f1
#   Skipped: 82950cm1
#   Skipped: 95590q1
#   Skipped: 36897i1
#   Skipped: 5810d1
#   Skipped: 17346j1
#   Skipped: 39446k1
#   Skipped: 72842g1
#   Skipped: 68712f1
#   Skipped: 65560h1
#   Skipped: 92760m1
#   Skipped: 45735d1
#   Skipped: 32227b1
#   Skipped: 62552a1
#   Skipped: 38304v1
#   Skipped: 66154b1
#   Skipped: 60696k1
#   Skipped: 88920k1
#   Skipped: 14760q1
#   Skipped: 12864i1
#   Skipped: 37245h1
#   Skipped: 18700b1
#   Skipped: 81242a1
#   Skipped: 1518d1
#   Skipped: 99654b1
#   Skipped: 10456a1
#   Skipped: 98368f1
#   Skipped: 47322b1
#   Skipped: 63222b1
#   Skipped: 35574bn1
#   Skipped: 55600f1
#   Skipped: 65736d1
#   Skipped: 14619a1
#   Skipped: 23622p1
#   Skipped: 90622b1
#   Skipped: 20544bj1
#   Skipped: 31311h1
#   Skipped: 29376bo1
#   Skipped: 27027i1
#   Skipped: 67146f1
#   Skipped: 55104cp1
#   Skipped: 34496di1
#   Skipped: 50526b1
#   Skipped: 24822bb1
#   Skipped: 2205l1
#   Skipped: 18150bq1
#   Skipped: 80528b1
#   Skipped: 6960m1
#   Skipped: 39360cb1
#   Skipped: 17232p1
#   Skipped: 75840cl1
#   Skipped: 97488e1
#   Skipped: 72406d1
#   Skipped: 71181d1
#   Skipped: 80960cc1
#   Skipped: 23775p1
#   Skipped: 12012i1
#   Skipped: 2730c1
#   Skipped: 88347a1
#   Skipped: 14040g1
#   Skipped: 93968e1
#   Skipped: 44352cj1
#   Skipped: 41640c1
#   Skipped: 62640br1
#   Skipped: 75920c1
#   Skipped: 77600z1
#   Skipped: 35200ba1
#   Skipped: 56628i1
#   Skipped: 2932b1
#   Skipped: 69312bf1
#   Skipped: 38115i1
#   Skipped: 35136l1
#   Skipped: 88445bv1
#   Skipped: 48384p1
#   Skipped: 81934a1
#   Skipped: 65954g1
#   Skipped: 94227c1
#   Skipped: 74340e1
#   Skipped: 39132a1
#   Skipped: 53998g1
#   Skipped: 96126b1
#   Skipped: 44082k1
#   Skipped: 63315b1
#   Skipped: 84336d1
#   Skipped: 61947a1
#   Skipped: 73032c1
#   Skipped: 15129b1
#   Skipped: 49686dh1
#   Skipped: 62244b1
#   Skipped: 39576g1
#   Skipped: 36921d1
#   Skipped: 14544a1
#   Skipped: 79755d1
#   Skipped: 33321a1
#   Skipped: 27898g1
#   Skipped: 70686bf1
#   Skipped: 20969c1
#   Skipped: 11908a1
#   Skipped: 75670m1
#   Skipped: 39070b1
#   Skipped: 48719a1
#   Skipped: 82830s1
#   Skipped: 70950c1
#   Skipped: 56088d1
#   Skipped: 50562f1
#   Skipped: 85425f1
#   Skipped: 79424d1
#   Skipped: 81904c1
#   Skipped: 22264h1
#   Skipped: 45968d1
#   Skipped: 81600bl1
#   Skipped: 44310ba1
#   Skipped: 15300t1
#   Skipped: 54736e1
#   Skipped: 92700f1
#   Skipped: 85668h1
#   Skipped: 34133b1
#   Skipped: 83666b1
#   Skipped: 98670bn1
#   Skipped: 90504c1
#   Skipped: 60738c1
#   Skipped: 16096b1
#   Skipped: 79968bw1
#   Skipped: 5760l1
#   Skipped: 40768bd1
#   Skipped: 24480s1
#   Skipped: 14278a1
#   Skipped: 77044d1
#   Skipped: 61985c1
#   Skipped: 27864d1
#   Skipped: 23360o1
#   Skipped: 48320ca1
#   Skipped: 11547e1
#   Skipped: 76850d1
#   Skipped: 85890a1
#   Skipped: 79387b1
#   Skipped: 57558g1
#   Skipped: 85833j1
#   Skipped: 74272e1
#   Skipped: 49600r1
#   Skipped: 37392q1
#   Skipped: 24759d1
#   Skipped: 58656d1
#   Skipped: 15533d1
#   Skipped: 5598e1
#   Skipped: 54864o1
#   Skipped: 65702x1
#   Skipped: 81060f1
#   Skipped: 75622b1
#   Skipped: 67032ck1
#   Skipped: 58563d1
#   Skipped: 29792m1
#   Skipped: 21294cn1
#   Skipped: 65816a1
#   Skipped: 42816d1
#   Skipped: 33584b1
#   Skipped: 31248bz1
#   Skipped: 14896x1
#   Skipped: 78960f1
#   Skipped: 42780h1
#   Skipped: 52598d1
#   Skipped: 75650l1
#   Skipped: 47082t1
#   Skipped: 58120b1
#   Skipped: 82126c1
#   Skipped: 15648c1
#   Skipped: 25920cl1
#   Skipped: 33300p1
#   Skipped: 57086a1
#   Skipped: 41685b1
#   Skipped: 43170b1
#   Skipped: 44790q1
#   Skipped: 85932bf1
#   Skipped: 10560p1
#   Skipped: 4733a1
#   Skipped: 33369a1
#   Skipped: 26670y1
#   Skipped: 78120a1
#   Skipped: 2450u1
#   Skipped: 78873c1
#   Skipped: 9901a1
#   Skipped: 46550cy1
#   Skipped: 49422a1
#   Skipped: 65464o1
#   Skipped: 2822b1
#   Skipped: 97344gk1
#   Skipped: 98532b1
#   Skipped: 11850r1
#   Skipped: 81344f1
#   Skipped: 88176y1
#   Skipped: 17040w1
#   Skipped: 26670n1
#   Skipped: 92073b1
#   Skipped: 15696v1
#   Skipped: 80856d1
#   Skipped: 56749a1
#   Skipped: 89683a1
#   Skipped: 84798bg1
#   Skipped: 69531k1
#   Skipped: 77040f1
#   Skipped: 38415f1
#   Skipped: 51045c1
#   Skipped: 93730j1
#   Skipped: 48576do1
#   Skipped: 66240bb1
#   Skipped: 44198bb1
#   Skipped: 32720b1
#   Skipped: 16960n1
#   Skipped: 37742a1
#   Skipped: 36016c1
#   Skipped: 10143s1
#   Skipped: 52416bn1
#   Skipped: 22425g1
#   Skipped: 81654f1
#   Skipped: 19872r1
#   Skipped: 94672e1
#   Skipped: 32760g1
#   Skipped: 4719c1
#   Skipped: 17970k1
#   Skipped: 10170g1
#   Skipped: 12663g1
#   Skipped: 86994m1
#   Skipped: 62814n1
#   Skipped: 44730o1
#   Skipped: 79020h1
#   Skipped: 15170d1
#   Skipped: 35006a1
#   Skipped: 43200du1
#   Skipped: 32328b1
#   Skipped: 50145a1
#   Skipped: 13055c1
#   Skipped: 71098c1
#   Skipped: 66240ez1
#   Skipped: 3486l1
#   Skipped: 83574g1
#   Skipped: 7358b1
#   Skipped: 72688f1
#   Skipped: 72562a1
#   Skipped: 60162e1
#   Skipped: 88946c1
#   Skipped: 41412b1
#   Skipped: 64976d1
#   Skipped: 98205a1
#   Skipped: 53802bo1
#   Skipped: 11660b1
#   Skipped: 33600bp1
#   Skipped: 55720a1
#   Skipped: 79398e1
#   Skipped: 52041j1
#   Skipped: 56650bb1
#   Skipped: 49296bd1
#   Skipped: 34698e1
#   Skipped: 11390h1
#   Skipped: 24120r1
#   Skipped: 94705d1
#   Skipped: 47824q1
#   Skipped: 93330bn1
#   Skipped: 51569b1
#   Skipped: 2350o1
#   Skipped: 6160n1
#   Skipped: 42419b1
#   Skipped: 76530a1
#   Skipped: 75636f1
#   Skipped: 58604g1
#   Skipped: 57024cm1
#   Skipped: 62730f1
#   Skipped: 15675g1
#   Skipped: 41616r1
#   Skipped: 50304p1
#   Skipped: 58856a1
#   Skipped: 7666a1
#   Skipped: 28480m1
#   Skipped: 8406j1
#   Skipped: 49915a1
#   Skipped: 54320c1
#   Skipped: 77478d1
#   Skipped: 57330n1
#   Skipped: 87681c1
#   Skipped: 83790dz1
#   Skipped: 74405b1
#   Skipped: 6272b1
#   Skipped: 7092a1
#   Skipped: 89424l1
#   Skipped: 16048e1
#   Skipped: 51840k1
#   Skipped: 56448ct1
#   Skipped: 34048a1
#   Skipped: 12880u1
#   Skipped: 13158r1
#   Skipped: 69048g1
#   Skipped: 70384d1
#   Skipped: 39468c1
#   Skipped: 54776a1
#   Skipped: 33299b1
#   Skipped: 86254j1
#   Skipped: 61040e1
#   Skipped: 11600k1
#   Skipped: 69552e1
#   Skipped: 48804n1
#   Skipped: 35532c1
#   Skipped: 46128d1
#   Skipped: 69966u1
#   Skipped: 92352l1
#   Skipped: 17280o1
#   Skipped: 40898n1
#   Skipped: 57360y1
#   Skipped: 91290h1
#   Skipped: 4446p1
#   Skipped: 28482a1
#   Skipped: 17274d1
#   Skipped: 3666j1
#   Skipped: 76518d1
#   Skipped: 84422c1
#   Skipped: 49933b1
#   Skipped: 93104bc1
#   Skipped: 4410p1
#   Skipped: 49296u1
#   Skipped: 57876g1
#   Skipped: 68139b1
#   Skipped: 10550b1
#   Skipped: 65565k1
#   Skipped: 49950cr1
#   Skipped: 75594a1
#   Skipped: 94962r1
#   Skipped: 38710h1
#   Skipped: 39360cx1
#   Skipped: 10440k1
#   Skipped: 71610bs1
#   Skipped: 57600bh1
#   Skipped: 88138a1
#   Skipped: 6882j1
#   Skipped: 65863b1
#   Skipped: 99590e1
#   Skipped: 15040l1
#   Skipped: 35100bn1
#   Skipped: 60070f1
#   Skipped: 87952e1
#   Skipped: 79254bm1
#   Skipped: 42476d1
#   Skipped: 55451b1
#   Skipped: 4920a1
#   Skipped: 68760k1
#   Skipped: 42900bt1
#   Skipped: 97152e1
#   Skipped: 3822o1
#   Skipped: 36800ds1
#   Skipped: 32307a1
#   Skipped: 62218a1
#   Skipped: 12619c1
#   Skipped: 19320d1
#   Skipped: 72471h1
#   Skipped: 73980c1
#   Skipped: 95134a1
#   Skipped: 23829g1
#   Skipped: 75840w1
#   Skipped: 74700t1
#   Skipped: 69654l1
#   Skipped: 36752a1
#   Skipped: 42176j1
#   Skipped: 77270a1
#   Skipped: 66240ex1
#   Skipped: 96918a1
#   Skipped: 44030f1
#   Skipped: 33054h1
#   Skipped: 76257c1
#   Skipped: 63536d1
#   Skipped: 41008t1
#   Skipped: 14154n1
#   Skipped: 54968a1
#   Skipped: 47440g1
#   Skipped: 80850fu1
#   Skipped: 31168b1
#   Skipped: 48400cv1
#   Skipped: 12714e1
#   Skipped: 37944b1
#   Skipped: 8075g1
#   Skipped: 97002j1
#   Skipped: 53622g1
#   Skipped: 69721a1
#   Skipped: 20160ev1
#   Skipped: 81261a1
#   Skipped: 59122e1
#   Skipped: 66902b1
#   Skipped: 52233c1
#   Skipped: 11825c1
#   Skipped: 32208h1
#   Skipped: 17771c1
#   Skipped: 15066c1
#   Skipped: 73920ex1
#   Skipped: 5586x1
#   Skipped: 84050h1
#   Skipped: 48200h1
#   Skipped: 66960bx1
#   Skipped: 17100bb1
#   Skipped: 1818b1
#   Skipped: 82596a1
#   Skipped: 64768m1
#   Skipped: 5095d1
#   Skipped: 11466bo1
#   Skipped: 15822c1
#   Skipped: 57594c1
#   Skipped: 24336m1
#   Skipped: 92278c1
#   Skipped: 82880u1
#   Skipped: 28248f1
#   Skipped: 31590u1
#   Skipped: 50355a1
#   Skipped: 13872bp1
#   Skipped: 29210i1
#   Skipped: 50544bx1
#   Skipped: 47712l1
#   Skipped: 38610bx1
#   Skipped: 44936a1
#   Skipped: 82110bp1
#   Skipped: 7410v1
#   Skipped: 39315b1
#   Skipped: 93515a1
#   Skipped: 97926b1
#   Skipped: 24060c1
#   Skipped: 77910i1
#   Skipped: 43113a1
#   Skipped: 55815c1
#   Skipped: 73568e1
#   Skipped: 38880y1
#   Skipped: 34230q1
#   Skipped: 60258ba1
#   Skipped: 90180b1
#   Skipped: 2484b1
#   Skipped: 97635b1
#   Skipped: 59850cy1
#   Skipped: 72504c1
#   Skipped: 92850d1
#   Skipped: 74560e1
#   Skipped: 2440a1
#   Skipped: 19600dn1
#   Skipped: 39130t1
#   Skipped: 83942b1
#   Skipped: 1727a1
#   Skipped: 27936z1
#   Skipped: 76879a1
#   Skipped: 96129b1
#   Skipped: 65565m1
#   Skipped: 27170z1
#   Skipped: 24816t1
#   Skipped: 39585j1
#   Skipped: 73682d1
#   Skipped: 57387a1
#   Skipped: 7961a1
#   Skipped: 51168r1
#   Skipped: 72471q1
#   Skipped: 4050y1
#   Skipped: 14016cf1
#   Skipped: 92159a1
#   Skipped: 24200i1
#   Skipped: 13202c1
#   Skipped: 29055h1
#   Skipped: 84400bi1
#   Skipped: 46800ej1
#   Skipped: 29175i1
#   Skipped: 38002a1
#   Skipped: 12992i1
#   Skipped: 30940a1
#   Skipped: 10790b1
#   Skipped: 96558bq1
#   Skipped: 15407d1
#   Skipped: 5680c1
#   Skipped: 24650y1
#   Skipped: 37950cm1
#   Skipped: 10086j1
#   Skipped: 93522o1
#   Skipped: 58374ba1
#   Skipped: 58550d1
#   Skipped: 83850cj1
#   Skipped: 116c1
#   Skipped: 23232z1
#   Skipped: 588f1
#   Skipped: 46230c1
#   Skipped: 86880b1
#   Skipped: 4150p1
#   Skipped: 39151c1
#   Skipped: 45822d1
#   Skipped: 99902b1
#   Skipped: 75078j1
#   Skipped: 31584e1
#   Skipped: 97560w1
#   Skipped: 65930c1
#   Skipped: 89528h1
#   Skipped: 86450i1
#   Skipped: 53418h1
#   Skipped: 78342h1
#   Skipped: 99120be1
#   Skipped: 18768z1
#   Skipped: 98504b1
#   Skipped: 47210b1
#   Skipped: 11328m1
#   Skipped: 70864a1
#   Skipped: 22274f1
#   Skipped: 45890l1
#   Skipped: 20524b1
#   Skipped: 10960f1
#   Skipped: 97440bs1
#   Skipped: 85080f1
#   Skipped: 60450dc1
#   Skipped: 16362n1
#   Skipped: 3381a1
#   Skipped: 36550j1
#   Skipped: 50900a1
#   Skipped: 41868b1
#   Skipped: 22372a1
#   Skipped: 99582f1
#   Skipped: 54173a1
#   Skipped: 49770h1
#   Skipped: 91098q1
#   Skipped: 25065i1
#   Skipped: 32946g1
#   Skipped: 19205a1
#   Skipped: 22131c1
#   Skipped: 59722a1
#   Skipped: 89490i1
#   Skipped: 92070b1
#   Skipped: 26688l1
#   Skipped: 72618cd1
#   Skipped: 87050f1
#   Skipped: 12051b1
#   Skipped: 11600r1
#   Skipped: 67470c1
#   Skipped: 48864i1
#   Skipped: 92301b1
#   Skipped: 34710p1
#   Skipped: 59414f1
#   Skipped: 55440cc1
#   Skipped: 37440ew1
#   Skipped: 83654c1
#   Skipped: 98714e1
#   Skipped: 26224b1
#   Skipped: 50985f1
#   Skipped: 47586k1
#   Skipped: 16954s1
#   Skipped: 47370b1
#   Skipped: 23520ba1
#   Skipped: 64240c1
#   Skipped: 62058b1
#   Skipped: 50130e1
#   Skipped: 67300h1
#   Skipped: 16800bu1
#   Skipped: 35557b1
#   Skipped: 14064c1
#   Skipped: 11934c1
#   Skipped: 9153d1
#   Skipped: 28674g1
#   Skipped: 12210d1
#   Skipped: 16995b1
#   Skipped: 23576b1
#   Skipped: 10128j1
#   Skipped: 90202e1
#   Skipped: 67662h1
#   Skipped: 29376ba1
#   Skipped: 37856g1
#   Skipped: 25792w1
#   Skipped: 95810h1
#   Skipped: 23472z1
#   Skipped: 86800s1
#   Skipped: 88550bb1
#   Skipped: 82224s1
#   Skipped: 52075b1
#   Skipped: 25092b1
#   Skipped: 41470b1
#   Skipped: 24240r1
#   Skipped: 57438a1
#   Skipped: 94284e1
#   Skipped: 51280g1
#   Skipped: 76845a1
#   Skipped: 12673d1
#   Skipped: 64032c1
#   Skipped: 22792e1
#   Skipped: 91200fn1
#   Skipped: 92898i1
#   Skipped: 75705ba1
#   Skipped: 78390bo1
#   Skipped: 57810j1
#   Skipped: 73573b1
#   Skipped: 24560b1
#   Skipped: 59360g1
#   Skipped: 77234a1
#   Skipped: 16704bn1
#   Skipped: 12736c1
#   Skipped: 52560g1
#   Skipped: 84735d1
#   Skipped: 60990bn1
#   Skipped: 8262h1
#   Skipped: 71706m1
#   Skipped: 99360x1
#   Skipped: 39330r1
#   Skipped: 52880k1
#   Skipped: 40956d1
#   Skipped: 71070c1
#   Skipped: 67398k1
#   Skipped: 44278b1
#   Skipped: 73692c1
#   Skipped: 75042h1
#   Skipped: 54230n1
#   Skipped: 59010i1
#   Skipped: 85440m1
#   Skipped: 1806g1
#   Skipped: 87450ci1
#   Skipped: 56472m1
#   Skipped: 70278l1
#   Skipped: 85008ch1
#   Skipped: 1890v1
#   Skipped: 47754p1
#   Skipped: 42850f1
#   Skipped: 65340a1
#   Skipped: 65520o1
#   Skipped: 94528h1
#   Skipped: 17970h1
#   Skipped: 68628d1
#   Skipped: 71190bl1
#   Skipped: 12072d1
#   Skipped: 9360d1
#   Skipped: 55720h1
#   Skipped: 11900d1
#   Skipped: 58242i1
#   Skipped: 16704de1
#   Skipped: 25608c1
#   Skipped: 12082a1
#   Skipped: 54936q1
#   Skipped: 25920bk1
#   Skipped: 17236b1
#   Skipped: 19065l1
#   Skipped: 53347a1
#   Skipped: 39139b1
#   Skipped: 97199h1
#   Skipped: 77376b1
#   Skipped: 68442j1
#   Skipped: 777c1
#   Skipped: 70422q1
#   Skipped: 79275j1
#   Skipped: 24402j1
#   Skipped: 92826f1
#   Skipped: 64922g1
#   Skipped: 83700q1
#   Skipped: 15584g1
#   Skipped: 78533a1
#   Skipped: 3045i1
#   Skipped: 34680i1
#   Skipped: 94656bw1
#   Skipped: 82896c1
#   Skipped: 43150b1
#   Skipped: 67550m1
#   Skipped: 74736f1
#   Skipped: 98496bh1
#   Skipped: 47862j1
#   Skipped: 48139o1
#   Skipped: 606c1
#   Skipped: 76602k1
#   Skipped: 33915b1
#   Skipped: 17856h1
#   Skipped: 75570o1
#   Skipped: 68952l1
#   Skipped: 25760d1
#   Skipped: 28176h1
#   Skipped: 56700f1
#   Skipped: 57200bf1
#   Skipped: 780b1
#   Skipped: 97800g1
#   Skipped: 54240f1
#   Skipped: 68595c1
#   Skipped: 58374bb1
#   Skipped: 40502a1
#   Skipped: 44460s1
#   Skipped: 41070bi1
#   Skipped: 73536bq1
#   Skipped: 6150be1
#   Skipped: 97888d1
#   Skipped: 13221f1
#   Skipped: 86400ck1
#   Skipped: 63372a1
#   Skipped: 34515g1
#   Skipped: 66465b1
#   Skipped: 79520k1
#   Skipped: 95343a1
#   Skipped: 48230s1
#   Skipped: 7050ba1
#   Skipped: 80496bi1
#   Skipped: 72680e1
#   Skipped: 75888l1
#   Skipped: 82880bj1
#   Skipped: 28014g1
#   Skipped: 20859b1
#   Skipped: 79101c1
#   Skipped: 1640b1
#   Skipped: 81340m1
#   Skipped: 75200cm1
#   Skipped: 39402p1
#   Skipped: 27170p1
#   Skipped: 1350g1
#   Skipped: 89010e1
#   Skipped: 89358a1
#   Skipped: 91143h1
#   Skipped: 25530bh1
#   Skipped: 40182g1
#   Skipped: 89280ct1
#   Skipped: 62123c1
#   Skipped: 88766b1
#   Skipped: 24747c1
#   Skipped: 54390bn1
#   Skipped: 98658b1
#   Skipped: 43472e1
#   Skipped: 27390o1
#   Skipped: 4550p1
#   Skipped: 28592b1
#   Skipped: 13266q1
#   Skipped: 54808b1
#   Skipped: 85920o1
#   Skipped: 2442h1
#   Skipped: 74529h1
#   Skipped: 64715b1
#   Skipped: 51870bp1
#   Skipped: 70725b1
#   Skipped: 10134f1
#   Skipped: 53040p1
#   Skipped: 70738a1
#   Skipped: 43584j1
#   Skipped: 35264n1
#   Skipped: 50358j1
#   Skipped: 33408bc1
#   Skipped: 62784m1
#   Skipped: 53586r1
#   Skipped: 20550bp1
#   Skipped: 44088g1
#   Skipped: 95682c1
#   Skipped: 66822e1
#   Skipped: 5814q1
#   Skipped: 81072h1
#   Skipped: 87528h1
#   Skipped: 48416c1
#   Skipped: 73584s1
#   Skipped: 20730d1
#   Skipped: 8446b1
#   Skipped: 57904d1
#   Skipped: 8688c1
#   Skipped: 81161a1
#   Skipped: 15522a1
#   Skipped: 31542i1
#   Skipped: 56994bg1
#   Skipped: 73299e1
#   Skipped: 94864i1
#   Skipped: 83822a1
#   Skipped: 43304b1
#   Skipped: 52965r1
#   Skipped: 88825c1
#   Skipped: 75603e1
#   Skipped: 82544be1
#   Skipped: 1058b1
#   Skipped: 3895c1
#   Skipped: 82998a1
#   Skipped: 97530d1
#   Skipped: 54045f1
#   Skipped: 71760bk1
#   Skipped: 63330l1
#   Skipped: 70209d1
#   Skipped: 21906b1
#   Skipped: 15255a1
#   Skipped: 954l1
#   Skipped: 91728bv1
#   Skipped: 81077b1
#   Skipped: 73008bs1
#   Skipped: 64890bi1
#   Skipped: 95817g1
#   Skipped: 31034c1
#   Skipped: 7600n1
#   Skipped: 89955b1
#   Skipped: 85722s1
#   Skipped: 31958h1
#   Skipped: 34050a1
#   Skipped: 56800g1
#   Skipped: 57732a1
#   Skipped: 90342x1
#   Skipped: 66994b1
#   Skipped: 6486k1
#   Skipped: 95184d1
#   Skipped: 66096p1
#   Skipped: 32042a1
#   Skipped: 53064p1
#   Skipped: 97920bm1
#   Skipped: 99099d1
#   Skipped: 13680bk1
#   Skipped: 49680bs1
#   Skipped: 4902m1
#   Skipped: 2782f1
#   Skipped: 80104e1
#   Skipped: 11193e1
#   Skipped: 41616br1
#   Skipped: 93440q1
#   Skipped: 50880bt1
#   Skipped: 56298a1
#   Skipped: 62320bb1
#   Skipped: 93984a1
#   Skipped: 32448bm1
#   Skipped: 84600ca1
#   Skipped: 23400u1
#   Skipped: 15984x1
#   Skipped: 5130c1
#   Skipped: 72299b1
#   Skipped: 67410cm1
#   Skipped: 7067b1
#   Skipped: 73872v1
#   Skipped: 37442a1
#   Skipped: 36354p1
#   Skipped: 65184b1
#   Skipped: 85218e1
#   Skipped: 83148e1
#   Skipped: 30792d1
#   Skipped: 44704b1
#   Skipped: 19947f1
#   Skipped: 39837g1
#   Skipped: 7950j1
#   Skipped: 59616e1
#   Skipped: 61460a1
#   Skipped: 25992bc1
#   Skipped: 56720b1
#   Skipped: 99106a1
#   Skipped: 45530f1
#   Skipped: 16944e1
#   Skipped: 4851m1
#   Skipped: 29930c1
#   Skipped: 54575d1
#   Skipped: 80790o1
#   Skipped: 74772c1
#   Skipped: 98496w1
#   Skipped: 9100k1
#   Skipped: 79798c1
#   Skipped: 91808f1
#   Skipped: 93765h1
#   Skipped: 32912x1
#   Skipped: 24436a1
#   Skipped: 33558bg1
#   Skipped: 76690b1
#   Skipped: 45990by1
#   Skipped: 38906a1
#   Skipped: 86592df1
#   Skipped: 99176a1
#   Skipped: 88920bk1
#   Skipped: 16146i1
#   Skipped: 55186b1
#   Skipped: 93990m1
#   Skipped: 52677c1
#   Skipped: 34485p1
#   Skipped: 54048e1
#   Skipped: 29177a1
#   Skipped: 58230m1
#   Skipped: 6555b1
#   Skipped: 57570p1
#   Skipped: 10845d1
#   Skipped: 29648j1
#   Skipped: 60900i1
#   Skipped: 10830j1
#   Skipped: 37200bk1
#   Skipped: 2150e1
#   Skipped: 76320g1
#   Skipped: 67024d1
#   Skipped: 37842m1
#   Skipped: 72760a1
#   Skipped: 95040p1
#   Skipped: 55854e1
#   Skipped: 55932c1
#   Skipped: 34278j1
#   Skipped: 75606a1
#   Skipped: 42630y1
#   Skipped: 58322m1
#   Skipped: 54624d1
#   Skipped: 90168k1
#   Skipped: 12992m1
#   Skipped: 37680q1
#   Skipped: 12411b1
#   Skipped: 85056w1
#   Skipped: 42280m1
#   Skipped: 44270a1
#   Skipped: 31990f1
#   Skipped: 25888a1
#   Skipped: 47786a1
#   Skipped: 22704g1
#   Skipped: 56542a1
#   Skipped: 96063b1
#   Skipped: 75545a1
#   Skipped: 82825c1
#   Skipped: 80240n1
#   Skipped: 84271c1
#   Skipped: 18558d1
#   Skipped: 51726h1
#   Skipped: 61770u1
#   Skipped: 17202b1
#   Skipped: 52582c1
#   Skipped: 55104cg1
#   Skipped: 68880p1
#   Skipped: 63856i1
#   Skipped: 67230f1
#   Skipped: 96450l1
#   Skipped: 93210n1
#   Skipped: 24102b1
#   Skipped: 46389g1
#   Skipped: 24552b1
#   Skipped: 54621be1
#   Skipped: 43690f1
#   Skipped: 86658d1
#   Skipped: 84422p1
#   Skipped: 95810i1
#   Skipped: 69534d1
#   Skipped: 82051a1
#   Skipped: 12122d1
#   Skipped: 54603f1
#   Skipped: 82159e1
#   Skipped: 14283b1
#   Skipped: 81144y1
#   Skipped: 95160q1
#   Skipped: 21880b1
#   Skipped: 7037b1
#   Skipped: 24192k1
#   Skipped: 74382bx1
#   Skipped: 42560cs1
#   Skipped: 80410j1
#   Skipped: 8522a1
#   Skipped: 17913a1
#   Skipped: 58176s1
#   Skipped: 38246b1
#   Skipped: 35336b1
#   Skipped: 2277a1
#   Skipped: 58254p1
#   Skipped: 72942d1
#   Skipped: 56080e1
#   Skipped: 84784c1
#   Skipped: 66664d1
#   Skipped: 28730r1
#   Skipped: 33600eq1
#   Skipped: 3363b1
#   Skipped: 83580h1
#   Skipped: 17085b1
#   Skipped: 24420m1
#   Skipped: 67958d1
#   Skipped: 70350bv1
#   Skipped: 89378d1
#   Skipped: 71313b1
#   Skipped: 2914d1
#   Skipped: 85701w1
#   Skipped: 5658h1
#   Skipped: 11760t1
#   Skipped: 93975m1
#   Skipped: 9108o1
#   Skipped: 29610u1
#   Skipped: 48124a1
#   Skipped: 68024a1
#   Skipped: 53675b1
#   Skipped: 58212p1
#   Skipped: 40820b1
#   Skipped: 73408h1
#   Skipped: 28230b1
#   Skipped: 87248q1
#   Skipped: 7248c1
#   Skipped: 38920i1
#   Skipped: 80305a1
#   Skipped: 93600ei1
#   Skipped: 26880x1
#   Skipped: 7257j1
#   Skipped: 64911c1
#   Skipped: 43995e1
#   Skipped: 89040z1
#   Skipped: 65175j1
#   Skipped: 39216n1
#   Skipped: 39739f1
#   Skipped: 11152c1
#   Skipped: 99488d1
#   Skipped: 16746b1
#   Skipped: 77440l1
#   Skipped: 38480u1
#   Skipped: 4656o1
#   Skipped: 72240cc1
#   Skipped: 68820d1
#   Skipped: 83496s1
#   Skipped: 49166a1
#   Skipped: 8970h1
#   Skipped: 7656d1
#   Skipped: 92862bo1
#   Skipped: 17024b1
#   Skipped: 1090a1
#   Skipped: 3234t1
#   Skipped: 26710a1
#   Skipped: 97488j1
#   Skipped: 44109ba1
#   Skipped: 59358g1
#   Skipped: 66752j1
#   Skipped: 80640g1
#   Skipped: 44505l1
#   Skipped: 36696f1
#   Skipped: 54663b1
#   Skipped: 61350e1
#   Skipped: 53670b1
#   Skipped: 18476a1
#   Skipped: 28810a1
#   Skipped: 43290bt1
#   Skipped: 77665k1
#   Skipped: 16422v1
#   Skipped: 86360b1
#   Skipped: 12937a1
#   Skipped: 58027b1
#   Skipped: 53605b1
#   Skipped: 90244d1
#   Skipped: 99648h1
#   Skipped: 97410e1
#   Skipped: 79380y1
#   Skipped: 79536e1
#   Skipped: 56112d1
#   Skipped: 16354c1
#   Skipped: 54550b1
#   Skipped: 54912bo1
#   Skipped: 22335e1
#   Skipped: 79950d1
#   Skipped: 39714h1
#   Skipped: 65850e1
#   Skipped: 67065d1
#   Skipped: 1590u1
#   Skipped: 67274a1
#   Skipped: 45600o1
#   Skipped: 29390b1
#   Skipped: 2450n1
#   Skipped: 19842e1
#   Skipped: 94690c1
#   Skipped: 86697c1
#   Skipped: 95296h1
#   Skipped: 26040r1
#   Skipped: 58888a1
#   Skipped: 26235a1
#   Skipped: 16400i1
#   Skipped: 42398a1
#   Skipped: 48951i1
#   Skipped: 12530o1
#   Skipped: 6951a1
#   Skipped: 99294r1
#   Skipped: 68544ee1
#   Skipped: 11326a1
#   Skipped: 5472c1
#   Skipped: 73200cw1
#   Skipped: 92950r1
#   Skipped: 59136bl1
#   Skipped: 7007d1
#   Skipped: 37257a1
#   Skipped: 98406d1
#   Skipped: 43200ca1
#   Skipped: 2262h1
#   Skipped: 15543f1
#   Skipped: 40470bl1
#   Skipped: 70047d1
#   Skipped: 14166g1
#   Skipped: 56784cd1
#   Skipped: 81600im1
#   Skipped: 47700a1
#   Skipped: 81368a1
#   Skipped: 5425f1
#   Skipped: 58482ba1
#   Skipped: 94400o1
#   Skipped: 42048i1
#   Skipped: 45600q1
#   Skipped: 67398b1
#   Skipped: 74928c1
#   Skipped: 15984k1
#   Skipped: 99912a1
#   Skipped: 69218c1
#   Skipped: 28224fg1
#   Skipped: 64092o1
#   Skipped: 88502c1
#   Skipped: 44880bx1
#   Skipped: 36800ce1
#   Skipped: 55488bb1
#   Skipped: 55510s1
#   Skipped: 68838q1
#   Skipped: 32064f1
#   Skipped: 93385d1
#   Skipped: 30272v1
#   Skipped: 42096n1
#   Skipped: 93240l1
#   Skipped: 39135d1
#   Skipped: 94320bh1
#   Skipped: 50565c1
#   Skipped: 2150k1
#   Skipped: 68054c1
#   Skipped: 68274d1
#   Skipped: 7872r1
#   Skipped: 76650ca1
#   Skipped: 17649a1
#   Skipped: 27590d1
#   Skipped: 65026c1
#   Skipped: 77454j1
#   Skipped: 3392m1
#   Skipped: 56790p1
#   Skipped: 87920y1
#   Skipped: 70734a1
#   Skipped: 39330d1
#   Skipped: 67385b1
#   Skipped: 16874c1
#   Skipped: 61118b1
#   Skipped: 57456s1
#   Skipped: 5572e1
#   Skipped: 87010r1
#   Skipped: 37922b1
#   Skipped: 81096d1
#   Skipped: 29664i1
#   Skipped: 59148a1
#   Skipped: 63900k1
#   Skipped: 21792j1
#   Skipped: 44274a1
#   Skipped: 65088x1
#   Skipped: 7632o1
#   Skipped: 97960e1
#   Skipped: 67424b1
#   Skipped: 82260f1
#   Skipped: 19008p1
#   Skipped: 12730a1
#   Skipped: 50095a1
#   Skipped: 41664dq1
#   Skipped: 58128h1
#   Skipped: 76080u1
#   Skipped: 12397r1
#   Skipped: 81225v1
#   Skipped: 69720f1
#   Skipped: 79035e1
#   Skipped: 80550bl1
#   Skipped: 62002a1
#   Skipped: 96646c1
#   Skipped: 25810f1
#   Skipped: 9504c1
#   Skipped: 8946v1
#   Skipped: 11034e1
#   Skipped: 57150br1
#   Skipped: 42534l1
#   Skipped: 94290x1
#   Skipped: 82080j1
#   Skipped: 70455n1
#   Skipped: 23166d1
#   Skipped: 34112e1
#   Skipped: 32760bh1
#   Skipped: 70695a1
#   Skipped: 99148a1
#   Skipped: 17800i1
#   Skipped: 29072n1
#   Skipped: 61902i1
#   Skipped: 18411c1
#   Skipped: 21306a1
#   Skipped: 32889a1
#   Skipped: 30282bu1
#   Skipped: 10800do1
#   Skipped: 64285e1
#   Skipped: 60801h1
#   Skipped: 43036a1
#   Skipped: 95949b1
#   Skipped: 17424cc1
#   Skipped: 55800cd1
#   Skipped: 40222k1
#   Skipped: 12670r1
#   Skipped: 53390a1
#   Skipped: 77710b1
#   Skipped: 15878e1
#   Skipped: 6494c1
#   Skipped: 74727c1
#   Skipped: 96558br1
#   Skipped: 24711a1
#   Skipped: 85266g1
#   Skipped: 72705a1
#   Skipped: 23664g1
#   Skipped: 81137c1
#   Skipped: 42333c1
#   Skipped: 42486o1
#   Skipped: 27944a1
#   Skipped: 99370b1
#   Skipped: 38192h1
#   Skipped: 97650q1
#   Skipped: 62640cb1
#   Skipped: 89655c1
#   Skipped: 4161c1
#   Skipped: 86112n1
#   Skipped: 97240g1
#   Skipped: 31824c1
#   Skipped: 94128b1
#   Skipped: 93240y1
#   Skipped: 85400z1
#   Skipped: 19470c1
#   Skipped: 93642c1
#   Skipped: 86832h1
#   Skipped: 61778b1
#   Skipped: 20925bi1
#   Skipped: 61602c1
#   Skipped: 79770f1
#   Skipped: 14464a1
#   Skipped: 31680h1
#   Skipped: 74731a1
#   Skipped: 10192l1
#   Skipped: 70642d1
#   Skipped: 47950bf1
#   Skipped: 17010bm1
#   Skipped: 91336e1
#   Skipped: 80582a1
#   Skipped: 99606d1
#   Skipped: 38808ce1
#   Skipped: 57440b1
#   Skipped: 83037b1
#   Skipped: 12447a1
#   Skipped: 56280y1
#   Skipped: 52345g1
#   Skipped: 41107b1
#   Skipped: 53130bi1
#   Skipped: 78736j1
#   Skipped: 3774e1
#   Skipped: 56100bf1
#   Skipped: 55233b1
#   Skipped: 17586m1
#   Skipped: 93105j1
#   Skipped: 35490dx1
#   Skipped: 68355bc1
#   Skipped: 18304d1
#   Skipped: 7854h1
#   Skipped: 20677c1
#   Skipped: 41664ec1
#   Skipped: 58926g1
#   Skipped: 39382a1
#   Skipped: 9600be1
#   Skipped: 32490bt1
#   Skipped: 57584d1
#   Skipped: 99710j1
#   Skipped: 22477l1
#   Skipped: 8792c1
#   Skipped: 71536c1
#   Skipped: 76950bp1
#   Skipped: 82803a1
#   Skipped: 88536u1
#   Skipped: 30401a1
#   Skipped: 74898g1
#   Skipped: 55998d1
#   Skipped: 6518b1
#   Skipped: 37040s1
#   Skipped: 59508d1
#   Skipped: 31150y1
#   Skipped: 2295c1
#   Skipped: 10304d1
#   Skipped: 31400c1
#   Skipped: 77415c1
#   Skipped: 30240bd1
#   Skipped: 13376v1
#   Skipped: 53200bo1
#   Skipped: 58560j1
#   Skipped: 39039d1
#   Skipped: 11613a1
#   Skipped: 50572c1
#   Skipped: 46893e1
#   Skipped: 83030d1
#   Skipped: 14850cm1
#   Skipped: 96237g1
#   Skipped: 68871c1
#   Skipped: 87997b1
#   Skipped: 8778y1
#   Skipped: 34410l1
#   Skipped: 58254bb1
#   Skipped: 6480i1
#   Skipped: 74700k1
#   Skipped: 61056ci1
#   Skipped: 61525a1
#   Skipped: 23030u1
#   Skipped: 33174d1
#   Skipped: 19520o1
#   Skipped: 27608g1
#   Skipped: 90282o1
#   Skipped: 22806d1
#   Skipped: 30940h1
#   Skipped: 27840ds1
#   Skipped: 47530r1
#   Skipped: 40768l1
#   Skipped: 44838w1
#   Skipped: 4386i1
#   Skipped: 93798f1
#   Skipped: 49400n1
#   Skipped: 72162e1
#   Skipped: 25830r1
#   Skipped: 34368n1
#   Skipped: 33432h1
#   Skipped: 41550r1
#   Skipped: 35862s1
#   Skipped: 93119g1
#   Skipped: 12330b1
#   Skipped: 12240ba1
#   Skipped: 76908e1
#   Skipped: 78078t1
#   Skipped: 4224f1
#   Skipped: 57234a1
#   Skipped: 11560e1
#   Skipped: 33852d1
#   Skipped: 61656a1
#   Skipped: 18746a1
#   Skipped: 37200df1
#   Skipped: 51984bh1
#   Skipped: 48174w1
#   Skipped: 19110y1
#   Skipped: 71064h1
#   Skipped: 53730t1
#   Skipped: 67392cc1
#   Skipped: 90156h1
#   Skipped: 59040bo1
#   Skipped: 9548a1
#   Skipped: 67347c1
#   Skipped: 93056d1
#   Skipped: 48112e1
#   Skipped: 82144b1
#   Skipped: 22470bl1
#   Skipped: 55601c1
#   Skipped: 24822z1
#   Skipped: 54670m1
#   Skipped: 27720i1
#   Skipped: 67752a1
#   Skipped: 43190f1
#   Skipped: 54131c1
#   Skipped: 50460n1
#   Skipped: 84040d1
#   Skipped: 8640p1
#   Skipped: 75591a1
#   Skipped: 1309a1
#   Skipped: 1287b1
#   Skipped: 75950p1
#   Skipped: 41610bo1
#   Skipped: 51336o1
#   Skipped: 51216t1
#   Skipped: 62928ba1
#   Skipped: 95190r1
#   Skipped: 20530g1
#   Skipped: 32976c1
#   Skipped: 28935b1
#   Skipped: 84227b1
#   Skipped: 98286d1
#   Skipped: 17586q1
#   Skipped: 22265b1
#   Skipped: 56560m1
#   Skipped: 97470m1
#   Skipped: 25978c1
#   Skipped: 20524d1
#   Skipped: 50003a1
#   Skipped: 97695f1
#   Skipped: 8098b1
#   Skipped: 65280w1
#   Skipped: 61056n1
#   Skipped: 83394d1
#   Skipped: 90387t1
#   Skipped: 73694a1
#   Skipped: 76776g1
#   Skipped: 11445m1
#   Skipped: 55242j1
#   Skipped: 38870n1
#   Skipped: 68784c1
#   Skipped: 70448p1
#   Skipped: 88336a1
#   Skipped: 83520df1
#   Skipped: 21489d1
#   Skipped: 40400p1
#   Skipped: 40509a1
#   Skipped: 48755b1
#   Skipped: 5184r1
#   Skipped: 33390z1
#   Skipped: 32950a1
#   Skipped: 81970a1
#   Skipped: 80272b1
#   Skipped: 34200by1
#   Skipped: 48780d1
#   Skipped: 60840bx1
#   Skipped: 7266k1
#   Skipped: 59598u1
#   Skipped: 69230bd1
#   Skipped: 8834c1
#   Skipped: 44795g1
#   Skipped: 62073b1
#   Skipped: 74360e1
#   Skipped: 23088t1
#   Skipped: 42924e1
#   Skipped: 93120g1
#   Skipped: 49349a1
#   Skipped: 59354c1
#   Skipped: 83283c1
#   Skipped: 54336q1
#   Skipped: 68650d1
# ...
#   Skipped: 15626c1
#   Skipped: 93120br1
#   Skipped: 28059b1
#   Skipped: 61278j1
#   Skipped: 64320bh1
#   Skipped: 86850ck1
#   Skipped: 12402a1
#   Skipped: 3123a1
#   Skipped: 8062c1
#   Skipped: 97526r1
#   Skipped: 75184e1
#   Skipped: 49446o1
#   Skipped: 66435c1
#   Skipped: 63513h1
#   Skipped: 33462ci1
#   Skipped: 18300i1
#   Skipped: 16530n1
#   Skipped: 17650i1
#   Skipped: 85731a1
#   Skipped: 95659b1
#   Skipped: 36720u1
#   Skipped: 79744y1
#   Skipped: 44616o1
#   Skipped: 95760dt1
#   Skipped: 22506bm1
#   Skipped: 95570a1
#   Skipped: 68894m1
#   Skipped: 81090d1
#   Skipped: 87920b1
#   Skipped: 23748a1
#   Skipped: 57584h1
#   Skipped: 31427b1
#   Skipped: 13160c1
#   Skipped: 33825e1
#   Skipped: 21725b1
#   Skipped: 23550t1
#   Skipped: 9918j1
#   Skipped: 5384a1
#   Skipped: 70464d1
#   Skipped: 44400bn1
#   Skipped: 23730l1
#   Skipped: 97536bh1
#   Skipped: 6048l1
#   Skipped: 33450j1
#   Skipped: 15426l1
#   Skipped: 62280k1
#   Skipped: 54594h1
#   Skipped: 88172b1
#   Skipped: 75918b1
#   Skipped: 55188b1
#   Skipped: 97090h1
#   Skipped: 51850s1
#   Skipped: 48650n1
#   Skipped: 21675c1
#   Skipped: 57850u1
#   Skipped: 94150e1
#   Skipped: 68112g1
#   Skipped: 51946d1
#   Skipped: 30660c1
#   Skipped: 43803d1
#   Skipped: 9650k1
#   Skipped: 1578c1
#   Skipped: 7353g1
#   Skipped: 56725a1
#   Skipped: 17670p1
#   Skipped: 43585a1
#   Skipped: 99960bw1
#   Skipped: 8181b1
#   Skipped: 72540p1
#   Skipped: 36270bd1
#   Skipped: 74589f1
#   Skipped: 95445c1
#   Skipped: 27240j1
#   Skipped: 78585q1
#   Skipped: 93495f1
#   Skipped: 98622e1
#   Skipped: 24850x1
#   Skipped: 39150g1
#   Skipped: 98822a1
#   Skipped: 2548b1
#   Skipped: 86592cs1
#   Skipped: 1914l1
#   Skipped: 52416em1
#   Skipped: 89232bu1
#   Skipped: 90080a1
#   Skipped: 96483a1
#   Skipped: 84084v1
#   Skipped: 90168p1
#   Skipped: 92378i1
#   Skipped: 82800fu1
#   Skipped: 53704i1
#   Skipped: 16170i1
#   Skipped: 44541d1
#   Skipped: 52486d1
#   Skipped: 77760cb1
#   Skipped: 46320f1
#   Skipped: 41064b1
#   Skipped: 52864f1
#   Skipped: 99120t1
#   Skipped: 66080d1
#   Skipped: 77168a1
#   Skipped: 10994e1
#   Skipped: 74624e1
#   Skipped: 74175y1
#   Skipped: 77115f1
#   Skipped: 10668e1
#   Skipped: 26715f1
#   Skipped: 45060e1
#   Skipped: 30570f1
#   Skipped: 91425l1
#   Skipped: 63075c1
#   Skipped: 6050c1
#   Skipped: 352c1
#   Skipped: 27594l1
#   Skipped: 70510o1
#   Skipped: 97749a1
#   Skipped: 99060i1
#   Skipped: 5350f1
#   Skipped: 28600a1
#   Skipped: 99792ce1
#   Skipped: 37180d1
#   Skipped: 11310a1
#   Skipped: 74163a1
#   Skipped: 45934k1
#   Skipped: 71658a1
#   Skipped: 30597c1
#   Skipped: 77976i1
#   Skipped: 27744d1
#   Skipped: 66273a1
#   Skipped: 98879a1
#   Skipped: 9618d1
#   Skipped: 57898a1
#   Skipped: 91630bx1
#   Skipped: 25776d1
#   Skipped: 41904x1
#   Skipped: 71820c1
#   Skipped: 68004b1
#   Skipped: 68060a1
#   Skipped: 44226t1
#   Skipped: 7808n1
#   Skipped: 31680a1
#   Skipped: 93808w1
#   Skipped: 2550bf1
#   Skipped: 89280d1
#   Skipped: 16506c1
#   Skipped: 64830g1
#   Skipped: 99540m1
#   Skipped: 34559a1
#   Skipped: 40950es1
#   Skipped: 78280d1
#   Skipped: 34650o1
#   Skipped: 53150i1
#   Skipped: 95385a1
#   Skipped: 8600d1
#   Skipped: 3667a1
#   Skipped: 35600z1
#   Skipped: 81120m1
#   Skipped: 84336t1
#   Skipped: 90864i1
#   Skipped: 47025z1
#   Skipped: 40290bc1
#   Skipped: 37450a1
#   Skipped: 44294b1
#   Skipped: 30810j1
#   Skipped: 86190bw1
#   Skipped: 45834d1
#   Skipped: 31850s1
#   Skipped: 81520g1
#   Skipped: 53678k1
#   Skipped: 51546e1
#   Skipped: 79380bt1
#   Skipped: 95550kv1
#   Skipped: 90350t1
#   Skipped: 85925e1
#   Skipped: 95654u1
#   Skipped: 6630p1
#   Skipped: 70050l1
#   Skipped: 88842k1
#   Skipped: 13110g1
#   Skipped: 80010f1
#   Skipped: 54782g1
#   Skipped: 3532a1
#   Skipped: 21294bu1
#   Skipped: 45227g1
#   Skipped: 52582f1
#   Skipped: 36800l1
#   Skipped: 53424r1
#   Skipped: 3008a1
#   Skipped: 95984c1
#   Skipped: 87840bg1
#   Skipped: 76107c1
#   Skipped: 35154o1
#   Skipped: 67770c1
#   Skipped: 35211b1
#   Skipped: 61110bf1
#   Skipped: 70785d1
#   Skipped: 55366f1
#   Skipped: 89082q1
#   Skipped: 36960bf1
#   Skipped: 35490du1
#   Skipped: 31440a1
#   Skipped: 53589a1
#   Skipped: 46899b1
#   Skipped: 60198g1
#   Skipped: 97282a1
#   Skipped: 44958c1
#   Skipped: 64246d1
#   Skipped: 71104a1
#   Skipped: 9752b1
#   Skipped: 69498r1
#   Skipped: 51064a1
#   Skipped: 48692c1
#   Skipped: 97300j1
#   Skipped: 55029a1
#   Skipped: 31360cb1
#   Skipped: 92046u1
#   Skipped: 81466l1
#   Skipped: 82038k1
#   Skipped: 32550m1
#   Skipped: 40878c1
#   Skipped: 89408x1
#   Skipped: 92235e1
#   Skipped: 38592ca1
#   Skipped: 25773s1
#   Skipped: 65088cv1
#   Skipped: 77376q1
#   Skipped: 92340ba1
#   Skipped: 69181a1
#   Skipped: 35244e1
#   Skipped: 39886e1
#   Skipped: 93138r1
#   Skipped: 6518c1
#   Skipped: 72285f1
#   Skipped: 84320q1
#   Skipped: 32807b1
#   Skipped: 88541b1
#   Skipped: 41457a1
#   Skipped: 76254e1
#   Skipped: 91446a1
#   Skipped: 24870e1
#   Skipped: 61197b1
#   Skipped: 13764a1
#   Skipped: 92752n1
#   Skipped: 60240k1
#   Skipped: 56504c1
#   Skipped: 27360n1
#   Skipped: 26988i1
#   Skipped: 91357a1
#   Skipped: 19581b1
#   Skipped: 87654i1
#   Skipped: 39200bb1
#   Skipped: 66265c1
#   Skipped: 52350b1
#   Skipped: 81468g1
#   Skipped: 40552e1
#   Skipped: 42735l1
#   Skipped: 77940d1
#   Skipped: 18746n1
#   Skipped: 82362x1
#   Skipped: 93483h1
#   Skipped: 23078b1
#   Skipped: 93390g1
#   Skipped: 96195f1
#   Skipped: 14480g1
#   Skipped: 75582f1
#   Skipped: 46437b1
#   Skipped: 62995c1
#   Skipped: 53850j1
#   Skipped: 14080l1
#   Skipped: 64108c1
#   Skipped: 22278a1
#   Skipped: 71510b1
#   Skipped: 87045j1
#   Skipped: 11838m1
#   Skipped: 68112o1
#   Skipped: 75200cs1
#   Skipped: 4600c1
#   Skipped: 96330bl1
#   Skipped: 75950ba1
#   Skipped: 35079a1
#   Skipped: 25392o1
#   Skipped: 2040d1
#   Skipped: 40344g1
#   Skipped: 48018d1
#   Skipped: 21510i1
#   Skipped: 24234g1
#   Skipped: 27255c1
#   Skipped: 79420e1
#   Skipped: 82008r1
#   Skipped: 87360gf1
#   Skipped: 76593f1
#   Skipped: 6930l1
#   Skipped: 65936c1
#   Skipped: 89550z1
#   Skipped: 35574x1
#   Skipped: 40150y1
#   Skipped: 95550ev1
#   Skipped: 94784a1
#   Skipped: 87204h1
#   Skipped: 66528x1
#   Skipped: 30675q1
#   Skipped: 97410be1
#   Skipped: 92547d1
#   Skipped: 50874d1
#   Skipped: 47970v1
#   Skipped: 12760f1
#   Skipped: 64962a1
#   Skipped: 3990m1
#   Skipped: 53940c1
#   Skipped: 73696d1
#   Skipped: 29040ba1
#   Skipped: 77770r1
#   Skipped: 86982e1
#   Skipped: 70410e1
#   Skipped: 12495c1
#   Skipped: 93840bz1
#   Skipped: 8840b1
#   Skipped: 38442l1
#   Skipped: 59478a1
#   Skipped: 44690a1
#   Skipped: 35406l1
#   Skipped: 50150f1
#   Skipped: 63945k1
#   Skipped: 83986i1
#   Skipped: 423c1
#   Skipped: 54060e1
#   Skipped: 15925m1
#   Skipped: 96350c1
#   Skipped: 51402p1
#   Skipped: 11115j1
#   Skipped: 48218d1
#   Skipped: 18822a1
#   Skipped: 41778k1
#   Skipped: 83796a1
#   Skipped: 65835k1
#   Skipped: 11757a1
#   Skipped: 16762a1
#   Skipped: 91680q1
#   Skipped: 33150i1
#   Skipped: 43536b1
#   Skipped: 41600cd1
#   Skipped: 58695o1
#   Skipped: 21882o1
#   Skipped: 72405b1
#   Skipped: 49632i1
#   Skipped: 43559a1
#   Skipped: 13650j1
#   Skipped: 70980k1
#   Skipped: 83190e1
#   Skipped: 16704bk1
#   Skipped: 23760bo1
#   Skipped: 90450e1
#   Skipped: 43848j1
#   Skipped: 53424l1
#   Skipped: 19686d1
#   Skipped: 77506c1
#   Skipped: 94374i1
#   Skipped: 92181a1
#   Skipped: 29584d1
#   Skipped: 57846n1
#   Skipped: 10850ba1
#   Skipped: 64580c1
#   Skipped: 70523b1
#   Skipped: 52262d1
#   Skipped: 74979a1
#   Skipped: 23139b1
#   Skipped: 55232j1
#   Skipped: 67344x1
#   Skipped: 56400dj1
#   Skipped: 39465a1
#   Skipped: 9840q1
#   Skipped: 59700i1
#   Skipped: 1804a1
#   Skipped: 29127a1
#   Skipped: 38745f1
#   Skipped: 36890o1
#   Skipped: 19099a1
#   Skipped: 53480i1
#   Skipped: 4338e1
#   Skipped: 65601g1
#   Skipped: 94192m1
#   Skipped: 22491bh1
#   Skipped: 11840bf1
#   Skipped: 46170p1
#   Skipped: 18540g1
#   Skipped: 86478b1
#   Skipped: 24960bl1
#   Skipped: 49842m1
#   Skipped: 40280f1
#   Skipped: 62742b1
#   Skipped: 15890b1
#   Skipped: 68310r1
#   Skipped: 29648d1
#   Skipped: 30057a1
#   Skipped: 70422f1
#   Skipped: 24345a1
#   Skipped: 81161b1
#   Skipped: 10304y1
#   Skipped: 37464c1
#   Skipped: 96882d1
#   Skipped: 96066b1
#   Skipped: 42570m1
#   Skipped: 67150h1
#   Skipped: 17430w1
#   Skipped: 8874d1
#   Skipped: 81950p1
#   Skipped: 17388b1
#   Skipped: 28686m1
#   Skipped: 92400ew1
#   Skipped: 85065f1
#   Skipped: 59878z1
#   Skipped: 48705f1
#   Skipped: 30331f1
#   Skipped: 47502k1
#   Skipped: 11150j1
#   Skipped: 21372a1
#   Skipped: 16610i1
#   Skipped: 50325y1
#   Skipped: 58590y1
#   Skipped: 64674a1
#   Skipped: 30681f1
#   Skipped: 28420k1
#   Skipped: 93560a1
#   Skipped: 54530l1
#   Skipped: 40425t1
#   Skipped: 55200bv1
#   Skipped: 18396f1
#   Skipped: 55140d1
#   Skipped: 71210a1
#   Skipped: 14320j1
#   Skipped: 2040k1
#   Skipped: 19648u1
#   Skipped: 21420r1
#   Skipped: 25470k1
#   Skipped: 73419a1
#   Skipped: 2800a1
#   Skipped: 86856g1
#   Skipped: 39555c1
#   Skipped: 87906bc1
#   Skipped: 36190m1
#   Skipped: 11528a1
#   Skipped: 24666c1
#   Skipped: 52890j1
#   Skipped: 44640h1
#   Skipped: 59942g1
#   Skipped: 7606a1
#   Skipped: 62530a1
#   Skipped: 5265a1
#   Skipped: 38261a1
#   Skipped: 12428b1
#   Skipped: 91510e1
#   Skipped: 53802bt1
#   Skipped: 39135c1
#   Skipped: 11550cb1
#   Skipped: 56160m1
#   Skipped: 45621f1
#   Skipped: 51814d1
#   Skipped: 96672e1
#   Skipped: 77760bp1
#   Skipped: 24075b1
#   Skipped: 48944ba1
#   Skipped: 12370d1
#   Skipped: 97695c1
#   Skipped: 10368j1
#   Skipped: 62832bs1
#   Skipped: 70460c1
#   Skipped: 96075bh1
#   Skipped: 72396a1
#   Skipped: 14240c1
#   Skipped: 3130f1
#   Skipped: 15024m1
#   Skipped: 37840m1
#   Skipped: 46560g1
#   Skipped: 73350bd1
#   Skipped: 99264d1
#   Skipped: 29862j1
#   Skipped: 17841f1
#   Skipped: 63225p1
#   Skipped: 88504a1
#   Skipped: 27006f1
#   Skipped: 44450b1
#   Skipped: 61838h1
#   Skipped: 79680a1
#   Skipped: 30112a1
#   Skipped: 79890k1
#   Skipped: 63360cn1
#   Skipped: 35970a1
#   Skipped: 12400y1
#   Skipped: 76930h1
#   Skipped: 61455d1
#   Skipped: 56925d1
#   Skipped: 55520d1
#   Skipped: 24180i1
#   Skipped: 95760l1
#   Skipped: 26208bb1
#   Skipped: 4032n1
#   Skipped: 92391a1
#   Skipped: 8128l1
#   Skipped: 64395f1
#   Skipped: 6762y1
#   Skipped: 40425cl1
#   Skipped: 17199g1
#   Skipped: 84081c1
#   Skipped: 34496cm1
#   Skipped: 29526d1
#   Skipped: 76059a1
#   Skipped: 53730b1
#   Skipped: 10275f1
#   Skipped: 59225a1
#   Skipped: 37895d1
#   Skipped: 18306s1
#   Skipped: 40128ce1
#   Skipped: 22512f1
#   Skipped: 9889b1
#   Skipped: 32098h1
#   Skipped: 75698c1
#   Skipped: 55600w1
#   Skipped: 3045e1
#   Skipped: 67424f1
#   Skipped: 40242e1
#   Skipped: 20832w1
#   Skipped: 64428k1
#   Skipped: 31584v1
#   Skipped: 46458f1
#   Skipped: 34329a1
#   Skipped: 53960a1
#   Skipped: 53550ek1
#   Skipped: 95030h1
#   Skipped: 36954g1
#   Skipped: 39744by1
#   Skipped: 69696ef1
#   Skipped: 10110g1
#   Skipped: 24794bd1
#   Skipped: 1810c1
#   Skipped: 91730b1
#   Skipped: 65364g1
#   Skipped: 47901b1
#   Skipped: 52900f1
#   Skipped: 89794a1
#   Skipped: 95370du1
#   Skipped: 84546bb1
#   Skipped: 70890bj1
#   Skipped: 64230a1
#   Skipped: 80372b1
#   Skipped: 39153a1
#   Skipped: 66180g1
#   Skipped: 19854b1
#   Skipped: 66066p1
#   Skipped: 33306l1
#   Skipped: 66860b1
#   Skipped: 9568g1
#   Skipped: 9330a1
#   Skipped: 74032j1
#   Skipped: 23366c1
#   Skipped: 46912b1
#   Skipped: 60379f1
#   Skipped: 80010o1
#   Skipped: 36378d1
#   Skipped: 39492b1
#   Skipped: 46350p1
#   Skipped: 50754l1
#   Skipped: 36678a1
#   Skipped: 792d1
#   Skipped: 38739a1
#   Skipped: 20400de1
#   Skipped: 86380b1
#   Skipped: 71544m1
#   Skipped: 1070c1
#   Skipped: 24765l1
#   Skipped: 84291a1
#   Skipped: 79518d1
#   Skipped: 45075a1
#   Skipped: 20274f1
#   Skipped: 88725ce1
#   Skipped: 13376i1
#   Skipped: 46410s1
#   Skipped: 34672a1
#   Skipped: 80132b1
#   Skipped: 11646b1
#   Skipped: 47775be1
#   Skipped: 64722u1
#   Skipped: 6050q1
#   Skipped: 52338z1
#   Skipped: 88935bb1
#   Skipped: 28056f1
#   Skipped: 96408s1
#   Skipped: 40830d1
#   Skipped: 64386r1
#   Skipped: 76224b1
#   Skipped: 56870u1
#   Skipped: 15418c1
#   Skipped: 75259b1
#   Skipped: 30987e1
#   Skipped: 39538a1
#   Skipped: 36810ba1
#   Skipped: 19718b1
#   Skipped: 50895j1
#   Skipped: 31977x1
#   Skipped: 58575o1
#   Skipped: 14910o1
#   Skipped: 51090i1
#   Skipped: 52546d1
#   Skipped: 47955d1
#   Skipped: 37680g1
#   Skipped: 77526f1
#   Skipped: 27920i1
#   Skipped: 40896bc1
#   Skipped: 46692a1
#   Skipped: 35618c1
#   Skipped: 74340b1
#   Skipped: 83083h1
#   Skipped: 97410f1
#   Skipped: 97359h1
#   Skipped: 81088bk1
#   Skipped: 19570c1
#   Skipped: 7758f1
#   Skipped: 93786bu1
#   Skipped: 98946s1
#   Skipped: 42096l1
#   Skipped: 28329a1
#   Skipped: 2739b1
#   Skipped: 2754b1
#   Skipped: 87618d1
#   Skipped: 10862a1
#   Skipped: 55930j1
#   Skipped: 47808a1
#   Skipped: 70832e1
#   Skipped: 39762q1
#   Skipped: 10138b1
#   Skipped: 41949g1
#   Skipped: 91749f1
#   Skipped: 71466d1
#   Skipped: 24442e1
#   Skipped: 68420c1
#   Skipped: 82415a1
#   Skipped: 73185a1
#   Skipped: 56186d1
#   Skipped: 13950bb1
#   Skipped: 32450x1
#   Skipped: 82560q1
#   Skipped: 10925i1
#   Skipped: 13440ci1
#   Skipped: 59176a1
#   Skipped: 25773p1
#   Skipped: 36192p1
#   Skipped: 16003c1
#   Skipped: 28050do1
#   Skipped: 67710b1
#   Skipped: 17600c1
#   Skipped: 20748k1
#   Skipped: 13200bw1
#   Skipped: 68400cn1
#   Skipped: 11949c1
#   Skipped: 6201a1
#   Skipped: 88368f1
#   Skipped: 63574l1
#   Skipped: 33930w1
#   Skipped: 34251b1
#   Skipped: 44255c1
#   Skipped: 29232d1
#   Skipped: 60480eg1
#   Skipped: 98154k1
#   Skipped: 16170j1
#   Skipped: 33390br1
#   Skipped: 23600c1
#   Skipped: 1048a1
#   Skipped: 65296f1
#   Skipped: 35532g1
#   Skipped: 11998c1
#   Skipped: 98306a1
#   Skipped: 32318m1
#   Skipped: 88330k1
#   Skipped: 55437a1
#   Skipped: 62760c1
#   Skipped: 85426f1
#   Skipped: 3605a1
#   Skipped: 6474b1
#   Skipped: 46530j1
#   Skipped: 32370o1
#   Skipped: 35424a1
#   Skipped: 13386e1
#   Skipped: 18885a1
#   Skipped: 47214h1
#   Skipped: 92718b1
#   Skipped: 7744w1
#   Skipped: 18034e1
#   Skipped: 3054i1
#   Skipped: 59270a1
#   Skipped: 9777a1
#   Skipped: 88400m1
#   Skipped: 74592p1
#   Skipped: 18201c1
#   Skipped: 56925a1
#   Skipped: 64704v1
#   Skipped: 78735e1
#   Skipped: 51075l1
#   Skipped: 68208t1
#   Skipped: 19270j1
#   Skipped: 92400bz1
#   Skipped: 37170bd1
#   Skipped: 22382e1
#   Skipped: 50490bf1
#   Skipped: 65824f1
#   Skipped: 97941a1
#   Skipped: 40650r1
#   Skipped: 37312r1
#   Skipped: 45999d1
#   Skipped: 81182a1
#   Skipped: 41470f1
#   Skipped: 68450g1
#   Skipped: 2838f1
#   Skipped: 63820a1
#   Skipped: 29253c1
#   Skipped: 47390b1
#   Skipped: 85154f1
#   Skipped: 93264a1
#   Skipped: 84280a1
#   Skipped: 71334d1
#   Skipped: 37952b1
#   Skipped: 39240h1
#   Skipped: 19494d1
#   Skipped: 41280t1
#   Skipped: 23850bi1
#   Skipped: 36528n1
#   Skipped: 6192q1
#   Skipped: 56538a1
#   Skipped: 39814f1
#   Skipped: 87525z1
#   Skipped: 27472d1
#   Skipped: 61910e1
#   Skipped: 1370b1
#   Skipped: 27537b1
#   Skipped: 44934d1
#   Skipped: 89364a1
#   Skipped: 26726h1
#   Skipped: 79050p1
#   Skipped: 82880bb1
#   Skipped: 3042l1
#   Skipped: 95550il1
#   Skipped: 43744a1
#   Skipped: 88256d1
#   Skipped: 7187a1
#   Skipped: 1326b1
#   Skipped: 65136j1
#   Skipped: 54762b1
#   Skipped: 57120bc1
#   Skipped: 86877c1
#   Skipped: 3525c1
#   Skipped: 18312a1
#   Skipped: 90896r1
#   Skipped: 2421a1
#   Skipped: 63294d1
#   Skipped: 23238a1
#   Skipped: 36630g1
#   Skipped: 78182g1
#   Skipped: 76230et1
#   Skipped: 64600i1
#   Skipped: 72960x1
#   Skipped: 93773a1
#   Skipped: 99594d1
#   Skipped: 15138t1
#   Skipped: 15230c1
#   Skipped: 66087a1
#   Skipped: 76608fk1
#   Skipped: 18624d1
#   Skipped: 13387b1
#   Skipped: 53224b1
#   Skipped: 30366f1
#   Skipped: 22064n1
#   Skipped: 40592m1
#   Skipped: 21018f1
#   Skipped: 16510a1
#   Skipped: 84579g1
#   Skipped: 40460f1
#   Skipped: 34122s1
#   Skipped: 49200q1
#   Skipped: 9726a1
#   Skipped: 25578m1
#   Skipped: 26825a1
#   Skipped: 96148d1
#   Skipped: 75809j1
#   Skipped: 11880r1
#   Skipped: 62292c1
#   Skipped: 61326m1
#   Skipped: 30240j1
#   Skipped: 52218a1
#   Skipped: 38360g1
#   Skipped: 72160l1
#   Skipped: 11475c1
#   Skipped: 39800b1
#   Skipped: 42334a1
#   Skipped: 87242b1
#   Skipped: 27200cn1
#   Skipped: 27798p1
#   Skipped: 56792b1
#   Skipped: 96387e1
#   Skipped: 18417b1
#   Skipped: 47439c1
#   Skipped: 59994a1
#   Skipped: 26910e1
#   Skipped: 8071a1
#   Skipped: 53175g1
#   Skipped: 50025a1
#   Skipped: 91182b1
#   Skipped: 74382bq1
#   Skipped: 5187f1
#   Skipped: 94962ba1
#   Skipped: 11712bj1
#   Skipped: 70464a1
#   Skipped: 74784o1
#   Skipped: 40920a1
#   Skipped: 26988k1
#   Skipped: 61056cd1
#   Skipped: 85680g1
#   Skipped: 65965b1
#   Skipped: 82225j1
#   Skipped: 80514m1
#   Skipped: 65190e1
#   Skipped: 59094bz1
#   Skipped: 3480c1
#   Skipped: 24360i1
#   Skipped: 63616g1
#   Skipped: 86706n1
#   Skipped: 54435f1
#   Skipped: 60030a1
#   Skipped: 96455a1
#   Skipped: 41448i1
#   Skipped: 78288q1
#   Skipped: 15888v1
#   Skipped: 25900b1
#   Skipped: 87360gm1
# Successfully computed ap for 3628/8000 rank 1 curves
# Plotting...
# === Summary ===
# Rank 0: 3677/8000 curves (46.0%)
# Rank 1: 3628/8000 curves (45.4%)
# Total skipped: 8695

# %%
curve_db = load('Curve Database (Conductor < 100 000)/curve_database_c1_to_100000.sobj')

# %%
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import os
import random

# Randomly sample from curves with conductor < 100,000

Nsample = 1500

isogeny_classes = random.sample(list(curve_db.keys()), Nsample)

# Create output directory
os.makedirs('Random_curves/', exist_ok=True)

# Extract average aps sorted by rank
rk0_aps = []
rk1_aps = []
rk2_aps = []
rk3_aps = []
cs = []

for iso in tqdm(isogeny_classes, desc="Loading aps: "):
    curve = curve_db[iso]
    rk = curve['rank']
    aps = curve['ap_list']
    c = curve['conductor']
    cs.append(c)
    
    if rk == 0:
        rk0_aps.append(aps)
    elif rk == 1:
        rk1_aps.append(aps)
    elif rk == 2:
        rk2_aps.append(aps)
    elif rk == 3:
        rk3_aps.append(aps)

# Convert to numpy arrays
rk0_aps = np.array(rk0_aps) if len(rk0_aps) > 0 else None
rk1_aps = np.array(rk1_aps) if len(rk1_aps) > 0 else None
rk2_aps = np.array(rk2_aps) if len(rk2_aps) > 0 else None
rk3_aps = np.array(rk3_aps) if len(rk3_aps) > 0 else None

print("Averaging the aps...")
rk0_average_aps = np.mean(rk0_aps, axis=0) if rk0_aps is not None else None
rk1_average_aps = np.mean(rk1_aps, axis=0) if rk1_aps is not None else None
rk2_average_aps = np.mean(rk2_aps, axis=0) if rk2_aps is not None else None
rk3_average_aps = np.mean(rk3_aps, axis=0) if rk3_aps is not None else None
print("Done.")

# Print statistics
print(f"\nRank 0: {len(rk0_aps) if rk0_aps is not None else 0} isogeny classes")
print(f"Rank 1: {len(rk1_aps) if rk1_aps is not None else 0} isogeny classes")
print(f"Rank 2: {len(rk2_aps) if rk2_aps is not None else 0} isogeny classes")
print(f"Rank 3: {len(rk3_aps) if rk3_aps is not None else 0} isogeny classes")

# Save the data
averages_data = {
    'rank_0_average': rk0_average_aps.tolist() if rk0_average_aps is not None else None,
    'rank_1_average': rk1_average_aps.tolist() if rk1_average_aps is not None else None,
    'rank_2_average': rk2_average_aps.tolist() if rk2_average_aps is not None else None,
    'rank_3_average': rk3_average_aps.tolist() if rk3_average_aps is not None else None,
    'rank_0_count': len(rk0_aps) if rk0_aps is not None else 0,
    'rank_1_count': len(rk1_aps) if rk1_aps is not None else 0,
    'rank_2_count': len(rk2_aps) if rk2_aps is not None else 0,
    'rank_3_count': len(rk3_aps) if rk3_aps is not None else 0,
    'isogeny_classes': isogeny_classes,
    'conductors': cs,
    'Nsample': Nsample
}

save(averages_data, f'Random_curves/N{Nsample}_average_aps.sobj')
print(f"\nSaved average aps to Random_curves/N{Nsample}_average_aps.sobj")

# Save individual arrays
if rk0_average_aps is not None:
    save(rk0_average_aps, f'Random_curves/N{Nsample}_rk0_average_aps.sobj')
if rk1_average_aps is not None:
    save(rk1_average_aps, f'Random_curves/N{Nsample}_rk1_average_aps.sobj')
if rk2_average_aps is not None:
    save(rk2_average_aps, f'Random_curves/N{Nsample}_rk2_average_aps.sobj')
if rk3_average_aps is not None:
    save(rk3_average_aps, f'Random_curves/N{Nsample}_rk3_average_aps.sobj')

# Create plots
N = len(rk0_average_aps) if rk0_average_aps is not None else (
     len(rk1_average_aps) if rk1_average_aps is not None else 0)

if N > 0:
    # Plot 1: Rank 0 vs Rank 1
    plt.figure(figsize=(14, 7))
    if rk0_average_aps is not None:
        plt.scatter(range(N), rk0_average_aps, 
                   label=f"Rank 0 (n={len(rk0_aps)})", alpha=0.6, s=15)
    if rk1_average_aps is not None:
        plt.scatter(range(N), rk1_average_aps, 
                   label=f"Rank 1 (n={len(rk1_aps)})", alpha=0.6, s=15)
    plt.axhline(y=0, color='gray', linestyle='--', alpha=0.3)
    plt.legend(fontsize=12)
    plt.xlabel(r"Prime index $i$", fontsize=12)
    plt.ylabel(r"Average $a_{p_i}$", fontsize=12)
    plt.ylim(-8,8)
    plt.title(rf"Average $a_p$ vs prime index, $N_{{sample}}={Nsample}$", fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(f'Random_curves/N{Nsample}_ap_averages_rank0_vs_rank1.png', dpi=150)
    print(f"Saved plot: Random_curves/N{Nsample}_ap_averages_rank0_vs_rank1.png")
    plt.show()
    plt.close()
    
    # Plot 2: All ranks
    plt.figure(figsize=(14, 7))
    if rk0_average_aps is not None:
        plt.scatter(range(N), rk0_average_aps, 
                   label=f"Rank 0 (n={len(rk0_aps)})", alpha=0.5, s=12)
    if rk1_average_aps is not None:
        plt.scatter(range(N), rk1_average_aps, 
                   label=f"Rank 1 (n={len(rk1_aps)})", alpha=0.5, s=12)
    if rk2_average_aps is not None:
        plt.scatter(range(N), rk2_average_aps, 
                   label=f"Rank 2 (n={len(rk2_aps)})", alpha=0.5, s=12)
    if rk3_average_aps is not None:
        plt.scatter(range(N), rk3_average_aps, 
                   label=f"Rank 3 (n={len(rk3_aps)})", alpha=0.5, s=12)
    plt.axhline(y=0, color='gray', linestyle='--', alpha=0.3)
    plt.legend(fontsize=12)
    plt.xlabel(r"Prime index $i$", fontsize=12)
    plt.ylabel(r"Average $a_{p_i}$", fontsize=12)
    plt.title(rf"Average $a_p$ by rank, $N_{{sample}}={Nsample}$", fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(f'Random_curves/N{Nsample}_ap_averages_all_ranks.png', dpi=150)
    print(f"Saved plot: Random_curves/N{Nsample}_ap_averages_all_ranks.png")
    plt.show()
    plt.close()
    
    print("\nDone!")
else:
    print("\nNo data to plot")

# Print summary
print("\n" + "="*60)
print("SUMMARY")
print("="*60)
print(f"Sample size: {Nsample}")
print(f"Total isogeny classes: {len(isogeny_classes)}")
print(f"Rank distribution:")
print(f"  Rank 0: {len(rk0_aps) if rk0_aps is not None else 0}")
print(f"  Rank 1: {len(rk1_aps) if rk1_aps is not None else 0}")
print(f"  Rank 2: {len(rk2_aps) if rk2_aps is not None else 0}")
print(f"  Rank 3: {len(rk3_aps) if rk3_aps is not None else 0}")
print("="*60)

# Plot distribution of conductors
plt.figure(figsize=(12, 6))
plt.hist(cs, bins=100)
plt.xlabel("Conductor")
plt.ylabel("Count")
plt.title(rf"Conductor distribution, $N_{{sample}}={Nsample}$")
plt.tight_layout()
plt.savefig(f'Random_curves/N{Nsample}_conductor_distribution.png', dpi=150)
print(f"Saved plot: Random_curves/N{Nsample}_conductor_distribution.png")
plt.show()
plt.close()
# Out:
# Loading aps: 100%|██████████████████████████████████████████████████████████████| 1500/1500 [00:00<00:00, 386500.55it/s]
# Averaging the aps...
# Done.
#
# Rank 0: 612 isogeny classes
# Rank 1: 734 isogeny classes
# Rank 2: 154 isogeny classes
# Rank 3: 0 isogeny classes
#
# Saved average aps to Random_curves/N1500_average_aps.sobj
# Saved plot: Random_curves/N1500_ap_averages_rank0_vs_rank1.png
# Saved plot: Random_curves/N1500_ap_averages_all_ranks.png
#
# Done!
#
# ============================================================
# SUMMARY
# ============================================================
# Sample size: 1500
# Total isogeny classes: 1500
# Rank distribution:
#   Rank 0: 612
#   Rank 1: 734
#   Rank 2: 154
#   Rank 3: 0
# ============================================================
# Saved plot: Random_curves/N1500_conductor_distribution.png

# %%
candelas_phis = [
    QQ(1/385), QQ(1/105), QQ(1/77), QQ(1/70), QQ(1/66), QQ(1/55), QQ(1/42), 
    QQ(2/77), QQ(1/35), QQ(1/33), QQ(1/30), QQ(2/55), QQ(3/77), QQ(1/22), 
    QQ(1/21), QQ(4/77), QQ(3/55), QQ(2/35), QQ(2/33), QQ(5/77), QQ(1/15), 
    QQ(1/14), QQ(4/55), QQ(5/66), QQ(13/165), QQ(3/35), QQ(1/11), QQ(2/21), 
    QQ(23/231), QQ(1/10), QQ(8/77), QQ(7/66), QQ(6/55), QQ(17/154), QQ(4/35), 
    QQ(9/77), QQ(5/42), QQ(4/33), QQ(13/105), QQ(7/55), QQ(9/70), QQ(2/15), 
    QQ(31/231), QQ(3/22), QQ(1/7), QQ(8/55), QQ(5/33), QQ(17/105), QQ(9/55), 
    QQ(1/6), QQ(13/77), QQ(6/35), QQ(29/165), QQ(2/11), QQ(4/21), QQ(1/5), 
    QQ(7/33), QQ(3/14), QQ(37/165), QQ(5/22), QQ(8/35), QQ(7/30), QQ(5/21), 
    QQ(8/33), QQ(9/35), QQ(4/15), QQ(3/11), QQ(2/7), QQ(16/55), QQ(3/10), 
    QQ(10/33), QQ(17/55), QQ(13/42), QQ(11/35), QQ(7/22), QQ(12/35), QQ(19/55), 
    QQ(27/77), QQ(5/14), QQ(4/11), QQ(11/30), QQ(29/77), QQ(8/21), QQ(41/105), 
    QQ(13/33), QQ(2/5), QQ(17/42), QQ(9/22), QQ(32/77), QQ(23/55), QQ(3/7), 
    QQ(5/11), QQ(16/35), QQ(7/15), QQ(10/21), QQ(37/77), QQ(16/33), QQ(17/35), 
    QQ(27/55), QQ(1/2), QQ(28/55), QQ(18/35), QQ(17/33), QQ(11/21), QQ(8/15), 
    QQ(19/35), QQ(6/11), QQ(31/55), QQ(4/7), QQ(45/77), QQ(13/22), QQ(3/5), 
    QQ(20/33), QQ(13/21), QQ(7/11), QQ(9/14), QQ(23/35), QQ(2/3), QQ(15/22), 
    QQ(24/35), QQ(53/77), QQ(7/10), QQ(39/55), QQ(5/7), QQ(8/11), QQ(11/15), 
    QQ(49/66), QQ(25/33), QQ(16/21), QQ(27/35), QQ(17/22), QQ(11/14), QQ(4/5), 
    QQ(17/21), QQ(9/11), QQ(5/6), QQ(47/55), QQ(6/7), QQ(19/22), QQ(13/15), 
    QQ(29/33), QQ(31/35), QQ(69/77), QQ(9/10), QQ(19/21), QQ(10/11), QQ(32/35), 
    QQ(97/105), QQ(13/14), QQ(14/15), QQ(20/21), QQ(21/22), QQ(29/30), QQ(32/33), 
    QQ(34/35), QQ(54/55), QQ(78/77), QQ(56/55), QQ(36/35), QQ(34/33), QQ(31/30), 
    QQ(23/22), QQ(22/21), QQ(81/77), QQ(16/15), QQ(15/14), QQ(12/11), QQ(23/21), 
    QQ(11/10), QQ(39/35), QQ(37/33), QQ(17/15), QQ(25/22), QQ(8/7), QQ(63/55), 
    QQ(121/105), QQ(64/55), QQ(7/6), QQ(13/11), QQ(25/21), QQ(6/5), QQ(17/14), 
    QQ(27/22), QQ(43/35), QQ(41/33), QQ(44/35), QQ(19/15), QQ(14/11), QQ(9/7), 
    QQ(13/10), QQ(4/3), QQ(19/14), QQ(15/11), QQ(29/21), QQ(7/5), QQ(10/7), 
    QQ(16/11), QQ(51/35), QQ(22/15), QQ(49/33), QQ(3/2), QQ(32/21), QQ(23/15), 
    QQ(17/11), QQ(11/7), QQ(8/5), QQ(169/105), QQ(125/77), QQ(18/11), QQ(23/14), 
    QQ(5/3), QQ(59/35), QQ(17/10), QQ(12/7), QQ(19/11), QQ(37/21), QQ(25/14), 
    QQ(9/5), QQ(20/11), QQ(11/6), QQ(13/7), QQ(19/10), QQ(21/11), QQ(67/35), 
    QQ(27/14), QQ(65/33), QQ(2), QQ(31/15), QQ(23/11), QQ(44/21), QQ(21/10), 
    QQ(32/15), QQ(15/7), QQ(13/6), QQ(24/11), QQ(11/5), QQ(49/22), QQ(25/11), 
    QQ(16/7), QQ(7/3), QQ(12/5), QQ(17/7), QQ(27/11), QQ(5/2), QQ(53/21), 
    QQ(18/7), QQ(13/5), QQ(29/11), QQ(8/3), QQ(89/33), QQ(27/10), QQ(19/7), 
    QQ(14/5), QQ(31/11), QQ(99/35), QQ(17/6), QQ(20/7), QQ(61/21), QQ(32/11), 
    QQ(3), QQ(47/15), QQ(22/7), QQ(19/6), QQ(35/11), QQ(16/5), QQ(36/11), 
    QQ(23/7), QQ(10/3), QQ(17/5), QQ(24/7), QQ(7/2), QQ(25/7), QQ(18/5), 
    QQ(11/3), QQ(37/10), QQ(19/5), QQ(23/6), QQ(27/7), QQ(43/11), QQ(4), 
    QQ(47/11), QQ(85/21), QQ(25/6), QQ(21/5), QQ(64/15)
]

# %%
import matplotlib.pyplot as plt

# %%
len(candelas_phis)
# Out:
# 282

# %%
import matplotlib.pyplot as plt
import numpy as np

# Convert to floats for plotting
candelas_phis_float = [float(phi) for phi in candelas_phis]

# Create histogram
plt.figure(figsize=(12, 6))
plt.hist(candelas_phis_float, bins=50, edgecolor='black', alpha=0.7)
plt.xlabel(r'$\phi$', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title(f'Distribution of Candelas φ values (N={len(candelas_phis)})', fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# Print some statistics
print(f"Total number of φ values: {len(candelas_phis)}")
print(f"Min φ: {min(candelas_phis_float):.6f} (= {min(candelas_phis)})")
print(f"Max φ: {max(candelas_phis_float):.6f} (= {max(candelas_phis)})")
print(f"Mean φ: {np.mean(candelas_phis_float):.6f}")
print(f"Median φ: {np.median(candelas_phis_float):.6f}")
# Out:
# Total number of φ values: 285
# Min φ: 0.002597 (= 1/385)
# Max φ: 4.272727 (= 47/11)
# Mean φ: 1.177993
# Median φ: 0.896104
