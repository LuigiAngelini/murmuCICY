# %%
# Parallelized with dictionary structure indexed by isogeny class

from sage.databases.cremona import CremonaDatabase
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from joblib import Parallel, delayed
import multiprocessing
import os

# Get number of available cores
n_cores = multiprocessing.cpu_count()
print(f"Using {n_cores} CPU cores")

# Database of elliptic curves over the rationals
db = CremonaDatabase()

# Define conductor range
Nmax = 100000
Nmin = 1

# Create output directory
output_dir = f"Curve Database (Conductor < {Nmax})/"
os.makedirs(output_dir, exist_ok=True)
print(f"Output directory: {output_dir}")

# Extract elliptic curves with conductor in [Nmin, Nmax), sorted by rank
print(f"Extracting curves in conductor range [{Nmin}, {Nmax})...")
rank_curves = {0: [], 1: [], 2: [], 3: []}

for E in tqdm(db.iter(range(Nmin, Nmax)), desc="Loading curves"):
    r = E.rank()
    if r in rank_curves:
        rank_curves[r].append(E)

for r in sorted(rank_curves):
    print(f"Found {len(rank_curves[r])} rank {r} curves")

# Extract one representative per isogeny class using Cremona labels
print("Extracting isogeny class representatives...")

def get_isogeny_class(E):
    """Extract isogeny class from Cremona label (e.g., '11a1' -> '11a')"""
    label = E.cremona_label()
    i = len(label) - 1
    while i >= 0 and label[i].isdigit():
        i -= 1
    return label[:i+1]

def extract_isogeny_reps(curve_list, desc):
    """Extract one representative per isogeny class"""
    isogeny_reps = []
    seen_classes = set()
    for E in tqdm(curve_list, desc=desc):
        iso_class = get_isogeny_class(E)
        if iso_class not in seen_classes:
            isogeny_reps.append(E)
            seen_classes.add(iso_class)
    return isogeny_reps

isogeny_reps = {}
for r in sorted(rank_curves):
    isogeny_reps[r] = extract_isogeny_reps(rank_curves[r], f"Rank {r} isogeny classes")
    print(f"Found {len(isogeny_reps[r])} rank {r} isogeny classes")

all_curves = []
for r in sorted(isogeny_reps):
    all_curves.extend(isogeny_reps[r])
print(f"Total isogeny classes to process: {len(all_curves)}")

# Generate list of primes
n_primes = 1000
print(f"Computing first {n_primes} primes...")
primes_list = list(primes_first_n(n_primes))
print(f"Prime range: {primes_list[0]} to {primes_list[-1]}")

# Function to compute curve data
def compute_curve_data(E, primes):
    """Compute curve data including ap values"""
    try:
        isogeny_class = get_isogeny_class(E)
        conductor = E.conductor()
        rank = E.rank()
        ap_list = [int(a) for a in E.aplist(primes[-1])]
        return {
            'isogeny_class': isogeny_class,
            'conductor': int(conductor),
            'rank': int(rank),
            'ap_list': ap_list
        }
    except Exception as e:
        print(f"  Error processing {get_isogeny_class(E)}: {e}")
        return None

# Process all curves in parallel
print("Computing ap values for all isogeny classes in parallel...")
results = Parallel(n_jobs=n_cores, backend='multiprocessing')(
    delayed(compute_curve_data)(E, primes_list)
    for E in tqdm(all_curves, desc="Processing isogeny classes")
)

# Build the main database dictionary indexed by isogeny class
print("Building database dictionary...")
curve_database = {}
skipped_count = 0

for result in results:
    if result is not None:
        curve_database[result['isogeny_class']] = result
    else:
        skipped_count += 1

print(f"Successfully processed {len(curve_database)} isogeny classes")
print(f"Skipped {skipped_count} isogeny classes due to errors")

# ========== SAVE DATABASE ==========
print("\n" + "="*60)
print("SAVING DATABASE")
print("="*60)

db_basename = f"curve_database_N{Nmin}_to_{Nmax}"
database_file = os.path.join(output_dir, f"{db_basename}.sobj")
print(f"Saving database to {database_file}...")
save(curve_database, database_file)
print("Done!")

# ========== COMPUTE AVERAGES AND PLOT ==========
print("\nComputing average ap values...")

rk_data = {}
rk_avg = {}
for r in sorted(rank_curves):
    rk_data[r] = [v for v in curve_database.values() if v['rank'] == r]
    if len(rk_data[r]) > 0:
        ap_matrix = np.array([c['ap_list'] for c in rk_data[r]], dtype=np.float64)
        rk_avg[r] = np.mean(ap_matrix, axis=0)
    else:
        rk_avg[r] = np.zeros(n_primes)

overall_avg = np.mean(
    np.array([v['ap_list'] for v in curve_database.values()], dtype=np.float64),
    axis=0
)

# Plot 1: Rank 0 vs Rank 1
plt.figure(figsize=(14, 7))
plt.scatter(range(n_primes), rk_avg[0], label=f"Rank 0 (n={len(rk_data[0])})", alpha=0.6, s=15)
plt.scatter(range(n_primes), rk_avg[1], label=f"Rank 1 (n={len(rk_data[1])})", alpha=0.6, s=15)
plt.axhline(y=0, color='gray', linestyle='--', alpha=0.3)
plt.legend(fontsize=12)
plt.xlabel(r"Prime index $i$", fontsize=12)
plt.ylabel(r"Average $a_{p_i}$", fontsize=12)
plt.title(fr"Average $a_p$ vs prime index over conductors $N \in [{Nmin}, {Nmax})$", fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plot1_file = os.path.join(output_dir, f"ap_averages_rank0_vs_rank1_N{Nmin}_to_{Nmax}.png")
plt.savefig(plot1_file, dpi=150)
print(f"  Saved plot: {plot1_file}")
plt.close()

# Plot 2: All ranks
plt.figure(figsize=(14, 7))
for r in sorted(rk_data):
    if len(rk_data[r]) > 0:
        plt.scatter(range(n_primes), rk_avg[r], label=f"Rank {r} (n={len(rk_data[r])})", alpha=0.5, s=12)
plt.axhline(y=0, color='gray', linestyle='--', alpha=0.3)
plt.legend(fontsize=12)
plt.xlabel(r"Prime index $i$", fontsize=12)
plt.ylabel(r"Average $a_{p_i}$", fontsize=12)
plt.title(fr"Average $a_p$ by rank over conductors $N \in [{Nmin}, {Nmax})$", fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plot2_file = os.path.join(output_dir, f"ap_averages_all_ranks_N{Nmin}_to_{Nmax}.png")
plt.savefig(plot2_file, dpi=150)
print(f"  Saved plot: {plot2_file}")
plt.close()

# Plot 3: Overall average
plt.figure(figsize=(14, 7))
plt.scatter(range(n_primes), overall_avg, alpha=0.6, s=15, color='purple')
plt.axhline(y=0, color='gray', linestyle='--', alpha=0.3)
plt.xlabel(r"Prime index $i$", fontsize=12)
plt.ylabel(r"Average $a_{p_i}$", fontsize=12)
plt.title(fr"Overall average $a_p$ over all {len(curve_database)} isogeny classes with $N \in [{Nmin}, {Nmax})$", fontsize=14)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plot3_file = os.path.join(output_dir, f"ap_average_overall_N{Nmin}_to_{Nmax}.png")
plt.savefig(plot3_file, dpi=150)
print(f"  Saved plot: {plot3_file}")
plt.close()

# ========== SUMMARY ==========
print("\n" + "="*60)
print("SUMMARY")
print("="*60)
print(f"Conductor range: [{Nmin}, {Nmax})")
print(f"Number of primes: {n_primes} (up to {primes_list[-1]})")
print(f"\nIsogeny classes by rank:")
for r in sorted(rk_data):
    print(f"  Rank {r}: {len(rk_data[r])} isogeny classes")
print(f"  Total:  {len(curve_database)} isogeny classes")
print(f"\nSaved files:")
print(f"  - {db_basename}.sobj")
print(f"  - 3 PNG plots")
print(f"\nAll files in: {output_dir}")
print(f"\nUsage:")
print(f"  curve_db = load('{db_basename}.sobj')")
print(f"  curve_db['11a']  # -> dict with isogeny_class, conductor, rank, ap_list")
print("="*60)
# Out:
# Output directory: Curve Database (Conductor < 500 000)/
# Using 28 CPU cores
# Conductor range: [1, 500000)
# Batch size: 500 conductors per task
#
# Computing first 1000 primes...
# Prime range: 2 to 7919
#
# Building conductor batches...
# Created 1000 batches
# Loading curves and computing ap values in parallel...
# Processing batches:   8%|█████                                                        | 84/1000 [03:01<37:20,  2.45s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 87
#      84 print(f"Created {len(conductor_batches)} batches")
#      86 print("Loading curves and computing ap values in parallel...")
# ---> 87 batch_results = Parallel(n_jobs=n_cores, backend='multiprocessing')(
#      88     delayed(process_conductor_batch)(batch, p_max)
#      89     for batch in tqdm(conductor_batches, desc="Processing batches")
#      90 )
# ...

# %%
from tqdm import tqdm

# ---- Example usage --------
# Load database
try:
    curve_db
    print(f"✓ curve_db loaded with {len(curve_db)} isogeny classes")
except NameError:
    print("Loading curve database...")
    curve_db = load('Curve Database (Conductor < 100000)/curve_database_N1_to_100000.sobj')
    print(f"✓ Loaded curve_db with {len(curve_db)} isogeny classes")

# Build subdatabase of fixed curves
print('Building rank-restricted databases...')

rk0_curves = {}
rk1_curves = {}
rk2_curves = {}
rk3_curves = {}
for iso in tqdm(list(curve_db.keys()), 'Building databases'):
    rk = curve_db[iso]['rank']
    if rk == 0:
        rk0_curves[iso] = curve_db[iso]
    elif rk == 1:
        rk1_curves[iso] = curve_db[iso]
    elif rk == 2:
        rk2_curves[iso] = curve_db[iso]
    elif rk == 3:
        rk3_curves[iso] = curve_db[iso]
